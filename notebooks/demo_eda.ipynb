# %%
import pandas as pd

# 加载数据
X_train = pd.read_csv("../data/X_train.csv", skiprows=1, header=None)
y_train = pd.read_csv("../data/y_train.csv", skiprows=1, header=None)

# 转为 NumPy
X = X_train.values                # shape: (10000, 300)
y = y_train.values.ravel()       # shape: (10000,)

# %%
print(f"The size of data is {X.shape[0]}")
print(f"The number of features of each sample is {X.shape[1]}")
# Out:
# The size of data is 10000
# The number of features of each sample is 300

# %% [markdown]
# ### 缺失值检测

# %%
import numpy as np

print(f"Feature missing values: {np.isnan(X).sum()}")
print(f"Label missing values: {np.isnan(y).sum()}")
# Out:
# Feature missing values: 0
# Label missing values: 0

# %% [markdown]
# ## 特征选择

# %% [markdown]
# ### 每对类别对应的 Top-K 区分性特征信息（按均值差排序）

# %%
import numpy as np
from itertools import combinations

class_list = np.unique(y)
class_pairs = list(combinations(class_list, 2))

pairwise_topk = {}
k = 10  # 控制 top-K 

for cls0, cls1 in class_pairs:
    idx0 = (y == cls0)
    idx1 = (y == cls1)
    
    # 计算class0和class1的特征均值差异
    mean0 = X[idx0].mean(axis=0)
    mean1 = X[idx1].mean(axis=0)
    diff = np.abs(mean0 - mean1)
    
    # 对特征差异进行排序
    topk_idx = np.argsort(diff)[::-1][:k]  

    feature_info = []
    for rank, feat_idx in enumerate(topk_idx):
        feature_info.append({
            "feature_idx": int(feat_idx),
            "mean_diff": float(diff[feat_idx]),
            "rank": rank + 1
        })

    pairwise_topk[(int(cls0), int(cls1))] = feature_info

# %%
for pair in list(pairwise_topk.keys()):
    print(f"\nClass Pair: {pair}")
    for feat in pairwise_topk[pair]:
        print(f"  F{feat['feature_idx']}: mean_diff = {feat['mean_diff']:.4f}")
# Out:
# Class Pair: (0, 1)
#   F131: mean_diff = 2.3882
#   F35: mean_diff = 1.9080
#   F85: mean_diff = 1.8621
#   F223: mean_diff = 1.8311
#   F200: mean_diff = 1.8172
#   F184: mean_diff = 1.8020
#   F148: mean_diff = 1.7221
#   F222: mean_diff = 1.7164
#   F42: mean_diff = 1.6864
#   F204: mean_diff = 1.6783
#
# Class Pair: (0, 2)
#   F55: mean_diff = 1.9008
#   F186: mean_diff = 1.8883
#   F208: mean_diff = 1.8279
#   F53: mean_diff = 1.5811
#   F123: mean_diff = 1.5511
#   F240: mean_diff = 1.4859
#   F242: mean_diff = 1.4702
#   F125: mean_diff = 1.4607
#   F44: mean_diff = 1.4404
#   F293: mean_diff = 1.4218
#
# Class Pair: (0, 3)
#   F210: mean_diff = 1.2958
#   F53: mean_diff = 1.2275
#   F21: mean_diff = 1.1430
#   F55: mean_diff = 1.0952
#   F278: mean_diff = 1.0869
#   F284: mean_diff = 1.0657
#   F254: mean_diff = 1.0295
#   F137: mean_diff = 0.9544
#   F288: mean_diff = 0.9502
#   F216: mean_diff = 0.9390
#
# Class Pair: (0, 4)
#   F53: mean_diff = 1.6164
#   F22: mean_diff = 1.5048
#   F213: mean_diff = 1.3916
#   F291: mean_diff = 1.3072
#   F91: mean_diff = 1.2712
#   F54: mean_diff = 1.2239
#   F186: mean_diff = 1.2074
#   F107: mean_diff = 1.1981
#   F237: mean_diff = 1.1785
#   F261: mean_diff = 1.1770
#
# Class Pair: (0, 5)
#   F249: mean_diff = 1.7406
#   F101: mean_diff = 1.6744
#   F257: mean_diff = 1.6458
#   F216: mean_diff = 1.6346
#   F265: mean_diff = 1.6071
#   F86: mean_diff = 1.6033
#   F132: mean_diff = 1.5415
#   F292: mean_diff = 1.5078
#   F141: mean_diff = 1.4810
#   F63: mean_diff = 1.4715
#
# Class Pair: (0, 6)
#   F205: mean_diff = 2.3257
#   F182: mean_diff = 2.3075
#   F261: mean_diff = 1.9943
#   F249: mean_diff = 1.9556
#   F216: mean_diff = 1.9180
#   F218: mean_diff = 1.9163
#   F189: mean_diff = 1.8594
#   F132: mean_diff = 1.7999
#   F117: mean_diff = 1.7556
#   F97: mean_diff = 1.7422
#
# Class Pair: (0, 7)
#   F223: mean_diff = 1.5807
#   F44: mean_diff = 1.5530
#   F162: mean_diff = 1.4952
#   F240: mean_diff = 1.4539
#   F79: mean_diff = 1.3917
#   F139: mean_diff = 1.3434
#   F101: mean_diff = 1.3009
#   F259: mean_diff = 1.2876
#   F132: mean_diff = 1.2800
#   F178: mean_diff = 1.2430
#
# Class Pair: (0, 8)
#   F56: mean_diff = 0.8259
#   F186: mean_diff = 0.5458
#   F43: mean_diff = 0.5252
#   F37: mean_diff = 0.5178
#   F180: mean_diff = 0.5109
#   F137: mean_diff = 0.5007
#   F244: mean_diff = 0.4943
#   F25: mean_diff = 0.4756
#   F261: mean_diff = 0.4744
#   F133: mean_diff = 0.4288
#
# Class Pair: (0, 9)
#   F182: mean_diff = 2.2234
#   F205: mean_diff = 2.0907
#   F249: mean_diff = 1.9867
#   F261: mean_diff = 1.9644
#   F117: mean_diff = 1.9058
#   F216: mean_diff = 1.9007
#   F189: mean_diff = 1.8325
#   F274: mean_diff = 1.7935
#   F132: mean_diff = 1.7820
#   F101: mean_diff = 1.7782
#
# Class Pair: (0, 10)
#   F265: mean_diff = 1.5439
#   F79: mean_diff = 1.5028
#   F259: mean_diff = 1.4481
#   F242: mean_diff = 1.4117
#   F53: mean_diff = 1.3937
#   F284: mean_diff = 1.3570
#   F240: mean_diff = 1.3344
#   F101: mean_diff = 1.3206
#   F215: mean_diff = 1.3205
#   F223: mean_diff = 1.3118
#
# Class Pair: (0, 11)
#   F208: mean_diff = 2.6527
#   F45: mean_diff = 2.4340
#   F297: mean_diff = 2.2903
#   F286: mean_diff = 2.2788
#   F25: mean_diff = 2.2194
#   F55: mean_diff = 2.0832
#   F108: mean_diff = 2.0158
#   F289: mean_diff = 1.9733
#   F285: mean_diff = 1.9624
#   F106: mean_diff = 1.9237
#
# Class Pair: (0, 12)
#   F53: mean_diff = 1.5209
#   F208: mean_diff = 1.3849
#   F55: mean_diff = 1.3395
#   F186: mean_diff = 1.1736
#   F216: mean_diff = 1.0660
#   F25: mean_diff = 1.0482
#   F284: mean_diff = 1.0336
#   F108: mean_diff = 1.0295
#   F66: mean_diff = 1.0248
#   F132: mean_diff = 1.0201
#
# Class Pair: (0, 13)
#   F53: mean_diff = 1.6978
#   F54: mean_diff = 1.2437
#   F240: mean_diff = 1.2116
#   F55: mean_diff = 1.2087
#   F140: mean_diff = 1.1687
#   F208: mean_diff = 1.1659
#   F91: mean_diff = 1.1354
#   F261: mean_diff = 1.0895
#   F66: mean_diff = 1.0881
#   F293: mean_diff = 1.0869
#
# Class Pair: (0, 14)
#   F216: mean_diff = 1.7568
#   F257: mean_diff = 1.6785
#   F87: mean_diff = 1.6396
#   F101: mean_diff = 1.6245
#   F284: mean_diff = 1.5633
#   F63: mean_diff = 1.5573
#   F132: mean_diff = 1.5494
#   F292: mean_diff = 1.5263
#   F265: mean_diff = 1.4952
#   F218: mean_diff = 1.4865
#
# Class Pair: (0, 15)
#   F53: mean_diff = 2.2178
#   F21: mean_diff = 1.9304
#   F280: mean_diff = 1.8690
#   F214: mean_diff = 1.7782
#   F131: mean_diff = 1.7257
#   F35: mean_diff = 1.6880
#   F215: mean_diff = 1.5694
#   F204: mean_diff = 1.5425
#   F120: mean_diff = 1.5327
#   F85: mean_diff = 1.4802
#
# Class Pair: (0, 16)
#   F44: mean_diff = 2.3577
#   F107: mean_diff = 2.3389
#   F51: mean_diff = 2.1999
#   F265: mean_diff = 2.0770
#   F291: mean_diff = 2.0438
#   F250: mean_diff = 1.9741
#   F284: mean_diff = 1.9705
#   F295: mean_diff = 1.9653
#   F247: mean_diff = 1.9593
#   F148: mean_diff = 1.9157
#
# Class Pair: (0, 17)
#   F132: mean_diff = 2.2891
#   F284: mean_diff = 1.9586
#   F216: mean_diff = 1.8534
#   F214: mean_diff = 1.7906
#   F218: mean_diff = 1.7318
#   F117: mean_diff = 1.6661
#   F247: mean_diff = 1.5991
#   F265: mean_diff = 1.5463
#   F76: mean_diff = 1.4781
#   F17: mean_diff = 1.4619
#
# Class Pair: (0, 18)
#   F53: mean_diff = 1.9292
#   F96: mean_diff = 1.6859
#   F261: mean_diff = 1.5653
#   F284: mean_diff = 1.5396
#   F196: mean_diff = 1.5008
#   F205: mean_diff = 1.3832
#   F66: mean_diff = 1.3264
#   F35: mean_diff = 1.2712
#   F208: mean_diff = 1.2655
#   F91: mean_diff = 1.2116
#
# Class Pair: (0, 19)
#   F210: mean_diff = 1.5197
#   F55: mean_diff = 1.4974
#   F107: mean_diff = 1.4545
#   F101: mean_diff = 1.3989
#   F254: mean_diff = 1.3952
#   F53: mean_diff = 1.3398
#   F223: mean_diff = 1.2206
#   F284: mean_diff = 1.1915
#   F242: mean_diff = 1.1864
#   F24: mean_diff = 1.1421
#
# Class Pair: (0, 20)
#   F53: mean_diff = 1.7566
#   F208: mean_diff = 1.5762
#   F35: mean_diff = 1.2729
#   F284: mean_diff = 1.2634
#   F132: mean_diff = 1.1652
#   F55: mean_diff = 1.1410
#   F254: mean_diff = 1.1232
#   F67: mean_diff = 1.0953
#   F199: mean_diff = 1.0906
#   F216: mean_diff = 1.0485
#
# Class Pair: (0, 21)
#   F208: mean_diff = 1.7384
#   F53: mean_diff = 1.6566
#   F66: mean_diff = 1.4912
#   F284: mean_diff = 1.4622
#   F215: mean_diff = 1.3307
#   F189: mean_diff = 1.2840
#   F291: mean_diff = 1.2291
#   F137: mean_diff = 1.2221
#   F186: mean_diff = 1.2011
#   F25: mean_diff = 1.1873
#
# Class Pair: (0, 22)
#   F25: mean_diff = 2.3382
#   F286: mean_diff = 2.2430
#   F66: mean_diff = 2.1081
#   F215: mean_diff = 2.0694
#   F35: mean_diff = 2.0470
#   F208: mean_diff = 2.0336
#   F45: mean_diff = 1.9734
#   F41: mean_diff = 1.9481
#   F106: mean_diff = 1.9207
#   F156: mean_diff = 1.8313
#
# Class Pair: (0, 23)
#   F265: mean_diff = 2.2425
#   F293: mean_diff = 2.0930
#   F215: mean_diff = 2.0867
#   F107: mean_diff = 1.9962
#   F211: mean_diff = 1.9733
#   F213: mean_diff = 1.9371
#   F44: mean_diff = 1.9185
#   F148: mean_diff = 1.9168
#   F79: mean_diff = 1.9046
#   F242: mean_diff = 1.8858
#
# Class Pair: (0, 24)
#   F53: mean_diff = 1.2813
#   F186: mean_diff = 1.0430
#   F54: mean_diff = 1.0021
#   F289: mean_diff = 0.9418
#   F291: mean_diff = 0.9107
#   F22: mean_diff = 0.9003
#   F284: mean_diff = 0.8988
#   F183: mean_diff = 0.8915
#   F132: mean_diff = 0.8799
#   F208: mean_diff = 0.8723
#
# Class Pair: (0, 25)
#   F53: mean_diff = 1.6551
#   F223: mean_diff = 1.2575
#   F54: mean_diff = 1.2556
#   F208: mean_diff = 1.1912
#   F240: mean_diff = 1.1882
#   F55: mean_diff = 1.1834
#   F242: mean_diff = 1.1395
#   F22: mean_diff = 1.0954
#   F186: mean_diff = 1.0938
#   F91: mean_diff = 1.0821
#
# Class Pair: (0, 26)
#   F284: mean_diff = 1.8228
#   F53: mean_diff = 1.3821
#   F208: mean_diff = 1.3181
#   F216: mean_diff = 1.1798
#   F293: mean_diff = 1.1260
#   F254: mean_diff = 1.1063
#   F137: mean_diff = 1.0731
#   F237: mean_diff = 1.0396
#   F54: mean_diff = 1.0327
#   F132: mean_diff = 1.0231
#
# Class Pair: (0, 27)
#   F292: mean_diff = 1.9419
#   F284: mean_diff = 1.8502
#   F244: mean_diff = 1.8068
#   F287: mean_diff = 1.8017
#   F99: mean_diff = 1.7958
#   F79: mean_diff = 1.7245
#   F259: mean_diff = 1.6744
#   F61: mean_diff = 1.6278
#   F22: mean_diff = 1.6138
#   F265: mean_diff = 1.5951
#
# Class Pair: (1, 2)
#   F131: mean_diff = 2.7636
#   F125: mean_diff = 2.3931
#   F279: mean_diff = 2.3168
#   F272: mean_diff = 2.1021
#   F259: mean_diff = 2.0280
#   F180: mean_diff = 1.9646
#   F222: mean_diff = 1.9445
#   F78: mean_diff = 1.8932
#   F120: mean_diff = 1.8907
#   F217: mean_diff = 1.8822
#
# Class Pair: (1, 3)
#   F131: mean_diff = 2.7087
#   F85: mean_diff = 2.0221
#   F222: mean_diff = 1.9581
#   F114: mean_diff = 1.9208
#   F279: mean_diff = 1.9198
#   F200: mean_diff = 1.8167
#   F169: mean_diff = 1.7729
#   F204: mean_diff = 1.7683
#   F100: mean_diff = 1.7152
#   F12: mean_diff = 1.6480
#
# Class Pair: (1, 4)
#   F131: mean_diff = 3.3018
#   F85: mean_diff = 2.6406
#   F194: mean_diff = 2.3476
#   F279: mean_diff = 2.1361
#   F100: mean_diff = 2.0683
#   F157: mean_diff = 1.8167
#   F150: mean_diff = 1.7854
#   F91: mean_diff = 1.7719
#   F259: mean_diff = 1.6083
#   F222: mean_diff = 1.5909
#
# Class Pair: (1, 5)
#   F194: mean_diff = 2.2485
#   F222: mean_diff = 2.1982
#   F46: mean_diff = 2.1570
#   F131: mean_diff = 2.1500
#   F90: mean_diff = 2.0768
#   F61: mean_diff = 1.8793
#   F249: mean_diff = 1.7851
#   F141: mean_diff = 1.7767
#   F182: mean_diff = 1.7662
#   F279: mean_diff = 1.6877
#
# Class Pair: (1, 6)
#   F182: mean_diff = 2.7503
#   F75: mean_diff = 2.6921
#   F46: mean_diff = 2.4715
#   F205: mean_diff = 2.2810
#   F279: mean_diff = 2.2579
#   F85: mean_diff = 2.1756
#   F61: mean_diff = 2.1578
#   F4: mean_diff = 2.1194
#   F238: mean_diff = 2.0726
#   F160: mean_diff = 2.0594
#
# Class Pair: (1, 7)
#   F131: mean_diff = 2.6445
#   F85: mean_diff = 2.6130
#   F279: mean_diff = 2.2073
#   F259: mean_diff = 2.1816
#   F194: mean_diff = 2.1510
#   F75: mean_diff = 1.8023
#   F12: mean_diff = 1.7647
#   F161: mean_diff = 1.7412
#   F114: mean_diff = 1.7307
#   F33: mean_diff = 1.7095
#
# Class Pair: (1, 8)
#   F131: mean_diff = 2.5531
#   F85: mean_diff = 2.0406
#   F200: mean_diff = 1.9231
#   F12: mean_diff = 1.7583
#   F35: mean_diff = 1.7118
#   F222: mean_diff = 1.6942
#   F42: mean_diff = 1.5947
#   F223: mean_diff = 1.5885
#   F184: mean_diff = 1.5770
#   F194: mean_diff = 1.5692
#
# Class Pair: (1, 9)
#   F182: mean_diff = 2.6663
#   F75: mean_diff = 2.3221
#   F279: mean_diff = 2.2307
#   F61: mean_diff = 2.2106
#   F85: mean_diff = 2.1563
#   F238: mean_diff = 2.1339
#   F46: mean_diff = 2.1209
#   F4: mean_diff = 2.0940
#   F205: mean_diff = 2.0460
#   F131: mean_diff = 2.0417
#
# Class Pair: (1, 10)
#   F131: mean_diff = 3.1993
#   F85: mean_diff = 2.5890
#   F259: mean_diff = 2.3421
#   F194: mean_diff = 2.2960
#   F279: mean_diff = 2.2849
#   F200: mean_diff = 2.0808
#   F100: mean_diff = 2.0209
#   F75: mean_diff = 1.9125
#   F33: mean_diff = 1.8809
#   F114: mean_diff = 1.8275
#
# Class Pair: (1, 11)
#   F208: mean_diff = 2.2522
#   F297: mean_diff = 2.1017
#   F161: mean_diff = 2.0927
#   F112: mean_diff = 1.9644
#   F39: mean_diff = 1.9491
#   F222: mean_diff = 1.9335
#   F286: mean_diff = 1.9322
#   F108: mean_diff = 1.8682
#   F179: mean_diff = 1.8319
#   F289: mean_diff = 1.8225
#
# Class Pair: (1, 12)
#   F131: mean_diff = 2.4564
#   F148: mean_diff = 1.8902
#   F85: mean_diff = 1.8871
#   F222: mean_diff = 1.8613
#   F194: mean_diff = 1.6906
#   F200: mean_diff = 1.6892
#   F279: mean_diff = 1.6738
#   F204: mean_diff = 1.5495
#   F114: mean_diff = 1.4881
#   F91: mean_diff = 1.4703
#
# Class Pair: (1, 13)
#   F131: mean_diff = 2.7788
#   F85: mean_diff = 2.2169
#   F279: mean_diff = 2.0758
#   F194: mean_diff = 2.0623
#   F100: mean_diff = 1.8633
#   F200: mean_diff = 1.7618
#   F259: mean_diff = 1.6841
#   F148: mean_diff = 1.6508
#   F91: mean_diff = 1.6362
#   F114: mean_diff = 1.5978
#
# Class Pair: (1, 14)
#   F194: mean_diff = 2.2195
#   F90: mean_diff = 2.1596
#   F222: mean_diff = 2.1443
#   F131: mean_diff = 2.1324
#   F46: mean_diff = 1.9443
#   F169: mean_diff = 1.7334
#   F141: mean_diff = 1.7214
#   F61: mean_diff = 1.7066
#   F23: mean_diff = 1.6697
#   F180: mean_diff = 1.6499
#
# Class Pair: (1, 15)
#   F148: mean_diff = 1.1374
#   F227: mean_diff = 1.0868
#   F78: mean_diff = 1.0172
#   F53: mean_diff = 1.0001
#   F42: mean_diff = 0.9104
#   F91: mean_diff = 0.9098
#   F223: mean_diff = 0.8491
#   F81: mean_diff = 0.8089
#   F186: mean_diff = 0.7954
#   F176: mean_diff = 0.7647
#
# Class Pair: (1, 16)
#   F259: mean_diff = 2.6603
#   F107: mean_diff = 2.4645
#   F23: mean_diff = 2.4348
#   F165: mean_diff = 2.2428
#   F43: mean_diff = 2.1958
#   F272: mean_diff = 2.1828
#   F79: mean_diff = 2.1402
#   F36: mean_diff = 2.1202
#   F279: mean_diff = 2.1155
#   F51: mean_diff = 2.1016
#
# Class Pair: (1, 17)
#   F131: mean_diff = 2.5795
#   F78: mean_diff = 2.2047
#   F194: mean_diff = 2.1538
#   F85: mean_diff = 2.1382
#   F259: mean_diff = 2.0524
#   F75: mean_diff = 2.0419
#   F61: mean_diff = 1.9912
#   F33: mean_diff = 1.9320
#   F90: mean_diff = 1.9098
#   F46: mean_diff = 1.8683
#
# Class Pair: (1, 18)
#   F131: mean_diff = 3.1167
#   F194: mean_diff = 2.4474
#   F85: mean_diff = 2.3097
#   F114: mean_diff = 2.2864
#   F279: mean_diff = 2.2594
#   F196: mean_diff = 2.0828
#   F75: mean_diff = 1.8495
#   F100: mean_diff = 1.8004
#   F4: mean_diff = 1.7641
#   F91: mean_diff = 1.7124
#
# Class Pair: (1, 19)
#   F131: mean_diff = 2.8812
#   F85: mean_diff = 2.2540
#   F200: mean_diff = 2.2323
#   F279: mean_diff = 2.1534
#   F100: mean_diff = 1.8070
#   F259: mean_diff = 1.7417
#   F42: mean_diff = 1.6072
#   F107: mean_diff = 1.5800
#   F222: mean_diff = 1.5582
#   F114: mean_diff = 1.5547
#
# Class Pair: (1, 20)
#   F131: mean_diff = 2.7579
#   F222: mean_diff = 2.3140
#   F85: mean_diff = 2.1267
#   F194: mean_diff = 2.0373
#   F279: mean_diff = 1.8837
#   F148: mean_diff = 1.8335
#   F259: mean_diff = 1.8244
#   F125: mean_diff = 1.6646
#   F180: mean_diff = 1.6516
#   F61: mean_diff = 1.5952
#
# Class Pair: (1, 21)
#   F131: mean_diff = 2.4354
#   F222: mean_diff = 1.9137
#   F180: mean_diff = 1.7656
#   F122: mean_diff = 1.7593
#   F194: mean_diff = 1.7366
#   F223: mean_diff = 1.7031
#   F259: mean_diff = 1.6128
#   F78: mean_diff = 1.5898
#   F204: mean_diff = 1.5817
#   F157: mean_diff = 1.4948
#
# Class Pair: (1, 22)
#   F110: mean_diff = 1.9252
#   F91: mean_diff = 1.9104
#   F286: mean_diff = 1.8965
#   F39: mean_diff = 1.7505
#   F84: mean_diff = 1.6715
#   F208: mean_diff = 1.6331
#   F25: mean_diff = 1.5064
#   F66: mean_diff = 1.5059
#   F6: mean_diff = 1.5035
#   F179: mean_diff = 1.4508
#
# Class Pair: (1, 23)
#   F131: mean_diff = 3.2636
#   F85: mean_diff = 2.9684
#   F259: mean_diff = 2.5715
#   F100: mean_diff = 2.3738
#   F200: mean_diff = 2.2398
#   F79: mean_diff = 2.1808
#   F279: mean_diff = 2.1575
#   F107: mean_diff = 2.1217
#   F180: mean_diff = 2.0412
#   F293: mean_diff = 2.0403
#
# Class Pair: (1, 24)
#   F131: mean_diff = 2.8014
#   F85: mean_diff = 2.6071
#   F200: mean_diff = 2.0539
#   F194: mean_diff = 2.0059
#   F279: mean_diff = 1.8685
#   F148: mean_diff = 1.7570
#   F222: mean_diff = 1.7300
#   F23: mean_diff = 1.6261
#   F42: mean_diff = 1.6137
#   F12: mean_diff = 1.5214
#
# Class Pair: (1, 25)
#   F131: mean_diff = 3.1834
#   F85: mean_diff = 2.3100
#   F194: mean_diff = 2.1148
#   F279: mean_diff = 2.0351
#   F227: mean_diff = 1.8760
#   F100: mean_diff = 1.8004
#   F148: mean_diff = 1.7614
#   F222: mean_diff = 1.7573
#   F259: mean_diff = 1.6511
#   F202: mean_diff = 1.6480
#
# Class Pair: (1, 26)
#   F131: mean_diff = 2.9680
#   F85: mean_diff = 2.1616
#   F194: mean_diff = 2.0736
#   F222: mean_diff = 1.9329
#   F114: mean_diff = 1.8172
#   F279: mean_diff = 1.7806
#   F100: mean_diff = 1.7469
#   F180: mean_diff = 1.6241
#   F61: mean_diff = 1.6157
#   F259: mean_diff = 1.6080
#
# Class Pair: (1, 27)
#   F131: mean_diff = 3.0689
#   F85: mean_diff = 2.7237
#   F259: mean_diff = 2.5684
#   F23: mean_diff = 2.4368
#   F171: mean_diff = 2.4356
#   F200: mean_diff = 2.4271
#   F202: mean_diff = 2.3798
#   F61: mean_diff = 2.2531
#   F118: mean_diff = 2.0337
#   F235: mean_diff = 2.0120
#
# Class Pair: (2, 3)
#   F278: mean_diff = 1.8153
#   F95: mean_diff = 1.7430
#   F123: mean_diff = 1.6130
#   F125: mean_diff = 1.5544
#   F186: mean_diff = 1.5534
#   F44: mean_diff = 1.4455
#   F98: mean_diff = 1.3987
#   F252: mean_diff = 1.3583
#   F120: mean_diff = 1.3533
#   F283: mean_diff = 1.3159
#
# Class Pair: (2, 4)
#   F125: mean_diff = 1.5599
#   F138: mean_diff = 1.3220
#   F228: mean_diff = 1.2292
#   F278: mean_diff = 1.1784
#   F73: mean_diff = 1.1393
#   F8: mean_diff = 1.1294
#   F55: mean_diff = 1.1079
#   F120: mean_diff = 1.0504
#   F293: mean_diff = 1.0193
#   F150: mean_diff = 1.0137
#
# Class Pair: (2, 5)
#   F125: mean_diff = 2.2890
#   F283: mean_diff = 1.8974
#   F123: mean_diff = 1.8859
#   F270: mean_diff = 1.8852
#   F17: mean_diff = 1.7967
#   F263: mean_diff = 1.7899
#   F38: mean_diff = 1.7780
#   F87: mean_diff = 1.7109
#   F124: mean_diff = 1.7033
#   F272: mean_diff = 1.6983
#
# Class Pair: (2, 6)
#   F182: mean_diff = 2.2595
#   F98: mean_diff = 2.2125
#   F17: mean_diff = 2.0515
#   F59: mean_diff = 2.0510
#   F125: mean_diff = 1.9693
#   F270: mean_diff = 1.9539
#   F218: mean_diff = 1.9469
#   F205: mean_diff = 1.9431
#   F236: mean_diff = 1.9222
#   F75: mean_diff = 1.8760
#
# Class Pair: (2, 7)
#   F239: mean_diff = 1.6244
#   F162: mean_diff = 1.5921
#   F228: mean_diff = 1.5676
#   F125: mean_diff = 1.5270
#   F55: mean_diff = 1.5149
#   F60: mean_diff = 1.4454
#   F197: mean_diff = 1.4156
#   F183: mean_diff = 1.3843
#   F3: mean_diff = 1.2111
#   F98: mean_diff = 1.1950
#
# Class Pair: (2, 8)
#   F55: mean_diff = 1.7935
#   F240: mean_diff = 1.7129
#   F242: mean_diff = 1.6877
#   F125: mean_diff = 1.6754
#   F208: mean_diff = 1.6469
#   F272: mean_diff = 1.5432
#   F256: mean_diff = 1.3912
#   F44: mean_diff = 1.3878
#   F259: mean_diff = 1.3830
#   F193: mean_diff = 1.3633
#
# Class Pair: (2, 9)
#   F59: mean_diff = 2.2291
#   F182: mean_diff = 2.1755
#   F98: mean_diff = 2.1649
#   F125: mean_diff = 2.1422
#   F17: mean_diff = 1.9060
#   F240: mean_diff = 1.8491
#   F186: mean_diff = 1.8160
#   F157: mean_diff = 1.8045
#   F55: mean_diff = 1.7946
#   F270: mean_diff = 1.7861
#
# Class Pair: (2, 10)
#   F228: mean_diff = 1.5210
#   F278: mean_diff = 1.4199
#   F239: mean_diff = 1.2973
#   F69: mean_diff = 1.2809
#   F162: mean_diff = 1.2809
#   F197: mean_diff = 1.2574
#   F60: mean_diff = 1.2533
#   F79: mean_diff = 1.2344
#   F125: mean_diff = 1.1685
#   F75: mean_diff = 1.0964
#
# Class Pair: (2, 11)
#   F297: mean_diff = 2.3281
#   F95: mean_diff = 2.3106
#   F242: mean_diff = 2.1923
#   F279: mean_diff = 2.1526
#   F39: mean_diff = 2.1478
#   F285: mean_diff = 2.1417
#   F112: mean_diff = 2.0735
#   F286: mean_diff = 2.0625
#   F177: mean_diff = 2.0120
#   F5: mean_diff = 1.9948
#
# Class Pair: (2, 12)
#   F278: mean_diff = 1.2232
#   F95: mean_diff = 1.1668
#   F256: mean_diff = 1.1507
#   F123: mean_diff = 1.1455
#   F31: mean_diff = 1.1095
#   F283: mean_diff = 1.0637
#   F125: mean_diff = 1.0211
#   F193: mean_diff = 1.0195
#   F272: mean_diff = 0.9878
#   F242: mean_diff = 0.9875
#
# Class Pair: (2, 13)
#   F278: mean_diff = 1.5439
#   F125: mean_diff = 1.4971
#   F120: mean_diff = 0.9850
#   F256: mean_diff = 0.9611
#   F272: mean_diff = 0.9556
#   F95: mean_diff = 0.9031
#   F123: mean_diff = 0.9019
#   F183: mean_diff = 0.8999
#   F186: mean_diff = 0.8419
#   F69: mean_diff = 0.8366
#
# Class Pair: (2, 14)
#   F125: mean_diff = 2.5701
#   F17: mean_diff = 2.0374
#   F272: mean_diff = 1.9614
#   F38: mean_diff = 1.9239
#   F283: mean_diff = 1.9101
#   F87: mean_diff = 1.9010
#   F270: mean_diff = 1.8892
#   F55: mean_diff = 1.8774
#   F124: mean_diff = 1.8264
#   F123: mean_diff = 1.7595
#
# Class Pair: (2, 15)
#   F125: mean_diff = 2.5027
#   F120: mean_diff = 2.2422
#   F131: mean_diff = 2.1011
#   F279: mean_diff = 2.0920
#   F100: mean_diff = 1.7718
#   F21: mean_diff = 1.7632
#   F214: mean_diff = 1.7136
#   F98: mean_diff = 1.7117
#   F259: mean_diff = 1.6777
#   F293: mean_diff = 1.6019
#
# Class Pair: (2, 16)
#   F125: mean_diff = 2.7960
#   F124: mean_diff = 2.0587
#   F104: mean_diff = 2.0224
#   F120: mean_diff = 2.0080
#   F201: mean_diff = 1.9732
#   F164: mean_diff = 1.9615
#   F50: mean_diff = 1.9497
#   F53: mean_diff = 1.8066
#   F3: mean_diff = 1.7879
#   F172: mean_diff = 1.7603
#
# Class Pair: (2, 17)
#   F17: mean_diff = 2.1375
#   F125: mean_diff = 1.9617
#   F55: mean_diff = 1.9564
#   F270: mean_diff = 1.9483
#   F38: mean_diff = 1.8393
#   F228: mean_diff = 1.8024
#   F98: mean_diff = 1.7835
#   F218: mean_diff = 1.7624
#   F214: mean_diff = 1.7259
#   F87: mean_diff = 1.7027
#
# Class Pair: (2, 18)
#   F228: mean_diff = 1.7934
#   F60: mean_diff = 1.7776
#   F6: mean_diff = 1.5674
#   F125: mean_diff = 1.5042
#   F186: mean_diff = 1.4036
#   F78: mean_diff = 1.3144
#   F272: mean_diff = 1.2756
#   F284: mean_diff = 1.2404
#   F147: mean_diff = 1.2397
#   F123: mean_diff = 1.2350
#
# Class Pair: (2, 19)
#   F278: mean_diff = 1.6294
#   F123: mean_diff = 1.5147
#   F125: mean_diff = 1.4040
#   F98: mean_diff = 1.2873
#   F252: mean_diff = 1.2280
#   F60: mean_diff = 1.2211
#   F239: mean_diff = 1.1398
#   F210: mean_diff = 1.1268
#   F59: mean_diff = 1.1223
#   F228: mean_diff = 1.0897
#
# Class Pair: (2, 20)
#   F278: mean_diff = 1.3436
#   F95: mean_diff = 1.1895
#   F186: mean_diff = 1.1005
#   F256: mean_diff = 1.0951
#   F272: mean_diff = 1.0042
#   F136: mean_diff = 0.9761
#   F293: mean_diff = 0.9674
#   F284: mean_diff = 0.9642
#   F73: mean_diff = 0.9199
#   F8: mean_diff = 0.9140
#
# Class Pair: (2, 21)
#   F55: mean_diff = 1.7499
#   F240: mean_diff = 1.4657
#   F193: mean_diff = 1.3871
#   F30: mean_diff = 1.3808
#   F295: mean_diff = 1.3766
#   F283: mean_diff = 1.3471
#   F95: mean_diff = 1.3442
#   F272: mean_diff = 1.2411
#   F242: mean_diff = 1.2261
#   F37: mean_diff = 1.2000
#
# Class Pair: (2, 22)
#   F279: mean_diff = 2.3287
#   F286: mean_diff = 2.0267
#   F47: mean_diff = 1.9668
#   F39: mean_diff = 1.9492
#   F181: mean_diff = 1.8598
#   F131: mean_diff = 1.7787
#   F11: mean_diff = 1.7409
#   F66: mean_diff = 1.6958
#   F154: mean_diff = 1.6907
#   F240: mean_diff = 1.6781
#
# Class Pair: (2, 23)
#   F125: mean_diff = 1.8308
#   F148: mean_diff = 1.7404
#   F79: mean_diff = 1.6361
#   F120: mean_diff = 1.6315
#   F69: mean_diff = 1.5406
#   F138: mean_diff = 1.5088
#   F201: mean_diff = 1.4238
#   F284: mean_diff = 1.4224
#   F87: mean_diff = 1.4015
#   F95: mean_diff = 1.3717
#
# Class Pair: (2, 24)
#   F278: mean_diff = 1.4540
#   F55: mean_diff = 1.4452
#   F125: mean_diff = 1.4428
#   F293: mean_diff = 1.2975
#   F272: mean_diff = 1.2803
#   F183: mean_diff = 1.1416
#   F44: mean_diff = 1.1270
#   F60: mean_diff = 1.1258
#   F239: mean_diff = 1.0937
#   F193: mean_diff = 1.0575
#
# Class Pair: (2, 25)
#   F278: mean_diff = 1.2533
#   F125: mean_diff = 0.9748
#   F136: mean_diff = 0.9551
#   F60: mean_diff = 0.9355
#   F8: mean_diff = 0.8925
#   F123: mean_diff = 0.8727
#   F272: mean_diff = 0.8719
#   F141: mean_diff = 0.8220
#   F239: mean_diff = 0.8107
#   F256: mean_diff = 0.8064
#
# Class Pair: (2, 26)
#   F125: mean_diff = 1.6942
#   F284: mean_diff = 1.5236
#   F55: mean_diff = 1.4488
#   F272: mean_diff = 1.3933
#   F123: mean_diff = 1.3043
#   F227: mean_diff = 1.2724
#   F186: mean_diff = 1.2515
#   F95: mean_diff = 1.2213
#   F278: mean_diff = 1.2149
#   F159: mean_diff = 1.2115
#
# Class Pair: (2, 27)
#   F292: mean_diff = 2.0801
#   F227: mean_diff = 1.8642
#   F47: mean_diff = 1.8322
#   F118: mean_diff = 1.8314
#   F98: mean_diff = 1.8171
#   F171: mean_diff = 1.7920
#   F125: mean_diff = 1.6026
#   F25: mean_diff = 1.5668
#   F284: mean_diff = 1.5510
#   F228: mean_diff = 1.5496
#
# Class Pair: (3, 4)
#   F262: mean_diff = 1.1888
#   F67: mean_diff = 1.1761
#   F291: mean_diff = 1.1602
#   F98: mean_diff = 1.1271
#   F95: mean_diff = 1.1076
#   F123: mean_diff = 1.0535
#   F169: mean_diff = 1.0492
#   F43: mean_diff = 1.0470
#   F150: mean_diff = 1.0310
#   F22: mean_diff = 1.0266
#
# Class Pair: (3, 5)
#   F299: mean_diff = 1.6632
#   F90: mean_diff = 1.5972
#   F41: mean_diff = 1.5305
#   F265: mean_diff = 1.4552
#   F141: mean_diff = 1.4146
#   F87: mean_diff = 1.4061
#   F249: mean_diff = 1.3779
#   F172: mean_diff = 1.3204
#   F204: mean_diff = 1.3086
#   F292: mean_diff = 1.2990
#
# Class Pair: (3, 6)
#   F182: mean_diff = 2.0292
#   F205: mean_diff = 1.8664
#   F4: mean_diff = 1.7311
#   F83: mean_diff = 1.7250
#   F77: mean_diff = 1.7164
#   F75: mean_diff = 1.7033
#   F218: mean_diff = 1.7029
#   F189: mean_diff = 1.6968
#   F168: mean_diff = 1.6701
#   F278: mean_diff = 1.6015
#
# Class Pair: (3, 7)
#   F44: mean_diff = 1.5582
#   F225: mean_diff = 1.5515
#   F162: mean_diff = 1.5398
#   F167: mean_diff = 1.4701
#   F95: mean_diff = 1.3960
#   F139: mean_diff = 1.3077
#   F228: mean_diff = 1.3057
#   F135: mean_diff = 1.1908
#   F222: mean_diff = 1.1736
#   F79: mean_diff = 1.1670
#
# Class Pair: (3, 8)
#   F113: mean_diff = 1.0800
#   F21: mean_diff = 1.0706
#   F299: mean_diff = 1.0616
#   F77: mean_diff = 1.0546
#   F188: mean_diff = 1.0184
#   F23: mean_diff = 1.0046
#   F55: mean_diff = 0.9879
#   F210: mean_diff = 0.9719
#   F240: mean_diff = 0.9607
#   F53: mean_diff = 0.9314
#
# Class Pair: (3, 9)
#   F182: mean_diff = 1.9451
#   F83: mean_diff = 1.8105
#   F4: mean_diff = 1.7057
#   F189: mean_diff = 1.6700
#   F43: mean_diff = 1.6480
#   F205: mean_diff = 1.6314
#   F249: mean_diff = 1.6240
#   F252: mean_diff = 1.6127
#   F274: mean_diff = 1.6090
#   F278: mean_diff = 1.5914
#
# Class Pair: (3, 10)
#   F265: mean_diff = 1.3919
#   F95: mean_diff = 1.3247
#   F79: mean_diff = 1.2782
#   F228: mean_diff = 1.2591
#   F44: mean_diff = 1.2367
#   F262: mean_diff = 1.2349
#   F162: mean_diff = 1.2286
#   F259: mean_diff = 1.1882
#   F48: mean_diff = 1.1402
#   F99: mean_diff = 1.1234
#
# Class Pair: (3, 11)
#   F112: mean_diff = 2.3914
#   F45: mean_diff = 2.3357
#   F208: mean_diff = 1.9833
#   F285: mean_diff = 1.9147
#   F297: mean_diff = 1.9101
#   F39: mean_diff = 1.8948
#   F106: mean_diff = 1.7933
#   F286: mean_diff = 1.7861
#   F279: mean_diff = 1.7557
#   F25: mean_diff = 1.7083
#
# Class Pair: (3, 12)
#   F127: mean_diff = 0.8416
#   F186: mean_diff = 0.8387
#   F120: mean_diff = 0.8258
#   F210: mean_diff = 0.7826
#   F67: mean_diff = 0.7672
#   F225: mean_diff = 0.7659
#   F251: mean_diff = 0.7563
#   F45: mean_diff = 0.7490
#   F166: mean_diff = 0.7353
#   F112: mean_diff = 0.7214
#
# Class Pair: (3, 13)
#   F68: mean_diff = 0.8454
#   F95: mean_diff = 0.8400
#   F67: mean_diff = 0.8244
#   F154: mean_diff = 0.7679
#   F282: mean_diff = 0.7637
#   F139: mean_diff = 0.7556
#   F23: mean_diff = 0.7418
#   F193: mean_diff = 0.7349
#   F44: mean_diff = 0.7253
#   F64: mean_diff = 0.7229
#
# Class Pair: (3, 14)
#   F299: mean_diff = 1.7429
#   F90: mean_diff = 1.6801
#   F87: mean_diff = 1.5962
#   F41: mean_diff = 1.5375
#   F17: mean_diff = 1.5079
#   F204: mean_diff = 1.4448
#   F141: mean_diff = 1.3592
#   F265: mean_diff = 1.3432
#   F292: mean_diff = 1.3175
#   F67: mean_diff = 1.2822
#
# Class Pair: (3, 15)
#   F131: mean_diff = 2.0462
#   F100: mean_diff = 1.8189
#   F280: mean_diff = 1.6998
#   F279: mean_diff = 1.6950
#   F85: mean_diff = 1.6402
#   F225: mean_diff = 1.6384
#   F204: mean_diff = 1.6324
#   F222: mean_diff = 1.5813
#   F194: mean_diff = 1.3893
#   F262: mean_diff = 1.3555
#
# Class Pair: (3, 16)
#   F44: mean_diff = 2.3628
#   F23: mean_diff = 1.9553
#   F265: mean_diff = 1.9251
#   F291: mean_diff = 1.8968
#   F295: mean_diff = 1.8653
#   F51: mean_diff = 1.8502
#   F247: mean_diff = 1.8056
#   F107: mean_diff = 1.8042
#   F221: mean_diff = 1.8033
#   F50: mean_diff = 1.7530
#
# Class Pair: (3, 17)
#   F252: mean_diff = 1.7095
#   F132: mean_diff = 1.6092
#   F17: mean_diff = 1.6080
#   F228: mean_diff = 1.5405
#   F218: mean_diff = 1.5185
#   F247: mean_diff = 1.4454
#   F21: mean_diff = 1.4421
#   F90: mean_diff = 1.4302
#   F87: mean_diff = 1.3979
#   F265: mean_diff = 1.3943
#
# Class Pair: (3, 18)
#   F228: mean_diff = 1.5315
#   F210: mean_diff = 1.4245
#   F196: mean_diff = 1.4086
#   F4: mean_diff = 1.3759
#   F96: mean_diff = 1.3039
#   F95: mean_diff = 1.2594
#   F262: mean_diff = 1.2572
#   F139: mean_diff = 1.1296
#   F6: mean_diff = 1.1147
#   F287: mean_diff = 1.1049
#
# Class Pair: (3, 19)
#   F44: mean_diff = 0.9849
#   F189: mean_diff = 0.9602
#   F107: mean_diff = 0.9198
#   F90: mean_diff = 0.9191
#   F135: mean_diff = 0.9102
#   F95: mean_diff = 0.8392
#   F228: mean_diff = 0.8278
#   F246: mean_diff = 0.8159
#   F274: mean_diff = 0.7921
#   F193: mean_diff = 0.7904
#
# Class Pair: (3, 20)
#   F67: mean_diff = 1.2415
#   F123: mean_diff = 0.9710
#   F120: mean_diff = 0.9447
#   F208: mean_diff = 0.9067
#   F109: mean_diff = 0.9041
#   F189: mean_diff = 0.8844
#   F225: mean_diff = 0.8333
#   F125: mean_diff = 0.8258
#   F209: mean_diff = 0.8231
#   F252: mean_diff = 0.8084
#
# Class Pair: (3, 21)
#   F210: mean_diff = 1.2607
#   F123: mean_diff = 1.1418
#   F189: mean_diff = 1.1215
#   F143: mean_diff = 1.0989
#   F200: mean_diff = 1.0931
#   F67: mean_diff = 1.0828
#   F291: mean_diff = 1.0821
#   F208: mean_diff = 1.0690
#   F299: mean_diff = 1.0422
#   F97: mean_diff = 1.0300
#
# Class Pair: (3, 22)
#   F41: mean_diff = 2.0402
#   F181: mean_diff = 1.9590
#   F279: mean_diff = 1.9317
#   F45: mean_diff = 1.8750
#   F25: mean_diff = 1.8270
#   F106: mean_diff = 1.7902
#   F287: mean_diff = 1.7566
#   F286: mean_diff = 1.7503
#   F131: mean_diff = 1.7238
#   F39: mean_diff = 1.6962
#
# Class Pair: (3, 23)
#   F265: mean_diff = 2.0906
#   F44: mean_diff = 1.9236
#   F211: mean_diff = 1.8359
#   F148: mean_diff = 1.7354
#   F79: mean_diff = 1.6800
#   F31: mean_diff = 1.5744
#   F241: mean_diff = 1.5613
#   F213: mean_diff = 1.5492
#   F8: mean_diff = 1.5357
#   F215: mean_diff = 1.5077
#
# Class Pair: (3, 24)
#   F23: mean_diff = 1.1467
#   F67: mean_diff = 0.9967
#   F262: mean_diff = 0.9076
#   F95: mean_diff = 0.8786
#   F225: mean_diff = 0.8690
#   F283: mean_diff = 0.8652
#   F299: mean_diff = 0.8434
#   F65: mean_diff = 0.8237
#   F209: mean_diff = 0.7991
#   F287: mean_diff = 0.7965
#
# Class Pair: (3, 25)
#   F67: mean_diff = 1.1383
#   F98: mean_diff = 1.0814
#   F95: mean_diff = 1.0324
#   F225: mean_diff = 1.0114
#   F262: mean_diff = 0.8667
#   F283: mean_diff = 0.8590
#   F2: mean_diff = 0.8008
#   F227: mean_diff = 0.7987
#   F230: mean_diff = 0.7768
#   F186: mean_diff = 0.7590
#
# Class Pair: (3, 26)
#   F210: mean_diff = 0.9889
#   F291: mean_diff = 0.8582
#   F159: mean_diff = 0.8382
#   F21: mean_diff = 0.8367
#   F83: mean_diff = 0.8091
#   F209: mean_diff = 0.8068
#   F252: mean_diff = 0.8061
#   F163: mean_diff = 0.7965
#   F8: mean_diff = 0.7958
#   F112: mean_diff = 0.7948
#
# Class Pair: (3, 27)
#   F23: mean_diff = 1.9573
#   F99: mean_diff = 1.7816
#   F287: mean_diff = 1.7704
#   F292: mean_diff = 1.7331
#   F8: mean_diff = 1.6854
#   F89: mean_diff = 1.6193
#   F235: mean_diff = 1.5113
#   F79: mean_diff = 1.4999
#   F47: mean_diff = 1.4991
#   F265: mean_diff = 1.4431
#
# Class Pair: (4, 5)
#   F270: mean_diff = 1.8999
#   F263: mean_diff = 1.6798
#   F172: mean_diff = 1.6789
#   F283: mean_diff = 1.5326
#   F47: mean_diff = 1.4963
#   F198: mean_diff = 1.4278
#   F150: mean_diff = 1.4194
#   F48: mean_diff = 1.3949
#   F17: mean_diff = 1.3828
#   F90: mean_diff = 1.3811
#
# Class Pair: (4, 6)
#   F182: mean_diff = 2.3191
#   F64: mean_diff = 2.2191
#   F168: mean_diff = 2.1835
#   F270: mean_diff = 1.9685
#   F98: mean_diff = 1.9409
#   F157: mean_diff = 1.9026
#   F14: mean_diff = 1.8727
#   F27: mean_diff = 1.6908
#   F17: mean_diff = 1.6376
#   F218: mean_diff = 1.6297
#
# Class Pair: (4, 7)
#   F178: mean_diff = 1.2202
#   F276: mean_diff = 1.1687
#   F261: mean_diff = 1.0537
#   F237: mean_diff = 1.0242
#   F291: mean_diff = 1.0200
#   F44: mean_diff = 0.9976
#   F162: mean_diff = 0.9862
#   F295: mean_diff = 0.9732
#   F91: mean_diff = 0.9547
#   F98: mean_diff = 0.9234
#
# Class Pair: (4, 8)
#   F213: mean_diff = 1.4615
#   F22: mean_diff = 1.3642
#   F53: mean_diff = 1.3203
#   F270: mean_diff = 1.2539
#   F237: mean_diff = 1.2421
#   F240: mean_diff = 1.1813
#   F242: mean_diff = 1.1739
#   F295: mean_diff = 1.1599
#   F159: mean_diff = 1.1400
#   F291: mean_diff = 1.1204
#
# Class Pair: (4, 9)
#   F182: mean_diff = 2.2350
#   F64: mean_diff = 2.1030
#   F168: mean_diff = 1.9873
#   F98: mean_diff = 1.8933
#   F14: mean_diff = 1.8717
#   F157: mean_diff = 1.8589
#   F270: mean_diff = 1.8008
#   F146: mean_diff = 1.6392
#   F177: mean_diff = 1.6208
#   F80: mean_diff = 1.5913
#
# Class Pair: (4, 10)
#   F174: mean_diff = 0.9712
#   F8: mean_diff = 0.9564
#   F150: mean_diff = 0.9149
#   F89: mean_diff = 0.8946
#   F79: mean_diff = 0.8916
#   F215: mean_diff = 0.8801
#   F159: mean_diff = 0.8629
#   F75: mean_diff = 0.8500
#   F177: mean_diff = 0.8348
#   F237: mean_diff = 0.8137
#
# Class Pair: (4, 11)
#   F297: mean_diff = 2.5831
#   F112: mean_diff = 2.5441
#   F150: mean_diff = 2.3869
#   F286: mean_diff = 2.2959
#   F285: mean_diff = 2.1397
#   F39: mean_diff = 2.1323
#   F29: mean_diff = 2.0901
#   F131: mean_diff = 2.0221
#   F177: mean_diff = 1.9722
#   F279: mean_diff = 1.9719
#
# Class Pair: (4, 12)
#   F280: mean_diff = 1.0546
#   F295: mean_diff = 1.0056
#   F235: mean_diff = 0.9439
#   F130: mean_diff = 0.9436
#   F150: mean_diff = 0.9357
#   F286: mean_diff = 0.9268
#   F29: mean_diff = 0.9135
#   F228: mean_diff = 0.8985
#   F143: mean_diff = 0.8913
#   F213: mean_diff = 0.8793
#
# Class Pair: (4, 13)
#   F43: mean_diff = 0.8836
#   F22: mean_diff = 0.8547
#   F138: mean_diff = 0.8415
#   F295: mean_diff = 0.8056
#   F16: mean_diff = 0.7924
#   F80: mean_diff = 0.7067
#   F176: mean_diff = 0.6930
#   F168: mean_diff = 0.6896
#   F293: mean_diff = 0.6844
#   F265: mean_diff = 0.6601
#
# Class Pair: (4, 14)
#   F270: mean_diff = 1.9038
#   F263: mean_diff = 1.6444
#   F17: mean_diff = 1.6235
#   F172: mean_diff = 1.6104
#   F283: mean_diff = 1.5453
#   F47: mean_diff = 1.5081
#   F124: mean_diff = 1.4962
#   F90: mean_diff = 1.4639
#   F157: mean_diff = 1.4344
#   F292: mean_diff = 1.3943
#
# Class Pair: (4, 15)
#   F131: mean_diff = 2.6393
#   F85: mean_diff = 2.2587
#   F100: mean_diff = 2.1720
#   F194: mean_diff = 2.1050
#   F279: mean_diff = 1.9113
#   F150: mean_diff = 1.8143
#   F133: mean_diff = 1.7587
#   F80: mean_diff = 1.6738
#   F21: mean_diff = 1.6015
#   F157: mean_diff = 1.5723
#
# Class Pair: (4, 16)
#   F50: mean_diff = 2.1743
#   F198: mean_diff = 2.0692
#   F250: mean_diff = 2.0467
#   F150: mean_diff = 1.9371
#   F164: mean_diff = 1.9090
#   F172: mean_diff = 1.9074
#   F53: mean_diff = 1.8420
#   F51: mean_diff = 1.8126
#   F44: mean_diff = 1.8022
#   F148: mean_diff = 1.7806
#
# Class Pair: (4, 17)
#   F270: mean_diff = 1.9630
#   F17: mean_diff = 1.7236
#   F132: mean_diff = 1.5895
#   F98: mean_diff = 1.5119
#   F112: mean_diff = 1.4583
#   F251: mean_diff = 1.4493
#   F218: mean_diff = 1.4453
#   F161: mean_diff = 1.4114
#   F14: mean_diff = 1.3862
#   F216: mean_diff = 1.3643
#
# Class Pair: (4, 18)
#   F64: mean_diff = 1.3356
#   F6: mean_diff = 1.3254
#   F295: mean_diff = 1.2191
#   F50: mean_diff = 1.1390
#   F159: mean_diff = 1.1075
#   F157: mean_diff = 1.0975
#   F255: mean_diff = 1.0603
#   F93: mean_diff = 1.0041
#   F177: mean_diff = 0.9937
#   F147: mean_diff = 0.9929
#
# Class Pair: (4, 19)
#   F150: mean_diff = 1.0351
#   F98: mean_diff = 1.0157
#   F43: mean_diff = 0.9858
#   F0: mean_diff = 0.9739
#   F123: mean_diff = 0.9552
#   F194: mean_diff = 0.9480
#   F177: mean_diff = 0.9165
#   F67: mean_diff = 0.8899
#   F200: mean_diff = 0.8708
#   F77: mean_diff = 0.8551
#
# Class Pair: (4, 20)
#   F138: mean_diff = 0.9997
#   F130: mean_diff = 0.9419
#   F22: mean_diff = 0.8548
#   F280: mean_diff = 0.8425
#   F125: mean_diff = 0.8314
#   F228: mean_diff = 0.8201
#   F169: mean_diff = 0.7930
#   F295: mean_diff = 0.7256
#   F222: mean_diff = 0.7231
#   F162: mean_diff = 0.7215
#
# Class Pair: (4, 21)
#   F295: mean_diff = 1.5755
#   F143: mean_diff = 1.2826
#   F198: mean_diff = 1.2648
#   F175: mean_diff = 1.1962
#   F159: mean_diff = 1.1757
#   F85: mean_diff = 1.1727
#   F16: mean_diff = 1.1505
#   F0: mean_diff = 1.0591
#   F37: mean_diff = 1.0507
#   F30: mean_diff = 1.0481
#
# Class Pair: (4, 22)
#   F131: mean_diff = 2.3169
#   F286: mean_diff = 2.2602
#   F85: mean_diff = 2.1995
#   F279: mean_diff = 2.1480
#   F39: mean_diff = 1.9337
#   F47: mean_diff = 1.9105
#   F154: mean_diff = 1.8938
#   F181: mean_diff = 1.8698
#   F150: mean_diff = 1.8211
#   F110: mean_diff = 1.6962
#
# Class Pair: (4, 23)
#   F148: mean_diff = 1.7817
#   F73: mean_diff = 1.7640
#   F293: mean_diff = 1.6905
#   F215: mean_diff = 1.6463
#   F150: mean_diff = 1.6261
#   F250: mean_diff = 1.5400
#   F8: mean_diff = 1.5029
#   F198: mean_diff = 1.4618
#   F211: mean_diff = 1.4375
#   F81: mean_diff = 1.3869
#
# Class Pair: (4, 24)
#   F290: mean_diff = 0.9179
#   F110: mean_diff = 0.8998
#   F295: mean_diff = 0.8833
#   F213: mean_diff = 0.8407
#   F112: mean_diff = 0.6990
#   F42: mean_diff = 0.6967
#   F200: mean_diff = 0.6923
#   F272: mean_diff = 0.6808
#   F154: mean_diff = 0.6775
#   F43: mean_diff = 0.6770
#
# Class Pair: (4, 25)
#   F295: mean_diff = 0.9254
#   F130: mean_diff = 0.8461
#   F43: mean_diff = 0.7618
#   F191: mean_diff = 0.7413
#   F280: mean_diff = 0.7235
#   F107: mean_diff = 0.7211
#   F64: mean_diff = 0.6398
#   F168: mean_diff = 0.6337
#   F162: mean_diff = 0.6193
#   F291: mean_diff = 0.6028
#
# Class Pair: (4, 26)
#   F159: mean_diff = 1.2438
#   F284: mean_diff = 1.0851
#   F270: mean_diff = 1.0563
#   F262: mean_diff = 1.0202
#   F295: mean_diff = 1.0117
#   F112: mean_diff = 0.9475
#   F110: mean_diff = 0.9249
#   F227: mean_diff = 0.8960
#   F91: mean_diff = 0.8777
#   F50: mean_diff = 0.8714
#
# Class Pair: (4, 27)
#   F292: mean_diff = 1.8099
#   F47: mean_diff = 1.7759
#   F8: mean_diff = 1.6526
#   F89: mean_diff = 1.5922
#   F98: mean_diff = 1.5455
#   F227: mean_diff = 1.4879
#   F14: mean_diff = 1.4808
#   F112: mean_diff = 1.4600
#   F176: mean_diff = 1.4507
#   F81: mean_diff = 1.3725
#
# Class Pair: (5, 6)
#   F134: mean_diff = 1.5378
#   F113: mean_diff = 1.4882
#   F116: mean_diff = 1.4763
#   F43: mean_diff = 1.3726
#   F64: mean_diff = 1.3690
#   F10: mean_diff = 1.3630
#   F274: mean_diff = 1.3534
#   F168: mean_diff = 1.3433
#   F77: mean_diff = 1.2274
#   F269: mean_diff = 1.2212
#
# Class Pair: (5, 7)
#   F216: mean_diff = 1.6006
#   F283: mean_diff = 1.5530
#   F46: mean_diff = 1.5361
#   F99: mean_diff = 1.5316
#   F27: mean_diff = 1.4989
#   F263: mean_diff = 1.4809
#   F88: mean_diff = 1.4711
#   F270: mean_diff = 1.4479
#   F48: mean_diff = 1.4408
#   F299: mean_diff = 1.4249
#
# Class Pair: (5, 8)
#   F24: mean_diff = 1.6613
#   F257: mean_diff = 1.6305
#   F132: mean_diff = 1.6007
#   F249: mean_diff = 1.5788
#   F61: mean_diff = 1.5611
#   F111: mean_diff = 1.5222
#   F86: mean_diff = 1.5151
#   F20: mean_diff = 1.5071
#   F265: mean_diff = 1.5051
#   F234: mean_diff = 1.4738
#
# Class Pair: (5, 9)
#   F113: mean_diff = 1.5895
#   F215: mean_diff = 1.5244
#   F43: mean_diff = 1.4438
#   F274: mean_diff = 1.4116
#   F134: mean_diff = 1.3959
#   F116: mean_diff = 1.3854
#   F48: mean_diff = 1.3549
#   F10: mean_diff = 1.3193
#   F64: mean_diff = 1.2529
#   F269: mean_diff = 1.2393
#
# Class Pair: (5, 10)
#   F48: mean_diff = 1.9077
#   F99: mean_diff = 1.6311
#   F88: mean_diff = 1.6047
#   F263: mean_diff = 1.5835
#   F231: mean_diff = 1.5649
#   F283: mean_diff = 1.4814
#   F17: mean_diff = 1.4794
#   F232: mean_diff = 1.4664
#   F290: mean_diff = 1.3435
#   F10: mean_diff = 1.2620
#
# Class Pair: (5, 11)
#   F71: mean_diff = 2.7008
#   F297: mean_diff = 2.0994
#   F111: mean_diff = 2.0726
#   F106: mean_diff = 1.9972
#   F147: mean_diff = 1.9855
#   F29: mean_diff = 1.9405
#   F208: mean_diff = 1.9367
#   F45: mean_diff = 1.9259
#   F25: mean_diff = 1.9254
#   F54: mean_diff = 1.9036
#
# Class Pair: (5, 12)
#   F172: mean_diff = 1.4960
#   F87: mean_diff = 1.4239
#   F141: mean_diff = 1.4157
#   F71: mean_diff = 1.3651
#   F270: mean_diff = 1.3511
#   F86: mean_diff = 1.3462
#   F90: mean_diff = 1.3295
#   F17: mean_diff = 1.2941
#   F249: mean_diff = 1.2927
#   F263: mean_diff = 1.2902
#
# Class Pair: (5, 13)
#   F172: mean_diff = 1.7450
#   F17: mean_diff = 1.6284
#   F270: mean_diff = 1.6162
#   F263: mean_diff = 1.5729
#   F87: mean_diff = 1.5225
#   F230: mean_diff = 1.3246
#   F5: mean_diff = 1.3106
#   F124: mean_diff = 1.2804
#   F283: mean_diff = 1.2578
#   F48: mean_diff = 1.2541
#
# Class Pair: (5, 14)
#   F140: mean_diff = 0.6054
#   F105: mean_diff = 0.4548
#   F279: mean_diff = 0.4532
#   F86: mean_diff = 0.3797
#   F70: mean_diff = 0.3596
#   F7: mean_diff = 0.3557
#   F103: mean_diff = 0.3420
#   F55: mean_diff = 0.3320
#   F248: mean_diff = 0.3315
#   F249: mean_diff = 0.3290
#
# Class Pair: (5, 15)
#   F133: mean_diff = 2.2397
#   F194: mean_diff = 2.0059
#   F90: mean_diff = 2.0024
#   F21: mean_diff = 1.9879
#   F111: mean_diff = 1.9233
#   F182: mean_diff = 1.8403
#   F222: mean_diff = 1.8214
#   F46: mean_diff = 1.7933
#   F101: mean_diff = 1.7599
#   F71: mean_diff = 1.6798
#
# Class Pair: (5, 16)
#   F295: mean_diff = 2.1098
#   F272: mean_diff = 1.7789
#   F194: mean_diff = 1.6321
#   F44: mean_diff = 1.5575
#   F74: mean_diff = 1.5437
#   F57: mean_diff = 1.5247
#   F88: mean_diff = 1.4922
#   F164: mean_diff = 1.4109
#   F221: mean_diff = 1.4041
#   F34: mean_diff = 1.4010
#
# Class Pair: (5, 17)
#   F69: mean_diff = 1.1447
#   F50: mean_diff = 1.1124
#   F116: mean_diff = 1.0299
#   F140: mean_diff = 0.8892
#   F252: mean_diff = 0.8843
#   F99: mean_diff = 0.8280
#   F89: mean_diff = 0.8056
#   F187: mean_diff = 0.7965
#   F101: mean_diff = 0.7816
#   F257: mean_diff = 0.7790
#
# Class Pair: (5, 18)
#   F231: mean_diff = 1.6803
#   F48: mean_diff = 1.6474
#   F134: mean_diff = 1.5065
#   F10: mean_diff = 1.4748
#   F114: mean_diff = 1.4620
#   F141: mean_diff = 1.4540
#   F263: mean_diff = 1.4336
#   F299: mean_diff = 1.3684
#   F28: mean_diff = 1.3531
#   F111: mean_diff = 1.3337
#
# Class Pair: (5, 19)
#   F41: mean_diff = 1.6460
#   F88: mean_diff = 1.5409
#   F17: mean_diff = 1.5071
#   F172: mean_diff = 1.4584
#   F292: mean_diff = 1.3487
#   F231: mean_diff = 1.3460
#   F232: mean_diff = 1.3377
#   F299: mean_diff = 1.2807
#   F26: mean_diff = 1.2666
#   F27: mean_diff = 1.2595
#
# Class Pair: (5, 20)
#   F270: mean_diff = 1.6537
#   F230: mean_diff = 1.6223
#   F125: mean_diff = 1.5605
#   F172: mean_diff = 1.5080
#   F263: mean_diff = 1.4561
#   F71: mean_diff = 1.4289
#   F87: mean_diff = 1.4237
#   F90: mean_diff = 1.3836
#   F124: mean_diff = 1.3595
#   F47: mean_diff = 1.3309
#
# Class Pair: (5, 21)
#   F263: mean_diff = 1.5425
#   F234: mean_diff = 1.5135
#   F86: mean_diff = 1.4910
#   F123: mean_diff = 1.4147
#   F46: mean_diff = 1.4050
#   F90: mean_diff = 1.4031
#   F101: mean_diff = 1.3890
#   F133: mean_diff = 1.3773
#   F270: mean_diff = 1.3532
#   F71: mean_diff = 1.3080
#
# Class Pair: (5, 22)
#   F111: mean_diff = 2.3628
#   F181: mean_diff = 2.2459
#   F25: mean_diff = 2.0441
#   F71: mean_diff = 2.0397
#   F106: mean_diff = 1.9942
#   F133: mean_diff = 1.9498
#   F19: mean_diff = 1.9337
#   F255: mean_diff = 1.8481
#   F270: mean_diff = 1.7764
#   F142: mean_diff = 1.7713
#
# Class Pair: (5, 23)
#   F211: mean_diff = 1.7945
#   F245: mean_diff = 1.7701
#   F218: mean_diff = 1.7612
#   F116: mean_diff = 1.6957
#   F232: mean_diff = 1.6864
#   F240: mean_diff = 1.6077
#   F88: mean_diff = 1.5262
#   F272: mean_diff = 1.5093
#   F31: mean_diff = 1.4655
#   F85: mean_diff = 1.4471
#
# Class Pair: (5, 24)
#   F270: mean_diff = 1.5343
#   F90: mean_diff = 1.4862
#   F249: mean_diff = 1.4796
#   F283: mean_diff = 1.4467
#   F234: mean_diff = 1.4084
#   F111: mean_diff = 1.3785
#   F230: mean_diff = 1.3726
#   F172: mean_diff = 1.3684
#   F263: mean_diff = 1.3590
#   F86: mean_diff = 1.2920
#
# Class Pair: (5, 25)
#   F172: mean_diff = 1.7084
#   F230: mean_diff = 1.6671
#   F270: mean_diff = 1.6269
#   F17: mean_diff = 1.5693
#   F47: mean_diff = 1.5278
#   F263: mean_diff = 1.4754
#   F5: mean_diff = 1.4588
#   F87: mean_diff = 1.4573
#   F283: mean_diff = 1.4405
#   F90: mean_diff = 1.3964
#
# Class Pair: (5, 26)
#   F141: mean_diff = 1.2043
#   F5: mean_diff = 1.2009
#   F90: mean_diff = 1.1856
#   F99: mean_diff = 1.1779
#   F234: mean_diff = 1.1707
#   F111: mean_diff = 1.1611
#   F249: mean_diff = 1.1484
#   F46: mean_diff = 1.1400
#   F227: mean_diff = 1.1399
#   F243: mean_diff = 1.1047
#
# Class Pair: (5, 27)
#   F99: mean_diff = 2.2893
#   F227: mean_diff = 1.7317
#   F118: mean_diff = 1.6955
#   F48: mean_diff = 1.5714
#   F111: mean_diff = 1.5208
#   F46: mean_diff = 1.5176
#   F222: mean_diff = 1.4759
#   F287: mean_diff = 1.4208
#   F71: mean_diff = 1.3521
#   F5: mean_diff = 1.2890
#
# Class Pair: (6, 7)
#   F238: mean_diff = 2.1788
#   F27: mean_diff = 2.1699
#   F218: mean_diff = 2.0156
#   F239: mean_diff = 1.9129
#   F182: mean_diff = 1.8953
#   F269: mean_diff = 1.8913
#   F77: mean_diff = 1.8871
#   F216: mean_diff = 1.8840
#   F261: mean_diff = 1.8710
#   F46: mean_diff = 1.8506
#
# Class Pair: (6, 8)
#   F205: mean_diff = 2.2973
#   F182: mean_diff = 2.2112
#   F189: mean_diff = 1.9262
#   F76: mean_diff = 1.8640
#   F132: mean_diff = 1.8591
#   F61: mean_diff = 1.8396
#   F274: mean_diff = 1.8047
#   F249: mean_diff = 1.7938
#   F238: mean_diff = 1.7612
#   F117: mean_diff = 1.7544
#
# Class Pair: (6, 9)
#   F291: mean_diff = 0.4891
#   F245: mean_diff = 0.4831
#   F260: mean_diff = 0.4793
#   F256: mean_diff = 0.4357
#   F211: mean_diff = 0.4287
#   F204: mean_diff = 0.4280
#   F175: mean_diff = 0.4225
#   F177: mean_diff = 0.3988
#   F158: mean_diff = 0.3825
#   F27: mean_diff = 0.3757
#
# Class Pair: (6, 10)
#   F64: mean_diff = 1.8677
#   F27: mean_diff = 1.8085
#   F88: mean_diff = 1.7759
#   F157: mean_diff = 1.7347
#   F17: mean_diff = 1.7341
#   F218: mean_diff = 1.7053
#   F135: mean_diff = 1.6436
#   F144: mean_diff = 1.6374
#   F182: mean_diff = 1.6286
#   F239: mean_diff = 1.5858
#
# Class Pair: (6, 11)
#   F297: mean_diff = 2.6198
#   F205: mean_diff = 2.2752
#   F274: mean_diff = 2.1669
#   F54: mean_diff = 2.1519
#   F279: mean_diff = 2.0938
#   F71: mean_diff = 2.0468
#   F97: mean_diff = 2.0302
#   F29: mean_diff = 2.0220
#   F45: mean_diff = 1.9938
#   F181: mean_diff = 1.9934
#
# Class Pair: (6, 12)
#   F59: mean_diff = 1.8504
#   F182: mean_diff = 1.8451
#   F205: mean_diff = 1.8418
#   F218: mean_diff = 1.7648
#   F75: mean_diff = 1.7237
#   F274: mean_diff = 1.6139
#   F168: mean_diff = 1.6110
#   F146: mean_diff = 1.5508
#   F17: mean_diff = 1.5489
#   F46: mean_diff = 1.5199
#
# Class Pair: (6, 13)
#   F64: mean_diff = 2.1595
#   F182: mean_diff = 1.9124
#   F17: mean_diff = 1.8831
#   F205: mean_diff = 1.7234
#   F218: mean_diff = 1.7218
#   F270: mean_diff = 1.6848
#   F59: mean_diff = 1.6842
#   F157: mean_diff = 1.5958
#   F83: mean_diff = 1.5620
#   F14: mean_diff = 1.5429
#
# Class Pair: (6, 14)
#   F274: mean_diff = 1.6671
#   F43: mean_diff = 1.4919
#   F264: mean_diff = 1.4882
#   F116: mean_diff = 1.4761
#   F64: mean_diff = 1.4502
#   F168: mean_diff = 1.4201
#   F103: mean_diff = 1.3899
#   F49: mean_diff = 1.3245
#   F113: mean_diff = 1.3157
#   F92: mean_diff = 1.3154
#
# Class Pair: (6, 15)
#   F182: mean_diff = 2.8244
#   F205: mean_diff = 2.6387
#   F75: mean_diff = 2.3971
#   F4: mean_diff = 2.1993
#   F46: mean_diff = 2.1078
#   F279: mean_diff = 2.0331
#   F133: mean_diff = 1.9955
#   F90: mean_diff = 1.9242
#   F154: mean_diff = 1.9042
#   F238: mean_diff = 1.8306
#
# Class Pair: (6, 16)
#   F64: mean_diff = 2.5175
#   F295: mean_diff = 2.4112
#   F74: mean_diff = 2.2322
#   F43: mean_diff = 2.2140
#   F205: mean_diff = 2.1291
#   F10: mean_diff = 2.0038
#   F4: mean_diff = 1.9543
#   F238: mean_diff = 1.9021
#   F75: mean_diff = 1.8929
#   F168: mean_diff = 1.8828
#
# Class Pair: (6, 17)
#   F274: mean_diff = 1.2618
#   F96: mean_diff = 1.2193
#   F187: mean_diff = 1.2110
#   F182: mean_diff = 1.2040
#   F135: mean_diff = 1.1802
#   F253: mean_diff = 1.1778
#   F28: mean_diff = 1.1595
#   F50: mean_diff = 1.1507
#   F205: mean_diff = 1.1250
#   F168: mean_diff = 1.1231
#
# Class Pair: (6, 18)
#   F182: mean_diff = 1.7397
#   F238: mean_diff = 1.3983
#   F88: mean_diff = 1.3525
#   F72: mean_diff = 1.3457
#   F168: mean_diff = 1.3260
#   F240: mean_diff = 1.3168
#   F14: mean_diff = 1.2741
#   F76: mean_diff = 1.2257
#   F17: mean_diff = 1.2112
#   F117: mean_diff = 1.2069
#
# Class Pair: (6, 19)
#   F27: mean_diff = 1.9306
#   F77: mean_diff = 1.9114
#   F64: mean_diff = 1.7973
#   F168: mean_diff = 1.7678
#   F17: mean_diff = 1.7619
#   F210: mean_diff = 1.7285
#   F144: mean_diff = 1.7234
#   F75: mean_diff = 1.7215
#   F218: mean_diff = 1.7145
#   F88: mean_diff = 1.7122
#
# Class Pair: (6, 20)
#   F59: mean_diff = 2.0009
#   F182: mean_diff = 1.9593
#   F205: mean_diff = 1.9000
#   F64: mean_diff = 1.7601
#   F270: mean_diff = 1.7224
#   F168: mean_diff = 1.7073
#   F157: mean_diff = 1.6385
#   F162: mean_diff = 1.6094
#   F14: mean_diff = 1.5933
#   F218: mean_diff = 1.5726
#
# Class Pair: (6, 21)
#   F182: mean_diff = 2.0564
#   F59: mean_diff = 2.0492
#   F205: mean_diff = 1.9903
#   F144: mean_diff = 1.9739
#   F97: mean_diff = 1.8609
#   F122: mean_diff = 1.8113
#   F238: mean_diff = 1.7925
#   F27: mean_diff = 1.7339
#   F64: mean_diff = 1.7244
#   F46: mean_diff = 1.7195
#
# Class Pair: (6, 22)
#   F205: mean_diff = 2.6430
#   F75: mean_diff = 2.5795
#   F181: mean_diff = 2.5567
#   F182: mean_diff = 2.5218
#   F279: mean_diff = 2.2698
#   F4: mean_diff = 2.2541
#   F154: mean_diff = 2.2394
#   F111: mean_diff = 2.0904
#   F83: mean_diff = 2.0792
#   F76: mean_diff = 2.0350
#
# Class Pair: (6, 23)
#   F211: mean_diff = 2.4240
#   F218: mean_diff = 2.3664
#   F64: mean_diff = 2.1948
#   F144: mean_diff = 1.9799
#   F215: mean_diff = 1.9736
#   F240: mean_diff = 1.9326
#   F245: mean_diff = 1.9134
#   F182: mean_diff = 1.7670
#   F79: mean_diff = 1.7312
#   F76: mean_diff = 1.7002
#
# Class Pair: (6, 24)
#   F182: mean_diff = 2.2058
#   F205: mean_diff = 2.0346
#   F249: mean_diff = 1.6946
#   F64: mean_diff = 1.6839
#   F144: mean_diff = 1.6444
#   F97: mean_diff = 1.6061
#   F270: mean_diff = 1.6030
#   F76: mean_diff = 1.5984
#   F59: mean_diff = 1.5893
#   F157: mean_diff = 1.5156
#
# Class Pair: (6, 25)
#   F182: mean_diff = 2.0342
#   F98: mean_diff = 1.8952
#   F59: mean_diff = 1.8313
#   F17: mean_diff = 1.8241
#   F218: mean_diff = 1.7618
#   F14: mean_diff = 1.7134
#   F157: mean_diff = 1.7095
#   F270: mean_diff = 1.6955
#   F75: mean_diff = 1.6176
#   F64: mean_diff = 1.5793
#
# Class Pair: (6, 26)
#   F168: mean_diff = 2.2269
#   F274: mean_diff = 1.7868
#   F205: mean_diff = 1.7851
#   F64: mean_diff = 1.5896
#   F122: mean_diff = 1.5794
#   F182: mean_diff = 1.5789
#   F59: mean_diff = 1.5652
#   F75: mean_diff = 1.5550
#   F76: mean_diff = 1.5337
#   F46: mean_diff = 1.4545
#
# Class Pair: (6, 27)
#   F274: mean_diff = 1.9986
# ...
#   F51: mean_diff = 1.8780
#   F244: mean_diff = 1.8616
#   F74: mean_diff = 1.8323
#   F112: mean_diff = 1.7673
#   F53: mean_diff = 1.7056
#
# Class Pair: (17, 18)
#   F78: mean_diff = 1.6259
#   F161: mean_diff = 1.6047
#   F187: mean_diff = 1.5473
#   F231: mean_diff = 1.5449
#   F1: mean_diff = 1.3830
#   F96: mean_diff = 1.3828
#   F53: mean_diff = 1.3624
#   F28: mean_diff = 1.3495
#   F71: mean_diff = 1.3452
#   F141: mean_diff = 1.3150
#
# Class Pair: (17, 19)
#   F17: mean_diff = 1.8479
#   F88: mean_diff = 1.5956
#   F252: mean_diff = 1.5792
#   F55: mean_diff = 1.5530
#   F218: mean_diff = 1.5300
#   F77: mean_diff = 1.4591
#   F247: mean_diff = 1.4526
#   F76: mean_diff = 1.3723
#   F41: mean_diff = 1.3580
#   F210: mean_diff = 1.3460
#
# Class Pair: (17, 20)
#   F270: mean_diff = 1.7168
#   F17: mean_diff = 1.6198
#   F89: mean_diff = 1.4667
#   F71: mean_diff = 1.4562
#   F87: mean_diff = 1.4155
#   F230: mean_diff = 1.3978
#   F228: mean_diff = 1.3933
#   F218: mean_diff = 1.3882
#   F251: mean_diff = 1.3574
#   F38: mean_diff = 1.2740
#
# Class Pair: (17, 21)
#   F122: mean_diff = 1.5438
#   F234: mean_diff = 1.5277
#   F89: mean_diff = 1.4588
#   F133: mean_diff = 1.4545
#   F270: mean_diff = 1.4163
#   F21: mean_diff = 1.3451
#   F71: mean_diff = 1.3353
#   F175: mean_diff = 1.3198
#   F146: mean_diff = 1.3160
#   F59: mean_diff = 1.3144
#
# Class Pair: (17, 22)
#   F181: mean_diff = 2.2602
#   F111: mean_diff = 2.2594
#   F25: mean_diff = 2.1537
#   F71: mean_diff = 2.0670
#   F133: mean_diff = 2.0270
#   F75: mean_diff = 1.9293
#   F89: mean_diff = 1.9276
#   F255: mean_diff = 1.9144
#   F106: mean_diff = 1.8673
#   F270: mean_diff = 1.8394
#
# Class Pair: (17, 23)
#   F211: mean_diff = 2.2053
#   F218: mean_diff = 2.1819
#   F245: mean_diff = 1.9377
#   F285: mean_diff = 1.6950
#   F17: mean_diff = 1.6710
#   F240: mean_diff = 1.6105
#   F88: mean_diff = 1.5809
#   F32: mean_diff = 1.4895
#   F107: mean_diff = 1.4830
#   F179: mean_diff = 1.4714
#
# Class Pair: (17, 24)
#   F270: mean_diff = 1.5974
#   F17: mean_diff = 1.4977
#   F234: mean_diff = 1.4226
#   F132: mean_diff = 1.4092
#   F214: mean_diff = 1.3954
#   F216: mean_diff = 1.3892
#   F76: mean_diff = 1.3552
#   F117: mean_diff = 1.3489
#   F251: mean_diff = 1.3447
#   F218: mean_diff = 1.3271
#
# Class Pair: (17, 25)
#   F17: mean_diff = 1.9101
#   F270: mean_diff = 1.6900
#   F218: mean_diff = 1.5773
#   F98: mean_diff = 1.4662
#   F87: mean_diff = 1.4491
#   F38: mean_diff = 1.4426
#   F230: mean_diff = 1.4426
#   F214: mean_diff = 1.4051
#   F47: mean_diff = 1.3088
#   F55: mean_diff = 1.2389
#
# Class Pair: (17, 26)
#   F122: mean_diff = 1.3119
#   F76: mean_diff = 1.2905
#   F214: mean_diff = 1.2827
#   F132: mean_diff = 1.2660
#   F218: mean_diff = 1.1928
#   F234: mean_diff = 1.1849
#   F161: mean_diff = 1.1224
#   F277: mean_diff = 1.1161
#   F243: mean_diff = 1.1142
#   F168: mean_diff = 1.1038
#
# Class Pair: (17, 27)
#   F118: mean_diff = 1.6607
#   F171: mean_diff = 1.6040
#   F218: mean_diff = 1.5403
#   F99: mean_diff = 1.4613
#   F227: mean_diff = 1.4597
#   F111: mean_diff = 1.4174
#   F71: mean_diff = 1.3794
#   F76: mean_diff = 1.2868
#   F46: mean_diff = 1.2289
#   F245: mean_diff = 1.2275
#
# Class Pair: (18, 19)
#   F210: mean_diff = 1.6484
#   F254: mean_diff = 1.4576
#   F6: mean_diff = 1.3232
#   F96: mean_diff = 1.1805
#   F276: mean_diff = 1.1525
#   F135: mean_diff = 1.1015
#   F194: mean_diff = 1.0478
#   F200: mean_diff = 1.0241
#   F65: mean_diff = 1.0093
#   F261: mean_diff = 1.0074
#
# Class Pair: (18, 20)
#   F228: mean_diff = 1.3843
#   F222: mean_diff = 1.3180
#   F6: mean_diff = 1.3014
#   F162: mean_diff = 1.1875
#   F254: mean_diff = 1.1856
#   F96: mean_diff = 1.1733
#   F294: mean_diff = 1.1653
#   F159: mean_diff = 1.1496
#   F196: mean_diff = 1.1243
#   F4: mean_diff = 1.1039
#
# Class Pair: (18, 21)
#   F143: mean_diff = 1.7712
#   F147: mean_diff = 1.5089
#   F196: mean_diff = 1.3781
#   F6: mean_diff = 1.3663
#   F60: mean_diff = 1.2972
#   F96: mean_diff = 1.2856
#   F162: mean_diff = 1.2337
#   F165: mean_diff = 1.1946
#   F254: mean_diff = 1.1387
#   F240: mean_diff = 1.1254
#
# Class Pair: (18, 22)
#   F279: mean_diff = 2.2713
#   F131: mean_diff = 2.1318
#   F39: mean_diff = 2.0315
#   F4: mean_diff = 1.8989
#   F85: mean_diff = 1.8686
#   F215: mean_diff = 1.8591
#   F147: mean_diff = 1.8335
#   F25: mean_diff = 1.8319
#   F255: mean_diff = 1.8177
#   F196: mean_diff = 1.7749
#
# Class Pair: (18, 23)
#   F215: mean_diff = 1.8763
#   F211: mean_diff = 1.7434
#   F254: mean_diff = 1.7398
#   F44: mean_diff = 1.6666
#   F148: mean_diff = 1.6548
#   F165: mean_diff = 1.5987
#   F51: mean_diff = 1.5546
#   F147: mean_diff = 1.4276
#   F31: mean_diff = 1.4139
#   F259: mean_diff = 1.3659
#
# Class Pair: (18, 24)
#   F196: mean_diff = 1.1849
#   F205: mean_diff = 1.0921
#   F149: mean_diff = 1.0523
#   F255: mean_diff = 1.0502
#   F6: mean_diff = 1.0432
#   F96: mean_diff = 1.0002
#   F93: mean_diff = 0.9825
#   F114: mean_diff = 0.9687
#   F187: mean_diff = 0.9252
#   F293: mean_diff = 0.8901
#
# Class Pair: (18, 25)
#   F6: mean_diff = 1.2333
#   F228: mean_diff = 1.1256
#   F162: mean_diff = 1.0853
#   F4: mean_diff = 1.0833
#   F254: mean_diff = 1.0678
#   F210: mean_diff = 1.0547
#   F78: mean_diff = 1.0249
#   F96: mean_diff = 0.9885
#   F159: mean_diff = 0.9787
#   F294: mean_diff = 0.9547
#
# Class Pair: (18, 26)
#   F96: mean_diff = 1.3323
#   F196: mean_diff = 1.1837
#   F254: mean_diff = 1.1687
#   F1: mean_diff = 1.1143
#   F60: mean_diff = 1.0935
#   F262: mean_diff = 1.0886
#   F231: mean_diff = 1.0153
#   F139: mean_diff = 0.9887
#   F261: mean_diff = 0.9529
#   F187: mean_diff = 0.9524
#
# Class Pair: (18, 27)
#   F207: mean_diff = 1.6034
#   F47: mean_diff = 1.4491
#   F60: mean_diff = 1.4460
#   F292: mean_diff = 1.4276
#   F227: mean_diff = 1.4109
#   F231: mean_diff = 1.3819
#   F135: mean_diff = 1.3732
#   F259: mean_diff = 1.3628
#   F202: mean_diff = 1.3279
#   F99: mean_diff = 1.2905
#
# Class Pair: (19, 20)
#   F59: mean_diff = 1.0722
#   F79: mean_diff = 0.9697
#   F67: mean_diff = 0.9553
#   F268: mean_diff = 0.8848
#   F123: mean_diff = 0.8727
#   F210: mean_diff = 0.8655
#   F209: mean_diff = 0.8552
#   F212: mean_diff = 0.8496
#   F170: mean_diff = 0.8492
#   F107: mean_diff = 0.8404
#
# Class Pair: (19, 21)
#   F200: mean_diff = 1.5087
#   F210: mean_diff = 1.4847
#   F55: mean_diff = 1.3465
#   F107: mean_diff = 1.1261
#   F59: mean_diff = 1.1205
#   F101: mean_diff = 1.1135
#   F240: mean_diff = 1.0949
#   F223: mean_diff = 1.0926
#   F268: mean_diff = 1.0866
#   F239: mean_diff = 1.0724
#
# Class Pair: (19, 22)
#   F279: mean_diff = 2.1652
#   F41: mean_diff = 2.1557
#   F286: mean_diff = 1.9487
#   F39: mean_diff = 1.9406
#   F131: mean_diff = 1.8963
#   F85: mean_diff = 1.8128
#   F25: mean_diff = 1.6993
#   F210: mean_diff = 1.6318
#   F66: mean_diff = 1.6013
#   F181: mean_diff = 1.5825
#
# Class Pair: (19, 23)
#   F148: mean_diff = 1.5647
#   F31: mean_diff = 1.4965
#   F241: mean_diff = 1.4226
#   F265: mean_diff = 1.3251
#   F211: mean_diff = 1.2359
#   F116: mean_diff = 1.1968
#   F213: mean_diff = 1.1673
#   F41: mean_diff = 1.1252
#   F73: mean_diff = 1.0920
#   F165: mean_diff = 1.0914
#
# Class Pair: (19, 24)
#   F55: mean_diff = 1.0418
#   F254: mean_diff = 1.0290
#   F276: mean_diff = 1.0215
#   F210: mean_diff = 0.9592
#   F65: mean_diff = 0.9496
#   F293: mean_diff = 0.8988
#   F288: mean_diff = 0.8481
#   F209: mean_diff = 0.8312
#   F268: mean_diff = 0.8187
#   F107: mean_diff = 0.8160
#
# Class Pair: (19, 25)
#   F107: mean_diff = 0.9774
#   F98: mean_diff = 0.9700
#   F164: mean_diff = 0.9419
#   F178: mean_diff = 0.9150
#   F59: mean_diff = 0.9026
#   F227: mean_diff = 0.8894
#   F67: mean_diff = 0.8521
#   F177: mean_diff = 0.7988
#   F184: mean_diff = 0.7834
#   F288: mean_diff = 0.7796
#
# Class Pair: (19, 26)
#   F210: mean_diff = 1.2128
#   F55: mean_diff = 1.0454
#   F274: mean_diff = 1.0280
#   F242: mean_diff = 0.8696
#   F232: mean_diff = 0.8463
#   F209: mean_diff = 0.8389
#   F240: mean_diff = 0.8283
#   F17: mean_diff = 0.8223
#   F88: mean_diff = 0.8085
#   F200: mean_diff = 0.7996
#
# Class Pair: (19, 27)
#   F292: mean_diff = 1.7828
#   F23: mean_diff = 1.5692
#   F99: mean_diff = 1.4159
#   F287: mean_diff = 1.3767
#   F247: mean_diff = 1.3654
#   F13: mean_diff = 1.3577
#   F92: mean_diff = 1.3298
#   F112: mean_diff = 1.3026
#   F202: mean_diff = 1.2914
#   F274: mean_diff = 1.2398
#
# Class Pair: (20, 21)
#   F159: mean_diff = 1.2179
#   F55: mean_diff = 0.9902
#   F37: mean_diff = 0.9721
#   F198: mean_diff = 0.9523
#   F66: mean_diff = 0.9302
#   F212: mean_diff = 0.9240
#   F82: mean_diff = 0.9190
#   F223: mean_diff = 0.8769
#   F240: mean_diff = 0.8750
#   F224: mean_diff = 0.8552
#
# Class Pair: (20, 22)
#   F181: mean_diff = 2.0176
#   F279: mean_diff = 1.8956
#   F39: mean_diff = 1.8233
#   F131: mean_diff = 1.7730
#   F47: mean_diff = 1.7452
#   F85: mean_diff = 1.6855
#   F66: mean_diff = 1.5471
#   F286: mean_diff = 1.5424
#   F41: mean_diff = 1.4796
#   F25: mean_diff = 1.3989
#
# Class Pair: (20, 23)
#   F148: mean_diff = 2.0282
#   F79: mean_diff = 1.9388
#   F293: mean_diff = 1.6385
#   F211: mean_diff = 1.6353
#   F250: mean_diff = 1.6037
#   F73: mean_diff = 1.5446
#   F268: mean_diff = 1.4915
#   F222: mean_diff = 1.4258
#   F51: mean_diff = 1.4209
#   F44: mean_diff = 1.3878
#
# Class Pair: (20, 24)
#   F254: mean_diff = 0.7569
#   F191: mean_diff = 0.7401
#   F276: mean_diff = 0.7245
#   F125: mean_diff = 0.7143
#   F208: mean_diff = 0.7039
#   F159: mean_diff = 0.7004
#   F55: mean_diff = 0.6854
#   F259: mean_diff = 0.6771
#   F207: mean_diff = 0.6727
#   F23: mean_diff = 0.6601
#
# Class Pair: (20, 25)
#   F106: mean_diff = 0.7060
#   F70: mean_diff = 0.7006
#   F109: mean_diff = 0.5752
#   F222: mean_diff = 0.5567
#   F36: mean_diff = 0.5474
#   F143: mean_diff = 0.5356
#   F212: mean_diff = 0.5349
#   F35: mean_diff = 0.5274
#   F110: mean_diff = 0.5064
#   F5: mean_diff = 0.4957
#
# Class Pair: (20, 26)
#   F159: mean_diff = 1.2860
#   F227: mean_diff = 1.0727
#   F125: mean_diff = 0.9657
#   F270: mean_diff = 0.8101
#   F79: mean_diff = 0.7642
#   F176: mean_diff = 0.7558
#   F195: mean_diff = 0.7445
#   F230: mean_diff = 0.7295
#   F2: mean_diff = 0.7129
#   F89: mean_diff = 0.7036
#
# Class Pair: (20, 27)
#   F89: mean_diff = 1.8517
#   F79: mean_diff = 1.7588
#   F227: mean_diff = 1.6646
#   F47: mean_diff = 1.6106
#   F222: mean_diff = 1.5917
#   F292: mean_diff = 1.4806
#   F171: mean_diff = 1.4789
#   F23: mean_diff = 1.4708
#   F8: mean_diff = 1.4372
#   F230: mean_diff = 1.4031
#
# Class Pair: (21, 22)
#   F131: mean_diff = 1.4505
#   F111: mean_diff = 1.3776
#   F279: mean_diff = 1.3086
#   F286: mean_diff = 1.2627
#   F234: mean_diff = 1.2177
#   F59: mean_diff = 1.2131
#   F181: mean_diff = 1.2071
#   F41: mean_diff = 1.1825
#   F77: mean_diff = 1.1787
#   F39: mean_diff = 1.1785
#
# Class Pair: (21, 23)
#   F79: mean_diff = 1.9467
#   F265: mean_diff = 1.9325
#   F240: mean_diff = 1.7413
#   F268: mean_diff = 1.6933
#   F107: mean_diff = 1.6678
#   F242: mean_diff = 1.6416
#   F148: mean_diff = 1.5866
#   F31: mean_diff = 1.5626
#   F143: mean_diff = 1.5598
#   F295: mean_diff = 1.5299
#
# Class Pair: (21, 24)
#   F200: mean_diff = 1.3302
#   F85: mean_diff = 1.1392
#   F285: mean_diff = 1.0667
#   F271: mean_diff = 1.0316
#   F239: mean_diff = 1.0263
#   F175: mean_diff = 0.9585
#   F143: mean_diff = 0.8999
#   F283: mean_diff = 0.8964
#   F267: mean_diff = 0.8747
#   F208: mean_diff = 0.8661
#
# Class Pair: (21, 25)
#   F143: mean_diff = 1.2358
#   F240: mean_diff = 1.1680
#   F227: mean_diff = 1.1669
#   F223: mean_diff = 1.1295
#   F198: mean_diff = 1.1044
#   F159: mean_diff = 1.0470
#   F55: mean_diff = 1.0325
#   F66: mean_diff = 1.0308
#   F39: mean_diff = 1.0072
#   F202: mean_diff = 0.9894
#
# Class Pair: (21, 26)
#   F175: mean_diff = 1.1397
#   F239: mean_diff = 0.9368
#   F133: mean_diff = 0.8748
#   F25: mean_diff = 0.8501
#   F16: mean_diff = 0.8399
#   F123: mean_diff = 0.8332
#   F202: mean_diff = 0.8263
#   F143: mean_diff = 0.8221
#   F195: mean_diff = 0.7898
#   F37: mean_diff = 0.7789
#
# Class Pair: (21, 27)
#   F118: mean_diff = 1.9048
#   F89: mean_diff = 1.8438
#   F79: mean_diff = 1.7667
#   F202: mean_diff = 1.7213
#   F200: mean_diff = 1.7034
#   F99: mean_diff = 1.5973
#   F171: mean_diff = 1.4820
#   F25: mean_diff = 1.4775
#   F92: mean_diff = 1.4669
#   F268: mean_diff = 1.4423
#
# Class Pair: (22, 23)
#   F85: mean_diff = 2.5273
#   F131: mean_diff = 2.2787
#   F279: mean_diff = 2.1694
#   F285: mean_diff = 2.0767
#   F286: mean_diff = 2.0267
#   F265: mean_diff = 2.0223
#   F245: mean_diff = 1.9942
#   F181: mean_diff = 1.9865
#   F268: mean_diff = 1.9607
#   F240: mean_diff = 1.9537
#
# Class Pair: (22, 24)
#   F85: mean_diff = 2.1660
#   F286: mean_diff = 2.0486
#   F25: mean_diff = 1.9030
#   F279: mean_diff = 1.8804
#   F131: mean_diff = 1.8165
#   F39: mean_diff = 1.7782
#   F285: mean_diff = 1.6994
#   F181: mean_diff = 1.6557
#   F41: mean_diff = 1.5931
#   F150: mean_diff = 1.5303
#
# Class Pair: (22, 25)
#   F131: mean_diff = 2.1985
#   F39: mean_diff = 2.1857
#   F279: mean_diff = 2.0470
#   F47: mean_diff = 1.9421
#   F85: mean_diff = 1.8689
#   F181: mean_diff = 1.8151
#   F286: mean_diff = 1.7748
#   F41: mean_diff = 1.7496
#   F106: mean_diff = 1.7138
#   F66: mean_diff = 1.6477
#
# Class Pair: (22, 26)
#   F25: mean_diff = 2.0010
#   F131: mean_diff = 1.9831
#   F181: mean_diff = 1.9048
#   F279: mean_diff = 1.7925
#   F85: mean_diff = 1.7205
#   F286: mean_diff = 1.6241
#   F106: mean_diff = 1.5129
#   F171: mean_diff = 1.5067
#   F215: mean_diff = 1.4887
#   F133: mean_diff = 1.4473
#
# Class Pair: (22, 27)
#   F25: mean_diff = 2.6285
#   F171: mean_diff = 2.4944
#   F89: mean_diff = 2.3127
#   F85: mean_diff = 2.2825
#   F286: mean_diff = 2.2371
#   F118: mean_diff = 2.1750
#   F181: mean_diff = 2.1295
#   F131: mean_diff = 2.0840
#   F279: mean_diff = 1.9642
#   F259: mean_diff = 1.9395
#
# Class Pair: (23, 24)
#   F293: mean_diff = 1.9686
#   F148: mean_diff = 1.9517
#   F265: mean_diff = 1.7726
#   F44: mean_diff = 1.6051
#   F32: mean_diff = 1.5497
#   F51: mean_diff = 1.5487
#   F73: mean_diff = 1.5390
#   F211: mean_diff = 1.4734
#   F245: mean_diff = 1.4391
#   F268: mean_diff = 1.4254
#
# Class Pair: (23, 25)
#   F148: mean_diff = 1.9561
#   F79: mean_diff = 1.5469
#   F107: mean_diff = 1.5191
#   F211: mean_diff = 1.4978
#   F265: mean_diff = 1.4657
#   F250: mean_diff = 1.4366
#   F73: mean_diff = 1.3866
#   F32: mean_diff = 1.3485
#   F215: mean_diff = 1.3356
#   F198: mean_diff = 1.3014
#
# Class Pair: (23, 26)
#   F148: mean_diff = 1.6102
#   F265: mean_diff = 1.5965
#   F242: mean_diff = 1.5690
#   F215: mean_diff = 1.5060
#   F211: mean_diff = 1.5012
#   F240: mean_diff = 1.4747
#   F44: mean_diff = 1.4452
#   F168: mean_diff = 1.4107
#   F140: mean_diff = 1.3794
#   F241: mean_diff = 1.3632
#
# Class Pair: (23, 27)
#   F116: mean_diff = 1.5659
#   F215: mean_diff = 1.5419
#   F282: mean_diff = 1.4843
#   F32: mean_diff = 1.4678
#   F227: mean_diff = 1.4069
#   F244: mean_diff = 1.3948
#   F292: mean_diff = 1.3378
#   F140: mean_diff = 1.3080
#   F23: mean_diff = 1.2865
#   F295: mean_diff = 1.2849
#
# Class Pair: (24, 25)
#   F191: mean_diff = 0.8213
#   F110: mean_diff = 0.7939
#   F70: mean_diff = 0.7791
#   F55: mean_diff = 0.7278
#   F293: mean_diff = 0.7088
#   F47: mean_diff = 0.6946
#   F36: mean_diff = 0.6904
#   F242: mean_diff = 0.6726
#   F65: mean_diff = 0.6655
#   F254: mean_diff = 0.6391
#
# Class Pair: (24, 26)
#   F293: mean_diff = 1.0017
#   F284: mean_diff = 0.9241
#   F227: mean_diff = 0.8847
#   F254: mean_diff = 0.7400
#   F262: mean_diff = 0.7390
#   F168: mean_diff = 0.7186
#   F216: mean_diff = 0.7156
#   F283: mean_diff = 0.7057
#   F149: mean_diff = 0.6999
#   F270: mean_diff = 0.6907
#
# Class Pair: (24, 27)
#   F89: mean_diff = 1.6397
#   F171: mean_diff = 1.5973
#   F227: mean_diff = 1.4765
#   F118: mean_diff = 1.4731
#   F292: mean_diff = 1.4413
#   F259: mean_diff = 1.4211
#   F99: mean_diff = 1.3973
#   F207: mean_diff = 1.3304
#   F8: mean_diff = 1.2795
#   F205: mean_diff = 1.2548
#
# Class Pair: (25, 26)
#   F227: mean_diff = 1.4986
#   F159: mean_diff = 1.1150
#   F240: mean_diff = 0.9014
#   F164: mean_diff = 0.8863
#   F17: mean_diff = 0.8845
#   F284: mean_diff = 0.8737
#   F242: mean_diff = 0.8227
#   F110: mean_diff = 0.8190
#   F171: mean_diff = 0.8006
#   F270: mean_diff = 0.7833
#
# Class Pair: (25, 27)
#   F227: mean_diff = 2.0905
#   F47: mean_diff = 1.8075
#   F171: mean_diff = 1.7883
#   F89: mean_diff = 1.6036
#   F98: mean_diff = 1.4998
#   F230: mean_diff = 1.4478
#   F292: mean_diff = 1.4306
#   F8: mean_diff = 1.4157
#   F99: mean_diff = 1.3740
#   F79: mean_diff = 1.3669
#
# Class Pair: (26, 27)
#   F292: mean_diff = 1.3502
#   F23: mean_diff = 1.3256
#   F118: mean_diff = 1.3076
#   F222: mean_diff = 1.2106
#   F89: mean_diff = 1.1482
#   F81: mean_diff = 1.1257
#   F99: mean_diff = 1.1114
#   F287: mean_diff = 1.0978
#   F47: mean_diff = 1.0928
#   F137: mean_diff = 1.0685

# %%
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

# 收集所有特征索引
all_topk_feats = []
for pair in pairwise_topk.values():
    all_topk_feats.extend([f['feature_idx'] for f in pair])

# 统计出现频次
feat_counter = Counter(all_topk_feats)

# 转为 DataFrame 
feat_freq_df = pd.DataFrame(feat_counter.items(), columns=["feature_idx", "count"])
feat_freq_df.sort_values(by="count", ascending=False, inplace=True)

# 前10个最常出现的特征
print("\nTop 10 most frequently selected features across class pairs:")
print(feat_freq_df.head(10))

# 柱状图可视化
top_n = 10
plt.figure(figsize=(10, 5))
plt.barh(
    [f"F{int(i)}" for i in feat_freq_df["feature_idx"].head(top_n)][::-1],
    feat_freq_df["count"].head(top_n)[::-1]
)
plt.xlabel("Frequency across class pairs")
plt.title(f"Top {top_n} Features Frequently Appearing in Top-K Class Pair Differences")
plt.tight_layout()
plt.show()
# Out:
# Top 10 most frequently selected features across class pairs:
#      feature_idx  count
# 96           279     68
# 0            131     66
# 2             85     56
# 52            79     49
# 83            17     49
# 15           240     49
# 140          270     48
# 10            55     47
# 54           259     46
# 46           182     44

# %% [markdown]
# ### 基于 p-value 的 pairwise 特征分析

# %%
import numpy as np
from itertools import combinations
from scipy.stats import ttest_ind

# 初始化
class_list = np.unique(y)
class_pairs = list(combinations(class_list, 2))

pairwise_topk_pval = {}
k = 10  # 控制 top-K

for cls0, cls1 in class_pairs:
    idx0 = (y == cls0)
    idx1 = (y == cls1)

    # 对每个特征进行 t-test
    p_values = []
    for i in range(X.shape[1]):
        stat, p = ttest_ind(X[idx0, i], X[idx1, i], equal_var=False)
        p_values.append(p)

    p_values = np.array(p_values)

    # 取前 k 个最显著（p 值最小）的特征
    topk_idx = np.argsort(p_values)[:k]

    feature_info = []
    for rank, feat_idx in enumerate(topk_idx):
        feature_info.append({
            "feature_idx": int(feat_idx),
            "p_value": float(p_values[feat_idx]),
            "rank": rank + 1
        })

    pairwise_topk_pval[(int(cls0), int(cls1))] = feature_info

# %%
for pair in list(pairwise_topk_pval.keys()):
    print(f"\nClass Pair: {pair}")
    for feat in pairwise_topk_pval[pair]:
        print(f"  F{feat['feature_idx']}: p_value = {feat['p_value']:.4e}")
# Out:
# Class Pair: (0, 1)
#   F215: p_value = 7.2119e-06
#   F131: p_value = 1.0586e-05
#   F49: p_value = 1.0922e-05
#   F46: p_value = 4.3906e-05
#   F43: p_value = 5.1901e-05
#   F216: p_value = 8.0268e-05
#   F35: p_value = 1.3457e-04
#   F85: p_value = 2.1428e-04
#   F41: p_value = 3.1122e-04
#   F191: p_value = 3.8586e-04
#
# Class Pair: (0, 2)
#   F55: p_value = 1.6105e-05
#   F208: p_value = 1.9026e-05
#   F158: p_value = 1.3723e-04
#   F270: p_value = 1.4763e-04
#   F44: p_value = 1.5858e-04
#   F213: p_value = 3.5389e-04
#   F123: p_value = 4.8544e-04
#   F242: p_value = 6.2168e-04
#   F216: p_value = 7.4613e-04
#   F60: p_value = 1.0061e-03
#
# Class Pair: (0, 3)
#   F55: p_value = 1.8989e-06
#   F21: p_value = 9.5715e-06
#   F288: p_value = 7.3358e-05
#   F210: p_value = 2.2186e-04
#   F223: p_value = 2.4664e-04
#   F97: p_value = 2.6029e-04
#   F166: p_value = 2.9106e-04
#   F278: p_value = 4.5712e-04
#   F146: p_value = 5.0511e-04
#   F283: p_value = 6.9075e-04
#
# Class Pair: (0, 4)
#   F22: p_value = 5.4815e-07
#   F199: p_value = 7.1720e-07
#   F291: p_value = 7.5241e-07
#   F43: p_value = 1.1388e-06
#   F280: p_value = 1.8699e-06
#   F154: p_value = 1.8775e-06
#   F213: p_value = 6.8762e-06
#   F140: p_value = 1.0621e-05
#   F195: p_value = 1.2594e-05
#   F261: p_value = 1.3241e-05
#
# Class Pair: (0, 5)
#   F218: p_value = 2.3590e-14
#   F86: p_value = 3.2055e-09
#   F88: p_value = 7.8406e-09
#   F90: p_value = 8.4049e-09
#   F111: p_value = 1.0061e-08
#   F234: p_value = 1.2585e-08
#   F141: p_value = 1.3258e-08
#   F17: p_value = 2.7705e-08
#   F87: p_value = 2.8119e-08
#   F71: p_value = 5.4657e-08
#
# Class Pair: (0, 6)
#   F218: p_value = 6.7062e-24
#   F182: p_value = 4.0961e-12
#   F274: p_value = 3.6857e-11
#   F88: p_value = 2.9989e-10
#   F205: p_value = 3.8302e-10
#   F17: p_value = 6.3558e-10
#   F199: p_value = 1.4389e-09
#   F214: p_value = 2.0083e-09
#   F189: p_value = 3.5564e-09
#   F43: p_value = 3.6519e-09
#
# Class Pair: (0, 7)
#   F223: p_value = 4.6755e-09
#   F44: p_value = 6.7575e-07
#   F274: p_value = 8.4925e-07
#   F158: p_value = 3.8942e-06
#   F162: p_value = 4.8942e-06
#   F259: p_value = 9.3989e-06
#   F13: p_value = 1.2033e-05
#   F139: p_value = 1.3165e-05
#   F79: p_value = 1.4757e-05
#   F21: p_value = 1.7600e-05
#
# Class Pair: (0, 8)
#   F218: p_value = 2.8937e-05
#   F56: p_value = 3.5558e-03
#   F43: p_value = 3.9752e-03
#   F92: p_value = 1.6668e-02
#   F10: p_value = 2.0251e-02
#   F133: p_value = 2.4607e-02
#   F261: p_value = 3.0105e-02
#   F288: p_value = 3.0721e-02
#   F25: p_value = 3.1032e-02
#   F71: p_value = 3.4597e-02
#
# Class Pair: (0, 9)
#   F182: p_value = 7.6372e-12
#   F274: p_value = 1.5292e-11
#   F218: p_value = 6.8464e-10
#   F43: p_value = 2.0968e-09
#   F189: p_value = 4.0722e-09
#   F86: p_value = 4.3385e-09
#   F17: p_value = 4.3839e-09
#   F261: p_value = 5.4415e-09
#   F214: p_value = 6.1077e-09
#   F249: p_value = 7.3781e-09
#
# Class Pair: (0, 10)
#   F158: p_value = 2.4355e-07
#   F223: p_value = 4.1540e-07
#   F265: p_value = 1.1789e-06
#   F226: p_value = 1.4910e-06
#   F274: p_value = 1.9183e-06
#   F259: p_value = 2.4569e-06
#   F290: p_value = 2.6457e-06
#   F189: p_value = 3.0615e-06
#   F242: p_value = 4.3714e-06
#   F79: p_value = 6.6750e-06
#
# Class Pair: (0, 11)
#   F285: p_value = 1.0561e-14
#   F55: p_value = 1.2964e-12
#   F158: p_value = 4.1118e-12
#   F297: p_value = 6.8634e-12
#   F45: p_value = 8.4747e-12
#   F214: p_value = 1.0368e-11
#   F25: p_value = 7.9528e-11
#   F29: p_value = 1.2690e-10
#   F88: p_value = 1.3179e-10
#   F39: p_value = 2.3219e-10
#
# Class Pair: (0, 12)
#   F55: p_value = 8.7120e-08
#   F199: p_value = 9.4603e-06
#   F223: p_value = 2.3380e-05
#   F208: p_value = 2.9377e-05
#   F25: p_value = 6.2454e-05
#   F146: p_value = 7.7649e-05
#   F22: p_value = 1.1179e-04
#   F53: p_value = 1.1477e-04
#   F108: p_value = 1.2395e-04
#   F186: p_value = 2.3238e-04
#
# Class Pair: (0, 13)
#   F55: p_value = 4.1213e-07
#   F140: p_value = 9.5283e-07
#   F158: p_value = 4.4146e-06
#   F199: p_value = 9.1202e-06
#   F54: p_value = 1.5651e-05
#   F223: p_value = 1.6267e-05
#   F185: p_value = 3.3714e-05
#   F53: p_value = 3.5984e-05
#   F261: p_value = 5.5958e-05
#   F154: p_value = 6.3649e-05
#
# Class Pair: (0, 14)
#   F218: p_value = 2.2378e-24
#   F17: p_value = 3.0037e-10
#   F90: p_value = 3.5583e-10
#   F234: p_value = 9.6035e-10
#   F87: p_value = 1.6440e-09
#   F141: p_value = 7.1089e-09
#   F88: p_value = 1.0509e-08
#   F111: p_value = 1.6690e-08
#   F92: p_value = 2.7091e-08
#   F71: p_value = 4.1484e-08
#
# Class Pair: (0, 15)
#   F214: p_value = 2.4016e-10
#   F280: p_value = 1.3449e-09
#   F21: p_value = 2.4820e-08
#   F35: p_value = 8.9060e-08
#   F204: p_value = 3.2088e-07
#   F215: p_value = 8.5498e-07
#   F53: p_value = 1.6672e-06
#   F49: p_value = 2.6557e-06
#   F234: p_value = 2.7028e-06
#   F185: p_value = 3.3571e-06
#
# Class Pair: (0, 16)
#   F141: p_value = 2.9000e-06
#   F284: p_value = 6.8464e-06
#   F213: p_value = 3.9018e-05
#   F71: p_value = 1.3214e-04
#   F79: p_value = 2.4088e-04
#   F86: p_value = 2.4528e-04
#   F263: p_value = 4.4473e-04
#   F247: p_value = 5.1902e-04
#   F250: p_value = 6.0586e-04
#   F44: p_value = 6.8423e-04
#
# Class Pair: (0, 17)
#   F218: p_value = 5.1094e-27
#   F17: p_value = 7.4649e-11
#   F214: p_value = 2.2686e-10
#   F88: p_value = 5.8692e-10
#   F234: p_value = 2.3888e-09
#   F252: p_value = 5.8904e-09
#   F111: p_value = 1.0418e-08
#   F199: p_value = 1.4318e-08
#   F71: p_value = 1.8674e-08
#   F87: p_value = 1.9896e-08
#
# Class Pair: (0, 18)
#   F218: p_value = 5.3909e-09
#   F96: p_value = 4.6856e-08
#   F261: p_value = 2.5609e-07
#   F196: p_value = 2.5881e-07
#   F149: p_value = 6.4228e-07
#   F205: p_value = 8.2975e-07
#   F10: p_value = 2.3833e-06
#   F158: p_value = 3.5542e-06
#   F189: p_value = 3.8964e-06
#   F35: p_value = 4.7142e-06
#
# Class Pair: (0, 19)
#   F55: p_value = 3.3357e-09
#   F274: p_value = 2.2839e-07
#   F223: p_value = 7.1967e-07
#   F189: p_value = 4.6876e-06
#   F24: p_value = 7.6548e-06
#   F288: p_value = 1.4431e-05
#   F199: p_value = 2.0293e-05
#   F254: p_value = 2.0630e-05
#   F268: p_value = 2.4210e-05
#   F107: p_value = 2.4592e-05
#
# Class Pair: (0, 20)
#   F195: p_value = 5.8965e-07
#   F55: p_value = 7.0456e-07
#   F199: p_value = 7.6594e-07
#   F35: p_value = 4.3601e-06
#   F208: p_value = 5.5928e-06
#   F189: p_value = 1.2250e-05
#   F223: p_value = 1.2448e-05
#   F53: p_value = 2.1643e-05
#   F61: p_value = 2.3539e-05
#   F185: p_value = 3.2791e-05
#
# Class Pair: (0, 21)
#   F218: p_value = 1.7967e-09
#   F195: p_value = 2.9538e-07
#   F189: p_value = 7.3977e-07
#   F199: p_value = 1.4098e-06
#   F208: p_value = 1.5069e-06
#   F291: p_value = 2.1790e-06
#   F143: p_value = 2.7191e-06
#   F215: p_value = 5.8621e-06
#   F285: p_value = 1.0182e-05
#   F25: p_value = 1.3835e-05
#
# Class Pair: (0, 22)
#   F25: p_value = 1.4476e-06
#   F279: p_value = 2.4710e-05
#   F45: p_value = 5.5621e-05
#   F286: p_value = 6.8198e-05
#   F19: p_value = 7.1028e-05
#   F256: p_value = 1.0668e-04
#   F156: p_value = 1.4169e-04
#   F66: p_value = 2.4161e-04
#   F287: p_value = 3.1423e-04
#   F216: p_value = 3.4036e-04
#
# Class Pair: (0, 23)
#   F148: p_value = 8.3369e-11
#   F293: p_value = 6.3465e-10
#   F265: p_value = 7.0104e-10
#   F215: p_value = 1.6996e-09
#   F158: p_value = 4.8832e-09
#   F140: p_value = 5.6988e-09
#   F250: p_value = 6.0001e-09
#   F44: p_value = 1.4710e-08
#   F268: p_value = 1.8713e-08
#   F242: p_value = 2.1945e-08
#
# Class Pair: (0, 24)
#   F218: p_value = 3.2380e-06
#   F291: p_value = 1.0131e-04
#   F54: p_value = 1.5720e-04
#   F183: p_value = 3.5431e-04
#   F22: p_value = 3.5783e-04
#   F261: p_value = 4.2162e-04
#   F199: p_value = 5.5552e-04
#   F220: p_value = 5.8230e-04
#   F53: p_value = 6.2926e-04
#   F280: p_value = 7.2173e-04
#
# Class Pair: (0, 25)
#   F223: p_value = 4.1621e-07
#   F55: p_value = 4.6036e-07
#   F195: p_value = 2.1695e-06
#   F199: p_value = 4.8143e-06
#   F158: p_value = 6.0540e-06
#   F54: p_value = 1.0839e-05
#   F185: p_value = 1.8153e-05
#   F140: p_value = 2.2017e-05
#   F22: p_value = 4.2399e-05
#   F53: p_value = 4.4293e-05
#
# Class Pair: (0, 26)
#   F218: p_value = 1.5098e-08
#   F199: p_value = 1.2533e-05
#   F61: p_value = 1.7837e-05
#   F284: p_value = 1.8172e-05
#   F293: p_value = 3.1039e-05
#   F291: p_value = 3.1606e-05
#   F208: p_value = 5.1757e-05
#   F149: p_value = 6.2355e-05
#   F54: p_value = 1.1447e-04
#   F216: p_value = 1.2317e-04
#
# Class Pair: (0, 27)
#   F158: p_value = 4.3249e-09
#   F92: p_value = 5.0173e-09
#   F61: p_value = 7.4826e-09
#   F118: p_value = 1.5743e-08
#   F149: p_value = 2.6498e-08
#   F247: p_value = 5.7201e-08
#   F204: p_value = 8.0547e-08
#   F89: p_value = 1.1079e-07
#   F22: p_value = 1.3528e-07
#   F8: p_value = 1.4395e-07
#
# Class Pair: (1, 2)
#   F131: p_value = 4.0031e-05
#   F279: p_value = 1.2854e-04
#   F125: p_value = 1.5973e-04
#   F85: p_value = 3.0828e-04
#   F46: p_value = 3.1379e-04
#   F49: p_value = 3.3088e-04
#   F61: p_value = 3.6729e-04
#   F208: p_value = 4.1337e-04
#   F161: p_value = 4.7342e-04
#   F123: p_value = 4.9985e-04
#
# Class Pair: (1, 3)
#   F288: p_value = 3.9404e-07
#   F131: p_value = 2.2564e-05
#   F46: p_value = 5.0040e-05
#   F41: p_value = 1.0355e-04
#   F43: p_value = 1.0402e-04
#   F197: p_value = 1.4385e-04
#   F262: p_value = 1.9742e-04
#   F85: p_value = 2.2481e-04
#   F121: p_value = 2.5472e-04
#   F215: p_value = 3.1390e-04
#
# Class Pair: (1, 4)
#   F288: p_value = 8.2688e-06
#   F131: p_value = 1.3260e-05
#   F46: p_value = 3.4598e-05
#   F85: p_value = 7.0246e-05
#   F215: p_value = 2.2301e-04
#   F100: p_value = 2.8660e-04
#   F49: p_value = 3.3910e-04
#   F91: p_value = 3.8518e-04
#   F26: p_value = 4.8668e-04
#   F279: p_value = 5.0961e-04
#
# Class Pair: (1, 5)
#   F46: p_value = 7.7442e-06
#   F38: p_value = 2.0355e-05
#   F238: p_value = 5.0299e-05
#   F86: p_value = 6.5215e-05
#   F121: p_value = 6.7637e-05
#   F61: p_value = 9.0395e-05
#   F47: p_value = 1.3208e-04
#   F81: p_value = 1.4734e-04
#   F288: p_value = 1.5714e-04
#   F63: p_value = 1.9940e-04
#
# Class Pair: (1, 6)
#   F238: p_value = 4.3658e-07
#   F46: p_value = 1.2802e-06
#   F61: p_value = 3.1773e-05
#   F197: p_value = 5.6230e-05
#   F215: p_value = 5.6280e-05
#   F49: p_value = 9.2718e-05
#   F76: p_value = 1.1820e-04
#   F86: p_value = 1.3826e-04
#   F288: p_value = 1.5149e-04
#   F281: p_value = 2.4396e-04
#
# Class Pair: (1, 7)
#   F288: p_value = 9.6490e-07
#   F95: p_value = 3.5417e-05
#   F131: p_value = 4.2373e-05
#   F79: p_value = 4.9634e-05
#   F85: p_value = 6.1115e-05
#   F216: p_value = 1.0813e-04
#   F191: p_value = 1.5244e-04
#   F161: p_value = 2.3932e-04
#   F269: p_value = 2.6965e-04
#   F121: p_value = 2.7169e-04
#
# Class Pair: (1, 8)
#   F131: p_value = 8.4314e-05
#   F215: p_value = 2.0153e-04
#   F212: p_value = 2.5991e-04
#   F85: p_value = 4.0849e-04
#   F49: p_value = 4.1072e-04
#   F46: p_value = 4.6504e-04
#   F216: p_value = 5.1823e-04
#   F288: p_value = 6.2791e-04
#   F26: p_value = 6.6611e-04
#   F191: p_value = 7.8278e-04
#
# Class Pair: (1, 9)
#   F238: p_value = 1.8999e-09
#   F46: p_value = 9.3181e-09
#   F215: p_value = 2.0359e-07
#   F61: p_value = 5.3889e-07
#   F86: p_value = 2.4675e-06
#   F181: p_value = 1.2736e-05
#   F142: p_value = 2.3868e-05
#   F49: p_value = 2.5833e-05
#   F76: p_value = 3.8294e-05
#   F202: p_value = 4.6111e-05
#
# Class Pair: (1, 10)
#   F131: p_value = 2.3899e-05
#   F85: p_value = 1.1284e-04
#   F79: p_value = 1.1439e-04
#   F95: p_value = 2.7804e-04
#   F81: p_value = 3.0570e-04
#   F279: p_value = 4.1292e-04
#   F100: p_value = 4.1569e-04
#   F288: p_value = 4.3595e-04
#   F61: p_value = 4.4552e-04
#   F46: p_value = 5.5319e-04
#
# Class Pair: (1, 11)
#   F197: p_value = 2.6507e-08
#   F288: p_value = 6.1222e-07
#   F54: p_value = 7.6367e-07
#   F39: p_value = 8.8288e-07
#   F81: p_value = 9.8966e-07
#   F285: p_value = 1.5173e-06
#   F208: p_value = 2.1892e-06
#   F161: p_value = 1.5617e-05
#   F145: p_value = 1.5631e-05
#   F47: p_value = 3.0687e-05
#
# Class Pair: (1, 12)
#   F197: p_value = 3.0676e-05
#   F288: p_value = 5.2449e-05
#   F131: p_value = 9.9734e-05
#   F49: p_value = 2.5357e-04
#   F85: p_value = 6.0330e-04
#   F46: p_value = 6.6176e-04
#   F148: p_value = 7.4069e-04
#   F61: p_value = 1.0095e-03
#   F43: p_value = 1.2175e-03
#   F238: p_value = 1.2455e-03
#
# Class Pair: (1, 13)
#   F288: p_value = 3.8216e-06
#   F131: p_value = 9.4651e-06
#   F46: p_value = 2.9865e-05
#   F140: p_value = 4.8900e-05
#   F85: p_value = 7.0003e-05
#   F238: p_value = 1.4119e-04
#   F49: p_value = 2.0546e-04
#   F197: p_value = 2.0792e-04
#   F84: p_value = 2.1990e-04
#   F285: p_value = 2.2610e-04
#
# Class Pair: (1, 14)
#   F38: p_value = 1.9862e-06
#   F46: p_value = 4.6605e-06
#   F238: p_value = 6.8409e-06
#   F121: p_value = 1.4101e-05
#   F288: p_value = 1.9689e-05
#   F47: p_value = 3.0826e-05
#   F81: p_value = 4.0571e-05
#   F63: p_value = 4.9043e-05
#   F61: p_value = 9.0769e-05
#   F124: p_value = 9.3601e-05
#
# Class Pair: (1, 15)
#   F81: p_value = 1.1713e-03
#   F148: p_value = 8.4748e-03
#   F227: p_value = 8.4885e-03
#   F189: p_value = 1.0143e-02
#   F53: p_value = 1.1615e-02
#   F91: p_value = 1.5313e-02
#   F181: p_value = 1.6277e-02
#   F78: p_value = 1.7543e-02
#   F60: p_value = 2.0387e-02
#   F176: p_value = 3.0813e-02
#
# Class Pair: (1, 16)
#   F79: p_value = 1.4099e-04
#   F85: p_value = 2.1569e-04
#   F86: p_value = 2.6574e-04
#   F43: p_value = 4.0035e-04
#   F71: p_value = 6.5926e-04
#   F279: p_value = 8.1292e-04
#   F23: p_value = 1.0699e-03
#   F216: p_value = 1.2006e-03
#   F200: p_value = 1.6247e-03
#   F46: p_value = 1.7156e-03
#
# Class Pair: (1, 17)
#   F38: p_value = 3.1717e-06
#   F46: p_value = 7.2261e-06
#   F238: p_value = 9.0246e-06
#   F61: p_value = 4.4249e-05
#   F131: p_value = 7.9759e-05
#   F81: p_value = 2.2819e-04
#   F76: p_value = 2.3055e-04
#   F86: p_value = 2.4382e-04
#   F251: p_value = 2.4418e-04
#   F121: p_value = 2.4736e-04
#
# Class Pair: (1, 18)
#   F131: p_value = 5.2497e-06
#   F46: p_value = 5.6021e-06
#   F215: p_value = 1.4266e-05
#   F81: p_value = 1.9893e-05
#   F85: p_value = 7.8430e-05
#   F95: p_value = 9.5347e-05
#   F143: p_value = 1.1540e-04
#   F61: p_value = 1.9621e-04
#   F196: p_value = 2.2701e-04
#   F161: p_value = 2.4213e-04
#
# Class Pair: (1, 19)
#   F288: p_value = 4.4914e-07
#   F131: p_value = 2.8327e-05
#   F210: p_value = 4.8187e-05
#   F41: p_value = 1.0053e-04
#   F85: p_value = 1.8644e-04
#   F238: p_value = 2.2583e-04
#   F43: p_value = 2.2888e-04
#   F46: p_value = 2.3358e-04
#   F121: p_value = 2.8662e-04
#   F81: p_value = 3.4749e-04
#
# Class Pair: (1, 20)
#   F197: p_value = 8.2416e-07
#   F131: p_value = 2.7981e-05
#   F49: p_value = 6.8934e-05
#   F61: p_value = 1.0474e-04
#   F288: p_value = 1.2695e-04
#   F46: p_value = 1.6322e-04
#   F121: p_value = 2.1147e-04
#   F85: p_value = 2.2072e-04
#   F238: p_value = 6.6116e-04
#   F26: p_value = 7.1017e-04
#
# Class Pair: (1, 21)
#   F131: p_value = 9.0169e-05
#   F208: p_value = 3.3906e-04
#   F38: p_value = 6.0001e-04
#   F288: p_value = 7.2419e-04
#   F212: p_value = 7.5378e-04
#   F97: p_value = 8.2933e-04
#   F61: p_value = 8.5189e-04
#   F43: p_value = 9.9313e-04
#   F191: p_value = 1.0749e-03
#   F123: p_value = 1.5500e-03
#
# Class Pair: (1, 22)
#   F84: p_value = 2.7840e-04
#   F91: p_value = 2.9997e-04
#   F110: p_value = 5.6217e-04
#   F25: p_value = 2.3476e-03
#   F286: p_value = 3.6890e-03
#   F6: p_value = 4.5365e-03
#   F19: p_value = 4.5770e-03
#   F78: p_value = 7.3066e-03
#   F256: p_value = 7.6508e-03
#   F106: p_value = 9.6000e-03
#
# Class Pair: (1, 23)
#   F81: p_value = 3.8491e-08
#   F46: p_value = 2.4142e-07
#   F140: p_value = 6.1229e-07
#   F238: p_value = 6.7908e-07
#   F131: p_value = 2.8344e-06
#   F285: p_value = 4.2727e-06
#   F79: p_value = 6.4148e-06
#   F49: p_value = 6.7017e-06
#   F85: p_value = 7.8305e-06
#   F107: p_value = 1.5450e-05
#
# Class Pair: (1, 24)
#   F131: p_value = 4.4225e-05
#   F85: p_value = 8.7554e-05
#   F49: p_value = 1.0251e-04
#   F46: p_value = 1.6058e-04
#   F191: p_value = 4.9650e-04
#   F285: p_value = 5.7226e-04
#   F238: p_value = 6.0835e-04
#   F81: p_value = 6.2106e-04
#   F121: p_value = 7.2237e-04
#   F200: p_value = 7.3047e-04
#
# Class Pair: (1, 25)
#   F131: p_value = 1.1691e-05
#   F85: p_value = 1.5517e-04
#   F49: p_value = 2.2149e-04
#   F202: p_value = 2.9398e-04
#   F46: p_value = 3.6370e-04
#   F238: p_value = 4.3632e-04
#   F121: p_value = 4.4080e-04
#   F227: p_value = 4.6191e-04
#   F61: p_value = 4.7764e-04
#   F279: p_value = 6.4638e-04
#
# Class Pair: (1, 26)
#   F131: p_value = 2.9076e-05
#   F288: p_value = 3.1739e-05
#   F61: p_value = 1.3047e-04
#   F85: p_value = 2.5929e-04
#   F121: p_value = 2.7852e-04
#   F238: p_value = 3.0905e-04
#   F46: p_value = 3.8623e-04
#   F202: p_value = 5.7994e-04
#   F215: p_value = 5.8926e-04
#   F100: p_value = 8.3341e-04
#
# Class Pair: (1, 27)
#   F238: p_value = 8.1338e-08
#   F47: p_value = 4.9824e-07
#   F81: p_value = 6.5918e-07
#   F197: p_value = 1.0772e-06
#   F61: p_value = 1.0897e-05
#   F202: p_value = 1.5023e-05
#   F131: p_value = 1.7322e-05
#   F38: p_value = 1.9412e-05
#   F79: p_value = 2.3105e-05
#   F121: p_value = 3.9509e-05
#
# Class Pair: (2, 3)
#   F278: p_value = 1.7715e-07
#   F283: p_value = 5.6504e-06
#   F44: p_value = 1.1593e-04
#   F270: p_value = 1.3153e-04
#   F98: p_value = 2.8089e-04
#   F123: p_value = 5.1674e-04
#   F208: p_value = 7.4139e-04
#   F57: p_value = 1.1113e-03
#   F125: p_value = 1.7470e-03
#   F201: p_value = 1.9376e-03
#
# Class Pair: (2, 4)
#   F278: p_value = 1.9352e-04
#   F69: p_value = 6.4072e-04
#   F216: p_value = 1.2553e-03
#   F125: p_value = 2.2301e-03
#   F151: p_value = 2.2916e-03
#   F55: p_value = 2.3366e-03
#   F0: p_value = 3.4066e-03
#   F150: p_value = 4.1245e-03
#   F138: p_value = 4.4422e-03
#   F44: p_value = 5.2715e-03
#
# Class Pair: (2, 5)
#   F231: p_value = 6.4707e-06
#   F270: p_value = 9.2571e-06
#   F283: p_value = 1.0839e-05
#   F5: p_value = 2.8642e-05
#   F218: p_value = 6.7967e-05
#   F292: p_value = 1.3083e-04
#   F263: p_value = 1.8530e-04
#   F277: p_value = 1.8657e-04
#   F17: p_value = 1.9124e-04
#   F90: p_value = 2.4972e-04
#
# Class Pair: (2, 6)
#   F218: p_value = 3.1383e-06
#   F270: p_value = 4.1140e-06
#   F277: p_value = 6.7872e-06
#   F283: p_value = 1.6185e-05
#   F151: p_value = 2.3644e-05
#   F98: p_value = 3.5510e-05
#   F205: p_value = 4.2372e-05
#   F216: p_value = 7.7552e-05
#   F17: p_value = 8.1085e-05
#   F5: p_value = 9.8022e-05
#
# Class Pair: (2, 7)
#   F216: p_value = 3.0125e-06
#   F278: p_value = 8.3943e-05
#   F69: p_value = 1.7889e-04
#   F55: p_value = 3.0384e-04
#   F183: p_value = 6.3374e-04
#   F277: p_value = 8.1173e-04
#   F98: p_value = 8.5435e-04
#   F60: p_value = 1.0481e-03
#   F3: p_value = 2.0560e-03
#   F125: p_value = 2.3114e-03
#
# Class Pair: (2, 8)
#   F270: p_value = 6.5156e-05
#   F216: p_value = 1.4241e-04
#   F298: p_value = 1.4471e-04
#   F55: p_value = 1.8431e-04
#   F208: p_value = 1.9705e-04
#   F213: p_value = 4.2615e-04
#   F44: p_value = 4.8278e-04
#   F278: p_value = 5.0053e-04
#   F242: p_value = 5.6283e-04
#   F5: p_value = 1.6604e-03
#
# Class Pair: (2, 9)
#   F270: p_value = 2.2899e-08
#   F218: p_value = 4.0260e-08
#   F283: p_value = 2.6681e-07
#   F277: p_value = 9.6999e-07
#   F98: p_value = 1.0172e-06
#   F69: p_value = 7.0182e-06
#   F205: p_value = 1.0550e-05
#   F216: p_value = 2.2048e-05
#   F17: p_value = 2.5518e-05
#   F55: p_value = 3.3897e-05
#
# Class Pair: (2, 10)
#   F278: p_value = 1.1492e-04
#   F69: p_value = 1.8364e-04
#   F270: p_value = 1.5190e-03
#   F292: p_value = 2.3135e-03
#   F277: p_value = 2.6413e-03
#   F60: p_value = 3.0680e-03
#   F55: p_value = 3.4539e-03
#   F88: p_value = 4.4569e-03
#   F151: p_value = 6.0312e-03
#   F70: p_value = 6.2841e-03
#
# Class Pair: (2, 11)
#   F5: p_value = 5.6272e-10
#   F283: p_value = 4.4881e-08
#   F0: p_value = 3.1202e-07
#   F297: p_value = 5.9259e-07
#   F279: p_value = 2.1933e-06
#   F286: p_value = 2.7041e-06
#   F71: p_value = 6.9968e-06
#   F292: p_value = 1.4986e-05
#   F242: p_value = 3.0352e-05
#   F106: p_value = 5.2060e-05
#
# Class Pair: (2, 12)
#   F283: p_value = 2.1491e-04
#   F278: p_value = 2.1741e-04
#   F127: p_value = 3.0419e-03
#   F44: p_value = 3.5480e-03
#   F165: p_value = 3.8627e-03
#   F5: p_value = 4.2212e-03
#   F123: p_value = 5.1710e-03
#   F31: p_value = 7.0948e-03
#   F213: p_value = 7.7016e-03
#   F270: p_value = 7.7792e-03
#
# Class Pair: (2, 13)
#   F278: p_value = 2.0944e-06
#   F69: p_value = 1.0314e-03
#   F125: p_value = 2.0715e-03
#   F283: p_value = 3.5077e-03
#   F165: p_value = 5.3825e-03
#   F183: p_value = 6.7986e-03
#   F98: p_value = 8.0248e-03
#   F277: p_value = 1.3806e-02
#   F123: p_value = 1.4572e-02
#   F44: p_value = 1.6085e-02
#
# Class Pair: (2, 14)
#   F231: p_value = 1.4559e-07
#   F270: p_value = 2.0186e-06
#   F283: p_value = 3.0464e-06
#   F5: p_value = 5.7774e-06
#   F218: p_value = 7.8316e-06
#   F277: p_value = 1.8406e-05
#   F17: p_value = 7.1400e-05
#   F90: p_value = 7.7058e-05
#   F292: p_value = 7.8960e-05
#   F55: p_value = 1.0672e-04
#
# Class Pair: (2, 15)
#   F279: p_value = 5.6966e-07
#   F133: p_value = 9.2600e-06
#   F98: p_value = 1.8478e-05
#   F283: p_value = 2.8732e-05
#   F69: p_value = 3.1912e-05
#   F278: p_value = 3.7043e-05
#   F125: p_value = 4.0084e-05
#   F85: p_value = 6.8556e-05
#   F161: p_value = 8.5492e-05
#   F208: p_value = 1.3300e-04
#
# Class Pair: (2, 16)
#   F263: p_value = 8.0555e-05
#   F125: p_value = 2.3342e-04
#   F270: p_value = 4.0495e-04
#   F201: p_value = 4.6780e-04
#   F278: p_value = 5.8166e-04
#   F0: p_value = 8.2708e-04
#   F3: p_value = 9.4782e-04
#   F104: p_value = 1.0318e-03
#   F17: p_value = 1.0916e-03
#   F123: p_value = 1.6867e-03
#
# Class Pair: (2, 17)
#   F231: p_value = 1.4784e-06
#   F270: p_value = 2.5314e-06
#   F218: p_value = 2.8624e-06
#   F277: p_value = 2.6174e-05
#   F69: p_value = 2.8826e-05
#   F5: p_value = 3.3232e-05
#   F17: p_value = 5.2811e-05
#   F216: p_value = 7.4644e-05
#   F55: p_value = 9.9913e-05
#   F98: p_value = 1.0403e-04
#
# Class Pair: (2, 18)
#   F283: p_value = 2.4825e-05
#   F278: p_value = 4.6407e-05
#   F165: p_value = 1.2031e-04
#   F60: p_value = 1.9649e-04
#   F218: p_value = 2.7590e-04
#   F277: p_value = 3.8282e-04
#   F69: p_value = 4.2402e-04
#   F270: p_value = 4.6052e-04
#   F44: p_value = 6.3697e-04
#   F57: p_value = 8.1831e-04
#
# Class Pair: (2, 19)
#   F278: p_value = 7.1026e-06
#   F98: p_value = 5.9117e-04
#   F283: p_value = 8.1293e-04
#   F123: p_value = 1.1388e-03
#   F270: p_value = 1.3977e-03
#   F0: p_value = 2.7787e-03
#   F60: p_value = 2.8768e-03
#   F208: p_value = 3.4186e-03
#   F210: p_value = 3.6342e-03
#   F125: p_value = 3.7066e-03
#
# Class Pair: (2, 20)
#   F278: p_value = 4.7731e-05
#   F283: p_value = 8.1406e-04
#   F69: p_value = 2.1014e-03
#   F57: p_value = 2.2337e-03
#   F5: p_value = 3.4225e-03
#   F44: p_value = 4.2385e-03
#   F231: p_value = 5.4423e-03
#   F282: p_value = 1.1274e-02
#   F98: p_value = 1.4490e-02
#   F60: p_value = 1.4506e-02
#
# Class Pair: (2, 21)
#   F283: p_value = 2.6806e-05
#   F55: p_value = 1.3950e-04
#   F278: p_value = 3.5053e-04
#   F5: p_value = 6.0635e-04
#   F298: p_value = 7.7291e-04
#   F0: p_value = 8.6498e-04
#   F295: p_value = 1.5550e-03
#   F279: p_value = 1.8029e-03
#   F98: p_value = 2.0396e-03
#   F292: p_value = 2.2535e-03
#
# Class Pair: (2, 22)
#   F279: p_value = 1.6639e-06
#   F286: p_value = 2.7450e-04
#   F66: p_value = 1.6616e-03
#   F140: p_value = 1.9066e-03
#   F193: p_value = 2.9059e-03
#   F181: p_value = 3.0285e-03
#   F11: p_value = 3.1503e-03
#   F106: p_value = 3.2973e-03
#   F283: p_value = 4.5895e-03
#   F285: p_value = 4.7201e-03
#
# Class Pair: (2, 23)
#   F69: p_value = 1.6285e-06
#   F5: p_value = 1.2037e-04
#   F277: p_value = 1.2387e-04
#   F127: p_value = 2.0981e-04
#   F201: p_value = 2.4276e-04
#   F0: p_value = 5.1063e-04
#   F183: p_value = 5.2341e-04
#   F55: p_value = 5.5447e-04
#   F125: p_value = 6.3281e-04
#   F85: p_value = 7.7709e-04
#
# Class Pair: (2, 24)
#   F278: p_value = 7.0319e-05
#   F55: p_value = 5.6733e-04
#   F216: p_value = 1.1164e-03
#   F44: p_value = 1.5665e-03
#   F57: p_value = 2.0847e-03
#   F183: p_value = 2.3408e-03
#   F125: p_value = 3.4783e-03
#   F69: p_value = 3.8829e-03
#   F208: p_value = 3.9424e-03
#   F98: p_value = 4.1413e-03
#
# Class Pair: (2, 25)
#   F278: p_value = 1.0442e-04
#   F70: p_value = 1.6771e-03
#   F44: p_value = 8.2419e-03
#   F57: p_value = 9.8329e-03
#   F60: p_value = 1.1221e-02
#   F292: p_value = 1.3541e-02
#   F69: p_value = 1.6902e-02
#   F123: p_value = 1.7237e-02
#   F283: p_value = 1.8403e-02
#   F55: p_value = 1.9047e-02
#
# Class Pair: (2, 26)
#   F283: p_value = 1.0278e-04
#   F270: p_value = 1.3569e-04
#   F231: p_value = 1.6773e-04
#   F278: p_value = 1.7239e-04
#   F57: p_value = 5.2675e-04
#   F55: p_value = 5.2921e-04
#   F69: p_value = 1.2722e-03
#   F125: p_value = 1.5086e-03
#   F17: p_value = 2.2064e-03
#   F123: p_value = 2.6826e-03
#
# Class Pair: (2, 27)
#   F231: p_value = 4.5078e-07
#   F292: p_value = 3.7376e-06
#   F270: p_value = 2.1008e-05
#   F283: p_value = 2.4891e-05
#   F69: p_value = 2.9692e-05
#   F98: p_value = 5.4897e-05
#   F205: p_value = 7.2975e-04
#   F55: p_value = 7.7776e-04
#   F47: p_value = 7.8911e-04
#   F26: p_value = 8.3719e-04
#
# Class Pair: (3, 4)
#   F98: p_value = 6.3127e-19
#   F95: p_value = 4.6521e-16
#   F228: p_value = 2.5042e-14
#   F283: p_value = 3.0704e-14
#   F265: p_value = 1.6644e-13
#   F22: p_value = 2.7726e-13
#   F123: p_value = 3.0563e-13
#   F43: p_value = 7.0420e-13
#   F67: p_value = 7.2742e-13
#   F116: p_value = 1.2081e-12
#
# Class Pair: (3, 5)
#   F299: p_value = 7.2521e-27
#   F90: p_value = 1.7131e-25
#   F86: p_value = 1.6086e-24
#   F17: p_value = 5.8803e-23
#   F292: p_value = 1.8287e-22
#   F265: p_value = 1.4476e-21
#   F249: p_value = 3.7793e-21
#   F71: p_value = 4.0982e-20
#   F41: p_value = 5.9042e-20
#   F231: p_value = 7.2981e-20
#
# Class Pair: (3, 6)
#   F205: p_value = 1.4944e-36
#   F182: p_value = 2.0841e-32
#   F218: p_value = 2.4321e-29
#   F17: p_value = 2.0775e-28
#   F4: p_value = 4.3995e-26
#   F90: p_value = 1.6401e-25
#   F249: p_value = 1.7881e-25
#   F228: p_value = 5.6612e-25
#   F27: p_value = 2.4547e-24
#   F189: p_value = 6.1266e-24
#
# Class Pair: (3, 7)
#   F228: p_value = 1.1216e-20
#   F95: p_value = 1.4975e-19
#   F162: p_value = 1.1004e-18
#   F225: p_value = 6.0035e-18
#   F167: p_value = 1.5893e-17
#   F44: p_value = 1.4166e-16
#   F246: p_value = 4.7074e-16
#   F139: p_value = 1.9319e-15
#   F7: p_value = 4.9304e-14
#   F123: p_value = 4.2736e-13
#
# Class Pair: (3, 8)
#   F299: p_value = 3.5563e-17
#   F21: p_value = 5.5267e-14
#   F23: p_value = 7.5961e-14
#   F55: p_value = 1.8086e-12
#   F283: p_value = 2.3858e-12
#   F77: p_value = 3.5058e-12
#   F4: p_value = 1.6076e-11
#   F166: p_value = 7.9057e-11
#   F254: p_value = 8.0765e-11
#   F240: p_value = 8.5613e-11
#
# Class Pair: (3, 9)
#   F265: p_value = 1.0271e-13
#   F17: p_value = 3.9863e-13
#   F274: p_value = 1.1820e-11
#   F90: p_value = 1.3322e-11
#   F182: p_value = 1.3749e-11
#   F67: p_value = 1.5944e-11
#   F43: p_value = 2.1358e-11
#   F168: p_value = 2.5265e-11
#   F252: p_value = 3.7784e-11
#   F87: p_value = 8.3023e-11
#
# Class Pair: (3, 10)
#   F265: p_value = 6.6896e-21
#   F228: p_value = 9.8371e-21
#   F95: p_value = 3.5083e-20
#   F162: p_value = 5.9282e-18
#   F79: p_value = 3.1083e-16
#   F246: p_value = 4.0380e-16
#   F23: p_value = 4.6656e-16
#   F259: p_value = 5.6487e-16
#   F48: p_value = 8.3682e-16
#   F226: p_value = 1.1076e-14
#
# Class Pair: (3, 11)
#   F45: p_value = 6.4248e-23
#   F112: p_value = 1.3090e-21
#   F106: p_value = 5.2668e-21
#   F279: p_value = 7.8347e-21
#   F208: p_value = 1.0652e-20
#   F285: p_value = 5.6791e-20
#   F39: p_value = 8.0576e-19
#   F286: p_value = 1.9700e-18
#   F71: p_value = 4.4804e-18
#   F147: p_value = 6.3081e-18
#
# Class Pair: (3, 12)
#   F120: p_value = 1.0245e-09
#   F186: p_value = 3.8846e-09
#   F251: p_value = 7.8091e-09
#   F112: p_value = 1.1373e-08
#   F127: p_value = 1.4393e-08
#   F98: p_value = 3.0712e-08
#   F166: p_value = 3.8121e-08
#   F225: p_value = 1.1366e-07
#   F67: p_value = 2.9769e-07
#   F143: p_value = 3.3006e-07
#
# Class Pair: (3, 13)
#   F95: p_value = 4.5262e-07
#   F116: p_value = 6.5213e-06
#   F154: p_value = 6.7131e-06
#   F123: p_value = 1.1148e-05
#   F283: p_value = 2.5434e-05
#   F263: p_value = 3.1255e-05
#   F67: p_value = 4.4774e-05
#   F64: p_value = 4.4990e-05
#   F139: p_value = 4.5006e-05
#   F23: p_value = 5.3505e-05
#
# Class Pair: (3, 14)
#   F299: p_value = 4.4548e-31
#   F90: p_value = 2.8002e-29
#   F17: p_value = 2.9172e-29
#   F292: p_value = 5.7362e-24
#   F87: p_value = 3.9792e-23
#   F231: p_value = 9.2857e-23
#   F218: p_value = 2.2732e-21
#   F41: p_value = 1.3171e-20
#   F234: p_value = 1.6438e-20
#   F265: p_value = 2.2660e-20
#
# Class Pair: (3, 15)
#   F100: p_value = 7.6710e-12
#   F222: p_value = 2.9059e-10
#   F280: p_value = 3.9467e-10
#   F194: p_value = 1.1639e-09
#   F279: p_value = 1.8592e-09
#   F131: p_value = 3.1871e-09
#   F204: p_value = 1.1101e-08
#   F225: p_value = 1.5800e-08
#   F45: p_value = 6.6358e-08
#   F214: p_value = 9.0020e-08
#
# Class Pair: (3, 16)
#   F284: p_value = 1.4450e-07
#   F141: p_value = 2.2949e-06
#   F263: p_value = 2.7042e-05
#   F299: p_value = 1.6850e-04
#   F239: p_value = 1.8298e-04
#   F213: p_value = 1.9466e-04
#   F16: p_value = 2.6069e-04
#   F52: p_value = 5.7625e-04
#   F71: p_value = 7.0852e-04
#   F155: p_value = 8.6932e-04
#
# Class Pair: (3, 17)
#   F17: p_value = 2.0154e-31
#   F228: p_value = 1.2611e-26
#   F218: p_value = 1.3691e-26
#   F132: p_value = 7.7963e-25
#   F90: p_value = 3.6642e-24
#   F299: p_value = 1.0228e-22
#   F71: p_value = 2.7658e-21
#   F265: p_value = 2.7968e-21
#   F252: p_value = 4.2051e-21
#   F21: p_value = 2.7200e-20
#
# Class Pair: (3, 18)
#   F228: p_value = 7.9110e-19
#   F95: p_value = 1.9911e-15
#   F4: p_value = 3.0155e-15
#   F210: p_value = 1.4017e-12
#   F196: p_value = 6.7500e-12
#   F205: p_value = 1.5411e-10
#   F90: p_value = 3.2589e-10
#   F6: p_value = 4.6089e-10
#   F96: p_value = 8.3058e-10
#   F139: p_value = 2.2832e-09
#
# Class Pair: (3, 19)
#   F90: p_value = 2.9072e-13
#   F189: p_value = 2.5844e-11
#   F228: p_value = 3.7597e-11
#   F95: p_value = 1.3388e-10
#   F135: p_value = 1.9248e-09
#   F246: p_value = 2.4148e-09
#   F44: p_value = 3.5705e-09
#   F265: p_value = 8.1843e-09
#   F107: p_value = 1.6156e-08
#   F232: p_value = 1.6939e-07
#
# Class Pair: (3, 20)
#   F67: p_value = 1.3550e-13
#   F123: p_value = 5.3260e-11
#   F120: p_value = 1.1112e-10
#   F189: p_value = 8.9657e-10
#   F299: p_value = 1.4589e-09
#   F265: p_value = 4.4131e-09
#   F125: p_value = 3.4761e-08
#   F61: p_value = 3.6031e-08
#   F98: p_value = 4.3781e-08
#   F230: p_value = 5.9101e-08
#
# Class Pair: (3, 21)
#   F299: p_value = 1.1311e-16
#   F123: p_value = 8.2239e-15
#   F189: p_value = 1.5209e-14
#   F143: p_value = 7.0871e-13
#   F210: p_value = 1.2427e-12
#   F209: p_value = 1.5297e-12
#   F291: p_value = 1.3700e-11
#   F67: p_value = 1.8117e-11
#   F97: p_value = 3.0952e-11
#   F55: p_value = 7.0760e-11
#
# Class Pair: (3, 22)
#   F279: p_value = 6.0575e-07
#   F52: p_value = 2.4743e-05
#   F19: p_value = 3.7666e-05
#   F25: p_value = 4.5582e-05
#   F45: p_value = 1.3358e-04
#   F287: p_value = 1.4804e-04
#   F181: p_value = 6.6799e-04
#   F286: p_value = 8.9594e-04
#   F147: p_value = 9.2824e-04
#   F270: p_value = 1.0396e-03
#
# Class Pair: (3, 23)
#   F265: p_value = 1.7037e-25
#   F79: p_value = 1.0541e-19
#   F44: p_value = 7.4691e-18
#   F215: p_value = 1.8690e-15
#   F116: p_value = 1.2217e-14
#   F211: p_value = 9.2485e-14
#   F268: p_value = 1.1018e-13
#   F148: p_value = 2.7096e-13
#   F213: p_value = 8.7635e-13
#   F32: p_value = 1.4214e-12
#
# Class Pair: (3, 24)
#   F23: p_value = 3.2573e-16
#   F283: p_value = 7.2049e-13
#   F299: p_value = 1.4048e-12
#   F95: p_value = 3.9650e-12
#   F228: p_value = 6.3385e-11
#   F67: p_value = 2.1249e-10
#   F4: p_value = 3.3638e-09
#   F209: p_value = 3.4179e-09
#   F225: p_value = 4.3863e-09
#   F150: p_value = 3.5368e-08
#
# Class Pair: (3, 25)
#   F98: p_value = 3.2844e-17
#   F95: p_value = 5.8854e-14
#   F283: p_value = 4.6353e-12
#   F67: p_value = 6.3511e-12
#   F225: p_value = 1.7396e-10
#   F230: p_value = 2.0016e-09
#   F23: p_value = 4.0078e-08
#   F227: p_value = 4.3494e-08
#   F157: p_value = 8.7033e-08
#   F123: p_value = 1.2143e-07
#
# Class Pair: (3, 26)
#   F228: p_value = 3.6685e-10
#   F112: p_value = 7.4566e-10
#   F21: p_value = 1.2264e-09
#   F159: p_value = 1.5661e-09
#   F61: p_value = 3.2746e-09
#   F209: p_value = 4.3415e-09
#   F210: p_value = 6.9034e-09
#   F17: p_value = 1.5950e-08
#   F291: p_value = 2.9441e-08
#   F299: p_value = 6.9430e-08
#
# Class Pair: (3, 27)
#   F292: p_value = 1.9638e-28
#   F23: p_value = 3.8946e-28
#   F99: p_value = 6.8146e-22
#   F265: p_value = 9.1454e-22
#   F228: p_value = 5.0429e-21
#   F61: p_value = 1.4142e-20
#   F287: p_value = 9.8953e-20
#   F79: p_value = 3.1184e-19
#   F89: p_value = 2.6386e-18
#   F235: p_value = 2.6685e-18
#
# Class Pair: (4, 5)
#   F270: p_value = 2.5904e-115
#   F172: p_value = 4.0432e-105
#   F86: p_value = 2.1210e-93
#   F263: p_value = 3.7667e-93
#   F26: p_value = 5.1632e-93
#   F17: p_value = 7.7860e-93
#   F283: p_value = 5.3741e-86
#   F90: p_value = 2.7767e-85
#   F48: p_value = 1.4670e-78
#   F47: p_value = 8.3388e-76
#
# Class Pair: (4, 6)
#   F182: p_value = 5.4225e-136
#   F270: p_value = 1.0633e-134
#   F64: p_value = 2.7511e-124
#   F218: p_value = 1.7899e-120
#   F17: p_value = 1.4548e-118
#   F168: p_value = 2.7942e-108
#   F157: p_value = 8.3741e-105
#   F14: p_value = 3.2764e-98
#   F27: p_value = 1.3679e-97
#   F98: p_value = 3.0658e-94
#
# Class Pair: (4, 7)
#   F261: p_value = 5.8035e-22
#   F178: p_value = 9.6232e-22
#   F237: p_value = 9.1288e-20
#   F222: p_value = 6.8488e-19
#   F46: p_value = 3.7352e-18
#   F213: p_value = 5.8062e-18
#   F77: p_value = 9.6135e-18
#   F295: p_value = 1.5658e-17
#   F276: p_value = 3.6973e-17
#   F98: p_value = 1.0663e-16
#
# Class Pair: (4, 8)
#   F270: p_value = 3.3767e-74
#   F213: p_value = 1.0900e-66
#   F240: p_value = 1.3897e-58
#   F22: p_value = 2.2684e-49
#   F295: p_value = 7.8920e-46
#   F53: p_value = 1.9827e-45
#   F242: p_value = 6.8169e-45
#   F64: p_value = 1.3534e-42
#   F159: p_value = 1.7291e-41
#   F112: p_value = 3.7151e-41
#
# Class Pair: (4, 9)
#   F168: p_value = 3.9180e-15
#   F17: p_value = 2.4227e-13
#   F64: p_value = 6.7484e-13
#   F182: p_value = 1.8645e-12
#   F14: p_value = 3.3697e-12
#   F216: p_value = 8.3340e-12
#   F73: p_value = 2.7818e-11
#   F270: p_value = 4.3886e-11
#   F98: p_value = 6.7516e-11
#   F142: p_value = 1.7332e-10
#
# Class Pair: (4, 10)
#   F79: p_value = 1.2816e-40
#   F174: p_value = 1.7114e-40
#   F270: p_value = 5.7928e-40
#   F215: p_value = 1.5267e-37
#   F88: p_value = 1.2499e-36
#   F89: p_value = 8.2857e-33
#   F75: p_value = 6.0231e-32
#   F90: p_value = 1.3572e-30
#   F8: p_value = 4.7328e-30
#   F159: p_value = 7.5947e-30
#
# Class Pair: (4, 11)
#   F286: p_value = 2.3977e-30
#   F279: p_value = 2.6703e-29
#   F131: p_value = 1.6143e-27
#   F95: p_value = 5.6671e-27
#   F85: p_value = 1.3434e-26
#   F54: p_value = 2.9482e-26
#   F29: p_value = 5.4269e-26
#   F71: p_value = 6.2176e-26
#   F285: p_value = 9.9464e-26
#   F150: p_value = 2.7390e-24
#
# Class Pair: (4, 12)
#   F295: p_value = 1.4046e-35
#   F280: p_value = 2.1148e-33
#   F64: p_value = 3.6176e-32
#   F213: p_value = 6.5528e-30
#   F290: p_value = 7.1119e-30
#   F29: p_value = 1.5518e-29
#   F112: p_value = 1.7809e-29
#   F235: p_value = 2.8732e-29
#   F228: p_value = 4.7837e-29
#   F130: p_value = 3.4700e-28
#
# Class Pair: (4, 13)
#   F43: p_value = 1.6378e-09
#   F22: p_value = 2.0918e-07
#   F168: p_value = 3.0085e-07
#   F138: p_value = 9.8298e-07
#   F295: p_value = 2.9885e-06
#   F16: p_value = 3.0562e-06
#   F247: p_value = 3.1063e-06
#   F265: p_value = 6.8107e-06
#   F190: p_value = 6.9737e-06
#   F176: p_value = 9.4764e-06
#
# Class Pair: (4, 14)
#   F270: p_value = 3.5656e-105
#   F17: p_value = 5.5481e-100
#   F172: p_value = 1.0009e-87
#   F263: p_value = 6.9908e-85
#   F283: p_value = 3.3529e-77
#   F90: p_value = 6.9534e-68
#   F48: p_value = 9.8060e-67
#   F47: p_value = 2.3183e-65
#   F157: p_value = 2.7274e-64
#   F87: p_value = 4.5543e-64
#
# Class Pair: (4, 15)
#   F194: p_value = 1.0790e-15
#   F100: p_value = 2.1816e-14
#   F150: p_value = 1.7890e-13
#   F107: p_value = 1.4074e-11
#   F131: p_value = 1.7176e-11
#   F267: p_value = 3.1939e-11
#   F80: p_value = 7.7056e-11
#   F85: p_value = 1.5732e-10
#   F279: p_value = 1.6002e-10
#   F198: p_value = 2.4534e-10
#
# Class Pair: (4, 16)
#   F284: p_value = 1.2905e-09
#   F263: p_value = 1.1179e-06
#   F0: p_value = 4.7209e-06
#   F154: p_value = 2.3750e-04
#   F52: p_value = 3.3538e-04
#   F8: p_value = 3.4507e-04
#   F239: p_value = 7.1684e-04
#   F53: p_value = 7.4592e-04
#   F270: p_value = 9.0782e-04
#   F250: p_value = 1.0728e-03
#
# Class Pair: (4, 17)
#   F270: p_value = 4.5928e-125
#   F17: p_value = 1.2934e-111
#   F132: p_value = 3.2833e-82
#   F218: p_value = 3.8430e-77
#   F112: p_value = 1.5415e-70
#   F251: p_value = 1.9210e-63
#   F90: p_value = 1.9842e-62
#   F14: p_value = 2.4655e-60
#   F98: p_value = 2.9750e-60
#   F161: p_value = 5.4891e-58
#
# Class Pair: (4, 18)
#   F64: p_value = 1.8624e-20
#   F295: p_value = 2.1093e-16
#   F6: p_value = 4.8062e-15
#   F50: p_value = 6.4617e-14
#   F112: p_value = 8.0796e-14
#   F159: p_value = 8.2641e-14
#   F93: p_value = 1.1531e-13
#   F157: p_value = 6.6884e-13
#   F255: p_value = 1.0454e-12
#   F283: p_value = 2.3828e-12
#
# Class Pair: (4, 19)
#   F123: p_value = 7.4270e-27
#   F98: p_value = 2.4418e-23
#   F150: p_value = 6.8350e-23
#   F177: p_value = 3.3434e-22
#   F77: p_value = 1.7510e-19
#   F270: p_value = 3.5115e-19
#   F43: p_value = 3.6134e-19
#   F90: p_value = 1.0543e-18
#   F182: p_value = 3.9617e-18
#   F0: p_value = 4.3503e-18
#
# Class Pair: (4, 20)
#   F130: p_value = 6.5982e-19
#   F138: p_value = 8.0163e-19
#   F125: p_value = 4.5722e-17
#   F280: p_value = 5.5268e-17
#   F228: p_value = 7.7469e-17
#   F22: p_value = 1.0150e-15
#   F71: p_value = 1.4195e-15
#   F290: p_value = 2.9586e-13
#   F169: p_value = 6.0211e-13
#   F222: p_value = 1.1492e-12
#
# Class Pair: (4, 21)
#   F295: p_value = 2.1244e-56
#   F198: p_value = 1.5697e-38
#   F143: p_value = 3.3244e-38
#   F159: p_value = 2.3096e-36
#   F283: p_value = 5.3157e-35
#   F240: p_value = 3.1412e-33
#   F290: p_value = 4.8085e-33
#   F30: p_value = 5.7745e-33
#   F29: p_value = 3.2389e-32
#   F85: p_value = 6.6904e-32
#
# Class Pair: (4, 22)
#   F279: p_value = 2.7115e-06
#   F286: p_value = 2.7720e-04
#   F25: p_value = 3.2712e-04
#   F52: p_value = 9.6022e-04
#   F154: p_value = 1.0727e-03
#   F198: p_value = 1.2546e-03
#   F181: p_value = 1.2954e-03
#   F45: p_value = 1.4929e-03
#   F110: p_value = 1.5243e-03
#   F19: p_value = 1.9191e-03
#
# Class Pair: (4, 23)
#   F79: p_value = 5.4262e-19
#   F215: p_value = 2.1662e-17
#   F268: p_value = 1.5196e-16
#   F293: p_value = 1.5450e-16
#   F150: p_value = 3.4776e-16
#   F73: p_value = 2.6590e-15
#   F250: p_value = 6.0628e-15
#   F148: p_value = 3.6612e-14
#   F81: p_value = 7.7530e-14
#   F44: p_value = 1.1019e-13
#
# Class Pair: (4, 24)
#   F290: p_value = 2.4572e-36
#   F295: p_value = 1.1441e-27
#   F213: p_value = 5.1135e-25
#   F112: p_value = 5.9722e-22
#   F110: p_value = 1.2390e-21
#   F249: p_value = 6.1210e-19
#   F272: p_value = 1.3400e-18
#   F265: p_value = 2.1253e-18
#   F47: p_value = 1.5119e-17
#   F168: p_value = 9.0447e-17
#
# Class Pair: (4, 25)
#   F295: p_value = 2.9843e-22
#   F107: p_value = 1.5209e-16
#   F130: p_value = 2.5294e-15
#   F64: p_value = 4.3769e-13
#   F43: p_value = 8.4427e-13
#   F168: p_value = 1.0296e-12
#   F280: p_value = 1.7242e-11
#   F125: p_value = 3.7082e-10
#   F213: p_value = 5.0150e-10
#   F191: p_value = 8.6655e-10
#
# Class Pair: (4, 26)
#   F270: p_value = 2.6066e-45
#   F159: p_value = 1.2980e-38
#   F112: p_value = 7.3254e-32
#   F284: p_value = 1.6164e-30
#   F295: p_value = 5.7316e-29
#   F283: p_value = 2.3987e-28
#   F17: p_value = 6.1098e-27
#   F172: p_value = 3.6180e-26
#   F262: p_value = 2.8660e-25
#   F140: p_value = 7.8272e-24
#
# Class Pair: (4, 27)
#   F47: p_value = 1.1196e-44
#   F8: p_value = 1.0899e-40
#   F292: p_value = 1.7653e-38
#   F98: p_value = 1.2474e-37
#   F112: p_value = 3.5565e-35
#   F89: p_value = 3.8949e-35
#   F14: p_value = 1.1044e-34
#   F270: p_value = 1.4570e-33
#   F81: p_value = 1.7367e-31
#   F99: p_value = 7.3874e-30
#
# Class Pair: (5, 6)
#   F116: p_value = 8.0065e-196
#   F134: p_value = 9.3219e-189
#   F274: p_value = 6.9989e-175
#   F113: p_value = 6.7857e-164
#   F48: p_value = 1.0373e-154
#   F10: p_value = 2.3714e-143
#   F263: p_value = 7.1933e-143
#   F43: p_value = 4.7621e-140
#   F92: p_value = 2.0751e-131
#   F77: p_value = 1.6729e-126
#
# Class Pair: (5, 7)
#   F218: p_value = 4.0136e-49
#   F88: p_value = 1.6134e-46
#   F27: p_value = 5.1496e-46
#   F270: p_value = 5.8899e-45
#   F222: p_value = 9.5488e-44
#   F46: p_value = 8.0306e-42
#   F17: p_value = 1.0669e-41
#   F5: p_value = 4.8826e-39
#   F216: p_value = 7.2252e-39
#   F299: p_value = 1.0071e-38
#
# Class Pair: (5, 8)
#   F86: p_value = 1.5540e-233
#   F249: p_value = 6.3118e-229
#   F90: p_value = 7.8685e-191
#   F111: p_value = 1.1237e-185
#   F141: p_value = 2.0926e-182
#   F234: p_value = 1.0957e-181
#   F24: p_value = 1.0133e-171
#   F283: p_value = 1.5496e-170
#   F87: p_value = 7.8319e-166
#   F257: p_value = 1.2655e-164
#
# Class Pair: (5, 9)
#   F48: p_value = 7.5212e-12
#   F274: p_value = 1.0375e-09
#   F38: p_value = 1.3195e-09
#   F43: p_value = 2.0733e-09
#   F113: p_value = 6.9310e-09
#   F168: p_value = 1.1990e-08
#   F41: p_value = 1.5235e-08
#   F215: p_value = 1.6473e-08
#   F116: p_value = 2.2806e-08
#   F231: p_value = 3.0006e-08
#
# Class Pair: (5, 10)
#   F48: p_value = 0.0000e+00
#   F231: p_value = 0.0000e+00
#   F71: p_value = 0.0000e+00
#   F88: p_value = 0.0000e+00
#   F99: p_value = 0.0000e+00
#   F263: p_value = 0.0000e+00
#   F17: p_value = 0.0000e+00
#   F26: p_value = 0.0000e+00
#   F283: p_value = 0.0000e+00
#   F290: p_value = 1.2606e-317
#
# Class Pair: (5, 11)
#   F111: p_value = 4.4807e-36
#   F71: p_value = 5.0045e-34
#   F142: p_value = 7.0599e-32
#   F106: p_value = 2.3761e-30
#   F208: p_value = 3.5785e-30
#   F86: p_value = 3.7113e-29
#   F46: p_value = 2.4472e-28
#   F141: p_value = 8.3667e-28
#   F147: p_value = 1.4334e-26
#   F54: p_value = 2.6038e-25
#
# Class Pair: (5, 12)
#   F86: p_value = 1.5616e-166
#   F172: p_value = 4.7606e-166
#   F249: p_value = 4.3639e-155
#   F17: p_value = 5.3102e-155
#   F141: p_value = 1.7408e-153
#   F90: p_value = 3.9358e-148
#   F111: p_value = 1.2328e-142
#   F270: p_value = 5.6426e-135
#   F218: p_value = 6.1907e-135
#   F46: p_value = 1.9624e-130
#
# Class Pair: (5, 13)
#   F172: p_value = 1.4570e-27
#   F17: p_value = 5.6719e-25
#   F270: p_value = 6.7951e-25
#   F263: p_value = 7.0222e-21
#   F87: p_value = 1.6381e-20
#   F90: p_value = 1.4627e-19
#   F48: p_value = 1.0133e-18
#   F63: p_value = 3.4534e-18
#   F218: p_value = 3.6191e-18
#   F249: p_value = 3.8875e-18
#
# Class Pair: (5, 14)
#   F140: p_value = 5.7643e-19
#   F279: p_value = 8.1540e-13
#   F86: p_value = 2.8280e-10
#   F105: p_value = 4.5660e-10
#   F7: p_value = 2.4397e-09
#   F249: p_value = 4.7629e-09
#   F55: p_value = 4.1682e-08
#   F155: p_value = 7.5171e-08
#   F133: p_value = 7.7276e-08
#   F17: p_value = 9.0556e-08
#
# Class Pair: (5, 15)
#   F270: p_value = 2.1926e-15
#   F90: p_value = 8.5671e-14
#   F111: p_value = 1.7808e-13
#   F194: p_value = 3.2127e-13
#   F249: p_value = 1.7393e-12
#   F133: p_value = 5.3361e-12
#   F46: p_value = 1.6474e-11
#   F71: p_value = 2.2539e-11
#   F222: p_value = 3.0643e-11
#   F172: p_value = 3.4435e-11
#
# Class Pair: (5, 16)
#   F63: p_value = 1.5541e-04
#   F239: p_value = 2.1768e-04
#   F284: p_value = 5.9789e-04
#   F16: p_value = 6.1294e-04
#   F216: p_value = 8.2480e-04
#   F92: p_value = 1.0241e-03
#   F72: p_value = 1.3769e-03
#   F111: p_value = 2.2425e-03
#   F299: p_value = 2.5082e-03
#   F76: p_value = 4.1296e-03
#
# Class Pair: (5, 17)
#   F116: p_value = 1.5142e-73
#   F69: p_value = 1.7944e-65
#   F50: p_value = 1.2916e-58
#   F172: p_value = 4.0938e-58
#   F283: p_value = 1.6388e-57
#   F99: p_value = 2.0224e-57
#   F263: p_value = 9.2088e-52
#   F257: p_value = 4.4858e-50
#   F101: p_value = 7.0657e-50
#   F140: p_value = 2.0512e-49
#
# Class Pair: (5, 18)
#   F134: p_value = 1.8052e-26
#   F111: p_value = 4.2473e-26
#   F71: p_value = 1.6685e-25
#   F155: p_value = 1.3720e-23
#   F141: p_value = 1.4925e-23
#   F10: p_value = 8.2644e-22
#   F299: p_value = 9.1404e-22
#   F88: p_value = 7.2818e-21
#   F231: p_value = 7.4216e-21
#   F207: p_value = 2.3399e-20
#
# Class Pair: (5, 19)
#   F17: p_value = 1.7490e-71
#   F88: p_value = 6.6064e-65
#   F86: p_value = 6.4619e-52
#   F249: p_value = 7.0532e-52
#   F172: p_value = 9.4202e-52
#   F27: p_value = 1.9898e-50
#   F231: p_value = 2.5215e-50
#   F232: p_value = 4.9359e-50
#   F41: p_value = 5.0691e-50
#   F292: p_value = 1.1114e-48
#
# Class Pair: (5, 20)
#   F90: p_value = 2.5676e-58
#   F270: p_value = 2.4080e-56
#   F172: p_value = 3.4017e-55
#   F86: p_value = 3.7743e-52
#   F263: p_value = 6.7413e-52
#   F17: p_value = 3.1653e-51
#   F71: p_value = 5.4175e-51
#   F124: p_value = 7.3744e-49
#   F26: p_value = 8.9505e-49
#   F230: p_value = 1.0489e-48
#
# Class Pair: (5, 21)
#   F86: p_value = 3.7060e-107
#   F249: p_value = 6.9321e-106
#   F270: p_value = 6.6152e-99
#   F234: p_value = 9.8750e-95
#   F90: p_value = 2.6917e-94
#   F263: p_value = 9.7913e-94
#   F46: p_value = 7.8045e-91
#   F172: p_value = 1.0013e-86
#   F101: p_value = 2.9420e-85
#   F71: p_value = 2.4887e-84
#
# Class Pair: (5, 22)
#   F52: p_value = 6.9762e-06
#   F270: p_value = 2.3850e-05
#   F279: p_value = 5.0852e-05
#   F19: p_value = 5.8891e-05
#   F25: p_value = 1.1801e-04
#   F142: p_value = 2.5144e-04
#   F141: p_value = 4.5139e-04
#   F147: p_value = 5.3230e-04
#   F181: p_value = 5.4764e-04
#   F28: p_value = 5.5157e-04
#
# Class Pair: (5, 23)
#   F88: p_value = 6.1660e-19
#   F218: p_value = 3.2890e-18
#   F116: p_value = 1.3329e-17
#   F245: p_value = 5.5129e-17
#   F232: p_value = 1.3128e-15
#   F17: p_value = 4.3074e-15
#   F270: p_value = 3.7815e-14
#   F211: p_value = 6.1451e-14
#   F240: p_value = 8.7218e-14
#   F28: p_value = 1.1576e-13
#
# Class Pair: (5, 24)
#   F270: p_value = 4.8039e-155
#   F249: p_value = 1.4964e-146
#   F111: p_value = 4.6569e-141
#   F283: p_value = 5.1223e-137
#   F90: p_value = 1.0011e-136
#   F86: p_value = 4.4045e-135
#   F234: p_value = 1.9230e-124
#   F172: p_value = 5.6180e-122
#   F63: p_value = 2.4018e-120
#   F182: p_value = 1.3827e-116
#
# Class Pair: (5, 25)
#   F17: p_value = 1.3614e-80
#   F270: p_value = 7.4372e-75
#   F172: p_value = 2.2476e-73
#   F230: p_value = 2.4158e-70
#   F90: p_value = 9.9754e-69
#   F283: p_value = 1.0549e-62
#   F249: p_value = 3.2680e-59
#   F5: p_value = 3.4567e-59
#   F87: p_value = 9.1692e-58
#   F47: p_value = 6.9362e-56
#
# Class Pair: (5, 26)
#   F90: p_value = 1.2674e-90
#   F249: p_value = 5.6862e-88
#   F111: p_value = 2.1180e-87
#   F5: p_value = 2.5321e-82
#   F46: p_value = 2.3429e-75
#   F141: p_value = 1.2401e-70
#   F234: p_value = 8.8427e-69
#   F299: p_value = 5.9111e-66
#   F99: p_value = 4.3247e-65
#   F71: p_value = 8.6481e-63
#
# Class Pair: (5, 27)
#   F99: p_value = 1.4742e-60
#   F71: p_value = 3.9119e-47
#   F111: p_value = 7.4503e-46
#   F48: p_value = 3.9763e-44
#   F46: p_value = 7.4855e-42
#   F5: p_value = 9.8788e-42
#   F222: p_value = 1.5784e-41
#   F118: p_value = 4.1030e-41
#   F85: p_value = 1.7759e-34
#   F287: p_value = 7.0975e-34
#
# Class Pair: (6, 7)
#   F218: p_value = 5.5420e-82
#   F27: p_value = 8.5482e-76
#   F88: p_value = 9.3713e-59
#   F77: p_value = 4.0220e-58
#   F46: p_value = 2.1400e-56
#   F17: p_value = 6.0304e-53
#   F64: p_value = 4.9229e-52
#   F270: p_value = 8.0323e-52
#   F261: p_value = 2.0111e-51
#   F157: p_value = 8.4362e-51
#
# Class Pair: (6, 8)
#   F182: p_value = 1.4768e-224
#   F205: p_value = 8.4700e-211
#   F249: p_value = 3.2638e-195
#   F76: p_value = 1.1818e-191
#   F274: p_value = 2.7847e-181
#   F61: p_value = 2.2189e-175
#   F189: p_value = 1.7353e-166
#   F238: p_value = 1.6536e-163
#   F216: p_value = 1.8385e-157
#   F17: p_value = 1.0633e-155
#
# Class Pair: (6, 9)
#   F175: p_value = 2.8279e-03
#   F260: p_value = 5.5395e-03
#   F245: p_value = 9.9576e-03
#   F291: p_value = 1.1371e-02
#   F170: p_value = 2.4252e-02
#   F75: p_value = 2.4529e-02
#   F9: p_value = 3.0148e-02
#   F256: p_value = 3.3122e-02
#   F177: p_value = 3.3501e-02
#   F25: p_value = 3.8519e-02
#
# Class Pair: (6, 10)
#   F17: p_value = 1.0936e-287
#   F88: p_value = 4.6377e-205
#   F157: p_value = 2.7948e-202
#   F27: p_value = 1.5079e-192
#   F240: p_value = 7.7234e-191
#   F218: p_value = 4.5427e-190
#   F14: p_value = 4.0507e-186
#   F182: p_value = 1.2373e-173
#   F64: p_value = 1.9622e-171
#   F144: p_value = 2.6415e-171
#
# Class Pair: (6, 11)
#   F205: p_value = 5.6260e-43
#   F182: p_value = 1.9710e-39
#   F46: p_value = 7.2966e-39
#   F111: p_value = 2.4697e-33
#   F142: p_value = 4.2173e-33
#   F146: p_value = 5.3989e-32
#   F228: p_value = 8.5036e-32
#   F218: p_value = 2.6609e-31
#   F279: p_value = 2.3485e-30
#   F274: p_value = 7.2502e-30
#
# Class Pair: (6, 12)
#   F17: p_value = 6.7725e-178
#   F218: p_value = 2.2554e-172
#   F182: p_value = 2.2989e-164
#   F205: p_value = 1.2933e-154
#   F59: p_value = 3.5710e-146
#   F249: p_value = 6.1315e-144
#   F75: p_value = 3.6190e-131
#   F274: p_value = 1.8541e-130
#   F270: p_value = 7.2738e-129
#   F146: p_value = 1.4695e-126
#
# Class Pair: (6, 13)
#   F64: p_value = 2.0011e-32
#   F182: p_value = 4.8192e-31
#   F218: p_value = 1.1136e-29
#   F17: p_value = 1.8172e-29
#   F270: p_value = 4.6766e-27
#   F249: p_value = 7.9766e-23
#   F205: p_value = 1.4006e-22
#   F14: p_value = 2.2155e-22
#   F46: p_value = 2.6909e-22
#   F27: p_value = 4.9392e-22
#
# Class Pair: (6, 14)
#   F274: p_value = 1.1496e-84
#   F113: p_value = 2.0158e-72
#   F48: p_value = 6.3296e-72
#   F64: p_value = 1.2558e-69
#   F264: p_value = 1.4813e-69
#   F43: p_value = 3.4959e-69
#   F38: p_value = 6.6319e-69
#   F77: p_value = 2.0040e-68
#   F92: p_value = 5.0588e-68
#   F168: p_value = 9.1917e-67
#
# Class Pair: (6, 15)
#   F270: p_value = 3.2206e-17
#   F182: p_value = 2.8373e-15
#   F205: p_value = 1.4263e-14
#   F249: p_value = 1.6946e-14
#   F146: p_value = 2.0794e-14
#   F90: p_value = 5.6851e-14
#   F218: p_value = 6.9788e-14
#   F46: p_value = 1.3277e-13
#   F17: p_value = 2.3014e-13
#   F189: p_value = 1.1661e-12
#
# Class Pair: (6, 16)
#   F239: p_value = 3.8879e-06
#   F72: p_value = 4.4587e-05
# ...
#   F234: p_value = 1.5194e-80
#   F133: p_value = 1.7167e-76
#   F71: p_value = 3.1059e-73
#   F90: p_value = 1.3332e-66
#   F89: p_value = 4.4536e-66
#   F6: p_value = 1.0069e-64
#   F265: p_value = 6.5658e-64
#   F122: p_value = 6.7325e-64
#   F146: p_value = 6.1175e-63
#
# Class Pair: (17, 22)
#   F52: p_value = 6.0458e-06
#   F270: p_value = 8.8929e-06
#   F19: p_value = 5.5602e-05
#   F25: p_value = 6.4554e-05
#   F279: p_value = 1.7313e-04
#   F147: p_value = 2.9517e-04
#   F142: p_value = 3.3768e-04
#   F28: p_value = 3.7404e-04
#   F15: p_value = 4.7812e-04
#   F181: p_value = 4.8209e-04
#
# Class Pair: (17, 23)
#   F218: p_value = 3.5552e-24
#   F88: p_value = 6.6844e-22
#   F17: p_value = 9.6098e-20
#   F245: p_value = 1.0199e-19
#   F32: p_value = 1.0996e-17
#   F211: p_value = 1.3299e-17
#   F268: p_value = 5.8083e-16
#   F179: p_value = 7.5868e-16
#   F72: p_value = 1.5527e-15
#   F270: p_value = 1.6683e-15
#
# Class Pair: (17, 24)
#   F270: p_value = 1.3635e-121
#   F17: p_value = 1.5901e-109
#   F90: p_value = 8.7614e-84
#   F234: p_value = 1.4035e-83
#   F285: p_value = 1.6384e-83
#   F87: p_value = 1.1309e-80
#   F216: p_value = 2.3952e-80
#   F214: p_value = 7.7695e-79
#   F132: p_value = 6.7661e-77
#   F111: p_value = 1.2398e-73
#
# Class Pair: (17, 25)
#   F17: p_value = 2.7017e-106
#   F270: p_value = 1.8037e-82
#   F218: p_value = 2.1554e-68
#   F230: p_value = 8.5029e-62
#   F87: p_value = 1.3286e-58
#   F90: p_value = 1.3050e-55
#   F214: p_value = 3.8808e-50
#   F55: p_value = 1.2753e-49
#   F98: p_value = 2.6979e-48
#   F38: p_value = 9.9452e-46
#
# Class Pair: (17, 26)
#   F214: p_value = 9.1493e-66
#   F76: p_value = 1.0850e-59
#   F132: p_value = 5.2882e-57
#   F218: p_value = 1.6615e-56
#   F122: p_value = 1.2987e-54
#   F90: p_value = 7.8859e-54
#   F234: p_value = 3.5628e-53
#   F17: p_value = 9.6722e-52
#   F111: p_value = 1.1563e-50
#   F71: p_value = 2.4190e-50
#
# Class Pair: (17, 27)
#   F71: p_value = 5.0925e-53
#   F218: p_value = 4.0202e-46
#   F111: p_value = 8.8928e-46
#   F99: p_value = 8.8847e-45
#   F118: p_value = 4.9895e-43
#   F171: p_value = 9.8376e-40
#   F76: p_value = 1.1458e-39
#   F46: p_value = 2.9937e-34
#   F5: p_value = 1.1309e-33
#   F251: p_value = 5.5109e-32
#
# Class Pair: (18, 19)
#   F210: p_value = 4.2728e-21
#   F134: p_value = 1.9153e-16
#   F254: p_value = 3.8846e-16
#   F65: p_value = 8.8501e-16
#   F155: p_value = 1.1318e-15
#   F6: p_value = 8.3490e-15
#   F27: p_value = 4.0799e-12
#   F64: p_value = 6.5040e-12
#   F207: p_value = 1.2497e-11
#   F194: p_value = 3.6721e-11
#
# Class Pair: (18, 20)
#   F228: p_value = 1.7154e-18
#   F59: p_value = 2.6956e-16
#   F222: p_value = 8.1337e-16
#   F294: p_value = 1.4703e-14
#   F6: p_value = 3.6836e-14
#   F159: p_value = 7.1743e-14
#   F155: p_value = 2.0415e-13
#   F4: p_value = 2.3439e-13
#   F165: p_value = 9.0690e-13
#   F205: p_value = 1.0410e-12
#
# Class Pair: (18, 21)
#   F59: p_value = 8.1346e-20
#   F143: p_value = 1.6244e-19
#   F147: p_value = 4.5549e-19
#   F268: p_value = 9.1950e-17
#   F215: p_value = 1.8521e-16
#   F240: p_value = 2.3073e-16
#   F6: p_value = 1.1431e-15
#   F60: p_value = 1.7890e-15
#   F165: p_value = 2.0276e-15
#   F196: p_value = 2.6018e-15
#
# Class Pair: (18, 22)
#   F279: p_value = 1.1225e-07
#   F52: p_value = 1.3265e-06
#   F147: p_value = 3.9110e-05
#   F25: p_value = 5.3210e-05
#   F196: p_value = 5.0108e-04
#   F19: p_value = 5.0435e-04
#   F276: p_value = 6.1925e-04
#   F114: p_value = 6.5309e-04
#   F268: p_value = 8.8968e-04
#   F286: p_value = 1.1522e-03
#
# Class Pair: (18, 23)
#   F215: p_value = 1.3250e-19
#   F165: p_value = 6.0744e-19
#   F44: p_value = 1.2723e-15
#   F254: p_value = 1.2599e-14
#   F265: p_value = 1.0647e-13
#   F134: p_value = 4.4011e-13
#   F211: p_value = 1.0876e-12
#   F64: p_value = 1.3457e-12
#   F148: p_value = 1.3850e-12
#   F218: p_value = 4.6192e-12
#
# Class Pair: (18, 24)
#   F205: p_value = 7.9573e-16
#   F93: p_value = 1.9265e-13
#   F255: p_value = 9.2578e-13
#   F196: p_value = 1.1943e-12
#   F90: p_value = 2.7548e-12
#   F268: p_value = 1.1248e-11
#   F149: p_value = 1.4048e-11
#   F6: p_value = 3.7399e-11
#   F283: p_value = 5.5737e-11
#   F155: p_value = 1.0429e-10
#
# Class Pair: (18, 25)
#   F155: p_value = 2.0659e-15
#   F228: p_value = 5.8946e-14
#   F6: p_value = 2.0351e-13
#   F4: p_value = 4.0486e-13
#   F59: p_value = 7.7600e-13
#   F210: p_value = 1.8822e-12
#   F159: p_value = 1.9129e-11
#   F78: p_value = 2.5987e-11
#   F294: p_value = 2.8685e-11
#   F254: p_value = 1.3649e-10
#
# Class Pair: (18, 26)
#   F1: p_value = 4.5459e-14
#   F207: p_value = 3.1649e-13
#   F196: p_value = 1.4329e-12
#   F254: p_value = 2.4373e-12
#   F60: p_value = 2.8089e-12
#   F96: p_value = 3.7672e-12
#   F93: p_value = 6.2717e-12
#   F231: p_value = 6.9827e-12
#   F205: p_value = 4.0287e-11
#   F240: p_value = 4.6743e-11
#
# Class Pair: (18, 27)
#   F207: p_value = 4.1805e-26
#   F47: p_value = 8.5128e-23
#   F99: p_value = 9.7563e-21
#   F292: p_value = 7.7504e-20
#   F259: p_value = 2.0414e-19
#   F8: p_value = 4.6031e-19
#   F231: p_value = 5.5927e-17
#   F60: p_value = 8.4180e-17
#   F247: p_value = 1.5972e-16
#   F65: p_value = 3.7162e-16
#
# Class Pair: (19, 20)
#   F59: p_value = 8.5941e-21
#   F88: p_value = 9.5614e-18
#   F67: p_value = 1.5425e-17
#   F123: p_value = 2.6508e-17
#   F79: p_value = 3.8885e-17
#   F268: p_value = 6.2969e-17
#   F90: p_value = 1.0210e-16
#   F170: p_value = 1.5198e-14
#   F212: p_value = 2.0404e-14
#   F107: p_value = 5.0456e-14
#
# Class Pair: (19, 21)
#   F200: p_value = 1.2578e-41
#   F101: p_value = 7.1288e-38
#   F268: p_value = 1.1744e-36
#   F240: p_value = 2.4017e-33
#   F123: p_value = 1.5379e-31
#   F239: p_value = 5.5610e-31
#   F210: p_value = 4.6682e-30
#   F223: p_value = 5.7727e-30
#   F59: p_value = 4.1666e-29
#   F55: p_value = 4.0904e-27
#
# Class Pair: (19, 22)
#   F279: p_value = 1.7548e-06
#   F52: p_value = 1.7858e-05
#   F25: p_value = 2.0016e-04
#   F19: p_value = 5.2016e-04
#   F210: p_value = 5.5102e-04
#   F107: p_value = 6.2389e-04
#   F286: p_value = 6.3071e-04
#   F193: p_value = 9.6067e-04
#   F268: p_value = 1.2339e-03
#   F142: p_value = 1.3533e-03
#
# Class Pair: (19, 23)
#   F265: p_value = 1.1863e-16
#   F165: p_value = 1.6871e-15
#   F116: p_value = 5.1765e-13
#   F79: p_value = 7.5765e-13
#   F241: p_value = 2.3106e-12
#   F148: p_value = 2.5418e-12
#   F31: p_value = 3.7494e-12
#   F32: p_value = 2.7882e-11
#   F247: p_value = 4.9985e-11
#   F6: p_value = 1.0304e-10
#
# Class Pair: (19, 24)
#   F90: p_value = 2.1818e-25
#   F65: p_value = 6.5356e-25
#   F268: p_value = 2.5611e-24
#   F254: p_value = 5.2029e-24
#   F24: p_value = 8.6316e-22
#   F55: p_value = 2.2552e-20
#   F276: p_value = 5.8998e-19
#   F101: p_value = 4.7329e-18
#   F150: p_value = 9.2738e-18
#   F293: p_value = 1.5442e-17
#
# Class Pair: (19, 25)
#   F98: p_value = 1.0213e-19
#   F107: p_value = 1.5294e-19
#   F178: p_value = 2.7711e-18
#   F90: p_value = 3.9728e-18
#   F164: p_value = 5.6448e-18
#   F59: p_value = 1.6713e-16
#   F227: p_value = 2.6158e-16
#   F177: p_value = 7.6073e-15
#   F24: p_value = 2.0868e-14
#   F67: p_value = 6.5255e-14
#
# Class Pair: (19, 26)
#   F17: p_value = 6.5472e-29
#   F88: p_value = 2.3399e-26
#   F274: p_value = 2.3975e-23
#   F232: p_value = 3.9871e-21
#   F210: p_value = 6.3751e-21
#   F55: p_value = 8.7599e-20
#   F112: p_value = 9.8508e-20
#   F242: p_value = 1.5473e-19
#   F240: p_value = 3.0147e-19
#   F231: p_value = 1.7258e-17
#
# Class Pair: (19, 27)
#   F292: p_value = 9.2587e-37
#   F99: p_value = 1.4583e-34
#   F247: p_value = 3.5933e-32
#   F287: p_value = 9.6513e-29
#   F112: p_value = 2.0273e-28
#   F23: p_value = 1.6250e-26
#   F92: p_value = 3.4598e-26
#   F17: p_value = 1.9228e-24
#   F231: p_value = 1.1363e-23
#   F274: p_value = 1.4342e-23
#
# Class Pair: (20, 21)
#   F159: p_value = 1.4290e-29
#   F55: p_value = 1.0877e-21
#   F82: p_value = 8.6427e-20
#   F198: p_value = 2.5513e-19
#   F37: p_value = 2.6734e-19
#   F240: p_value = 1.2115e-18
#   F223: p_value = 3.3083e-18
#   F66: p_value = 4.5721e-17
#   F224: p_value = 1.6358e-16
#   F212: p_value = 3.3647e-16
#
# Class Pair: (20, 22)
#   F279: p_value = 2.6633e-06
#   F25: p_value = 5.5327e-04
#   F52: p_value = 6.5492e-04
#   F181: p_value = 7.7062e-04
#   F256: p_value = 9.1968e-04
#   F19: p_value = 1.5866e-03
#   F286: p_value = 2.1463e-03
#   F45: p_value = 2.2200e-03
#   F66: p_value = 3.1925e-03
#   F287: p_value = 3.5243e-03
#
# Class Pair: (20, 23)
#   F79: p_value = 4.4451e-30
#   F268: p_value = 8.4952e-21
#   F265: p_value = 1.1445e-16
#   F148: p_value = 2.1213e-16
#   F293: p_value = 4.9231e-16
#   F87: p_value = 9.5449e-16
#   F250: p_value = 9.7731e-16
#   F32: p_value = 1.8073e-14
#   F44: p_value = 7.0594e-14
#   F245: p_value = 7.6931e-14
#
# Class Pair: (20, 24)
#   F208: p_value = 5.1163e-16
#   F125: p_value = 1.6080e-15
#   F55: p_value = 1.1799e-14
#   F254: p_value = 5.3726e-14
#   F159: p_value = 3.1143e-13
#   F259: p_value = 3.5695e-13
#   F276: p_value = 4.6212e-13
#   F228: p_value = 1.3571e-12
#   F216: p_value = 3.0353e-12
#   F207: p_value = 1.0160e-11
#
# Class Pair: (20, 25)
#   F106: p_value = 6.6255e-12
#   F70: p_value = 1.8699e-10
#   F109: p_value = 5.4883e-08
#   F222: p_value = 9.0113e-08
#   F5: p_value = 3.6934e-07
#   F143: p_value = 7.9919e-07
#   F71: p_value = 1.2974e-06
#   F36: p_value = 1.4406e-06
#   F110: p_value = 2.3138e-06
#   F212: p_value = 2.6315e-06
#
# Class Pair: (20, 26)
#   F159: p_value = 1.4230e-31
#   F125: p_value = 3.7141e-24
#   F227: p_value = 1.4385e-20
#   F270: p_value = 7.0301e-20
#   F17: p_value = 3.4937e-15
#   F294: p_value = 3.9693e-15
#   F195: p_value = 2.7287e-14
#   F79: p_value = 3.3478e-14
#   F155: p_value = 3.7356e-14
#   F55: p_value = 6.7266e-14
#
# Class Pair: (20, 27)
#   F79: p_value = 5.5914e-42
#   F222: p_value = 3.0955e-38
#   F89: p_value = 1.1454e-36
#   F47: p_value = 9.1809e-35
#   F230: p_value = 8.3882e-33
#   F171: p_value = 3.0811e-32
#   F130: p_value = 1.4955e-29
#   F8: p_value = 1.8553e-28
#   F228: p_value = 7.2025e-28
#   F292: p_value = 2.8244e-27
#
# Class Pair: (21, 22)
#   F52: p_value = 2.7447e-05
#   F279: p_value = 1.0109e-04
#   F15: p_value = 1.0634e-03
#   F19: p_value = 1.3413e-03
#   F234: p_value = 1.8379e-03
#   F25: p_value = 2.2094e-03
#   F45: p_value = 6.0623e-03
#   F286: p_value = 6.6397e-03
#   F91: p_value = 8.1634e-03
#   F156: p_value = 8.5742e-03
#
# Class Pair: (21, 23)
#   F79: p_value = 1.3786e-27
#   F265: p_value = 6.3767e-24
#   F268: p_value = 5.1396e-23
#   F242: p_value = 3.6790e-17
#   F240: p_value = 1.7821e-15
#   F107: p_value = 1.2501e-14
#   F245: p_value = 3.2978e-14
#   F32: p_value = 4.0701e-14
#   F293: p_value = 5.9015e-14
#   F143: p_value = 7.0804e-14
#
# Class Pair: (21, 24)
#   F200: p_value = 1.2528e-47
#   F285: p_value = 3.5537e-39
#   F239: p_value = 5.4355e-39
#   F85: p_value = 1.3119e-36
#   F283: p_value = 3.1617e-36
#   F271: p_value = 8.9678e-33
#   F175: p_value = 1.5126e-28
#   F189: p_value = 1.8540e-28
#   F267: p_value = 2.2997e-28
#   F49: p_value = 1.6044e-27
#
# Class Pair: (21, 25)
#   F240: p_value = 4.1908e-37
#   F143: p_value = 7.0239e-33
#   F17: p_value = 1.3211e-30
#   F227: p_value = 9.1623e-29
#   F223: p_value = 1.9362e-28
#   F159: p_value = 2.0179e-27
#   F55: p_value = 2.1098e-27
#   F39: p_value = 2.9253e-27
#   F283: p_value = 2.5636e-26
#   F198: p_value = 3.4982e-26
#
# Class Pair: (21, 26)
#   F175: p_value = 1.5412e-35
#   F239: p_value = 1.5517e-31
#   F133: p_value = 1.0300e-30
#   F25: p_value = 2.6113e-27
#   F123: p_value = 6.6592e-27
#   F79: p_value = 1.2840e-25
#   F16: p_value = 2.8729e-24
#   F195: p_value = 3.9387e-23
#   F143: p_value = 2.6266e-21
#   F147: p_value = 2.2052e-20
#
# Class Pair: (21, 27)
#   F79: p_value = 5.4459e-52
#   F118: p_value = 1.7003e-49
#   F99: p_value = 1.8919e-49
#   F268: p_value = 3.5760e-45
#   F89: p_value = 5.4023e-43
#   F101: p_value = 4.0584e-40
#   F143: p_value = 4.4840e-40
#   F265: p_value = 4.9521e-39
#   F130: p_value = 5.6415e-38
#   F37: p_value = 8.2059e-38
#
# Class Pair: (22, 23)
#   F279: p_value = 4.0528e-08
#   F52: p_value = 1.2616e-05
#   F107: p_value = 1.9706e-05
#   F25: p_value = 2.4959e-05
#   F268: p_value = 7.8040e-05
#   F140: p_value = 1.7267e-04
#   F245: p_value = 2.0668e-04
#   F193: p_value = 2.3609e-04
#   F19: p_value = 2.7845e-04
#   F286: p_value = 3.2107e-04
#
# Class Pair: (22, 24)
#   F279: p_value = 9.2932e-06
#   F52: p_value = 6.2858e-05
#   F25: p_value = 1.4017e-04
#   F286: p_value = 5.4211e-04
#   F19: p_value = 8.4271e-04
#   F256: p_value = 1.4863e-03
#   F156: p_value = 1.8632e-03
#   F276: p_value = 1.9855e-03
#   F181: p_value = 2.5338e-03
#   F147: p_value = 2.7589e-03
#
# Class Pair: (22, 25)
#   F279: p_value = 2.8501e-06
#   F52: p_value = 4.1598e-05
#   F25: p_value = 2.9708e-04
#   F19: p_value = 7.4512e-04
#   F286: p_value = 1.1039e-03
#   F193: p_value = 1.4083e-03
#   F181: p_value = 1.4512e-03
#   F45: p_value = 1.8974e-03
#   F106: p_value = 1.9121e-03
#   F110: p_value = 2.1970e-03
#
# Class Pair: (22, 26)
#   F279: p_value = 1.7848e-05
#   F52: p_value = 1.9459e-05
#   F25: p_value = 9.4883e-05
#   F270: p_value = 5.8117e-04
#   F19: p_value = 7.4658e-04
#   F181: p_value = 1.1730e-03
#   F286: p_value = 1.8626e-03
#   F102: p_value = 2.5692e-03
#   F256: p_value = 2.8158e-03
#   F147: p_value = 3.3006e-03
#
# Class Pair: (22, 27)
#   F279: p_value = 5.0783e-06
#   F25: p_value = 7.0250e-06
#   F19: p_value = 4.4641e-05
#   F270: p_value = 1.1987e-04
#   F89: p_value = 1.5175e-04
#   F244: p_value = 2.3056e-04
#   F286: p_value = 2.6453e-04
#   F268: p_value = 3.0412e-04
#   F142: p_value = 4.2690e-04
#   F171: p_value = 4.5224e-04
#
# Class Pair: (23, 24)
#   F265: p_value = 7.3957e-22
#   F79: p_value = 1.4641e-20
#   F268: p_value = 2.4192e-19
#   F293: p_value = 6.3204e-19
#   F32: p_value = 1.7722e-18
#   F44: p_value = 3.5981e-16
#   F148: p_value = 1.9384e-15
#   F245: p_value = 1.5071e-14
#   F242: p_value = 1.6984e-14
#   F215: p_value = 2.2998e-14
#
# Class Pair: (23, 25)
#   F79: p_value = 1.7711e-23
#   F265: p_value = 9.7881e-19
#   F87: p_value = 1.7304e-16
#   F32: p_value = 3.6477e-16
#   F268: p_value = 5.2407e-16
#   F148: p_value = 8.3678e-16
#   F215: p_value = 6.7360e-14
#   F250: p_value = 7.3824e-14
#   F107: p_value = 2.6454e-13
#   F44: p_value = 1.1274e-12
#
# Class Pair: (23, 26)
#   F265: p_value = 8.1470e-20
#   F79: p_value = 4.5696e-17
#   F242: p_value = 2.9416e-16
#   F215: p_value = 9.3638e-16
#   F268: p_value = 2.8583e-15
#   F44: p_value = 1.2605e-14
#   F165: p_value = 1.1233e-13
#   F168: p_value = 1.2543e-13
#   F245: p_value = 4.4838e-13
#   F240: p_value = 5.4542e-13
#
# Class Pair: (23, 27)
#   F116: p_value = 1.0772e-17
#   F32: p_value = 1.8035e-17
#   F215: p_value = 2.5958e-16
#   F47: p_value = 1.9415e-15
#   F244: p_value = 9.7379e-14
#   F165: p_value = 3.5483e-13
#   F23: p_value = 6.8623e-13
#   F282: p_value = 8.9198e-13
#   F227: p_value = 1.4649e-12
#   F202: p_value = 2.9920e-12
#
# Class Pair: (24, 25)
#   F55: p_value = 2.1200e-20
#   F70: p_value = 3.7544e-20
#   F110: p_value = 1.5733e-18
#   F47: p_value = 2.6207e-15
#   F191: p_value = 1.3938e-14
#   F293: p_value = 2.2377e-14
#   F65: p_value = 2.7808e-13
#   F242: p_value = 3.3464e-13
#   F98: p_value = 2.1153e-12
#   F144: p_value = 3.8352e-12
#
# Class Pair: (24, 26)
#   F284: p_value = 1.8718e-32
#   F293: p_value = 4.1891e-32
#   F283: p_value = 5.9772e-30
#   F270: p_value = 1.5635e-26
#   F227: p_value = 4.6985e-25
#   F216: p_value = 5.0067e-24
#   F182: p_value = 1.6199e-23
#   F231: p_value = 3.3564e-21
#   F168: p_value = 5.5205e-21
#   F285: p_value = 3.8171e-20
#
# Class Pair: (24, 27)
#   F99: p_value = 2.1237e-42
#   F207: p_value = 6.2898e-41
#   F171: p_value = 7.1793e-40
#   F89: p_value = 1.4741e-37
#   F205: p_value = 4.4404e-37
#   F118: p_value = 4.7589e-37
#   F268: p_value = 4.7047e-35
#   F79: p_value = 1.7860e-33
#   F265: p_value = 2.4471e-33
#   F230: p_value = 1.1792e-31
#
# Class Pair: (25, 26)
#   F227: p_value = 6.6419e-40
#   F17: p_value = 1.0461e-34
#   F159: p_value = 1.4835e-29
#   F270: p_value = 8.9104e-24
#   F240: p_value = 3.1885e-22
#   F172: p_value = 6.6809e-22
#   F140: p_value = 3.0155e-21
#   F283: p_value = 6.6170e-20
#   F164: p_value = 1.3846e-19
#   F230: p_value = 1.6225e-19
#
# Class Pair: (25, 27)
#   F47: p_value = 1.3841e-43
#   F230: p_value = 5.6807e-40
#   F171: p_value = 6.4206e-40
#   F227: p_value = 5.9665e-37
#   F99: p_value = 1.3396e-35
#   F98: p_value = 3.7957e-34
#   F89: p_value = 1.3013e-33
#   F79: p_value = 1.5005e-32
#   F8: p_value = 6.3640e-31
#   F14: p_value = 2.2135e-28
#
# Class Pair: (26, 27)
#   F222: p_value = 1.9225e-33
#   F99: p_value = 7.4975e-30
#   F118: p_value = 8.7555e-30
#   F292: p_value = 2.5430e-26
#   F205: p_value = 3.0007e-26
#   F265: p_value = 5.3491e-26
#   F79: p_value = 1.2540e-23
#   F23: p_value = 2.6052e-23
#   F81: p_value = 3.4368e-23
#   F287: p_value = 3.6863e-23

# %%
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

# 收集所有特征索引
all_topk_feats_pval = []
for pair in pairwise_topk_pval.values():
    all_topk_feats_pval.extend([f['feature_idx'] for f in pair])

# 统计出现频次
feat_counter_pval = Counter(all_topk_feats_pval)

# 转为 DataFrame
feat_freq_df_pval = pd.DataFrame(feat_counter_pval.items(), columns=["feature_idx", "count"])
feat_freq_df_pval.sort_values(by="count", ascending=False, inplace=True)

# 前10个最常出现的特征
print("\nTop 10 most frequently selected features across class pairs (by t-test p-value):")
print(feat_freq_df_pval.head(10))

top_n = 10
plt.figure(figsize=(10, 5))
plt.barh(
    [f"F{int(i)}" for i in feat_freq_df_pval["feature_idx"].head(top_n)][::-1],
    feat_freq_df_pval["count"].head(top_n)[::-1],
    color="skyblue"
)
plt.xlabel("Frequency across class pairs")
plt.title(f"Top {top_n} Features Frequently Selected by t-test p-value")
plt.tight_layout()
plt.show()
# Out:
# Top 10 most frequently selected features across class pairs (by t-test p-value):
#     feature_idx  count
# 43           17     93
# 13          270     85
# 90          279     62
# 55           79     58
# 39           90     58
# 36          218     56
# 45           71     53
# 5           216     47
# 62          265     47
# 10           55     46

# %% [markdown]
# ### 基于Mutual Information 的 全局 分析

# %% [markdown]
# 单次对整体 X vs y，每个特征对全体标签的 MI，哪些特征整体上最有用

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd
import numpy as np

# 计算所有特征与标签的 MI 分数
mi_scores = mutual_info_classif(X, y, discrete_features=False, random_state=42)

# 构建完整 DataFrame（所有特征）
feat_mi_global_df = pd.DataFrame({
    "feature_idx": np.arange(len(mi_scores)),
    "mi_global_score": mi_scores 
})

# 按分数从高到低排序
feat_mi_global_df.sort_values(by="mi_global_score", ascending=False, inplace=True)

# 展示前几行
print("\nMutual Information Full Feature Table (for fusion):")
print(feat_mi_global_df.head(10))
# Out:
# Mutual Information Full Feature Table (for fusion):
#      feature_idx  mi_global_score
# 48            48         0.318193
# 270          270         0.304972
# 17            17         0.301547
# 263          263         0.275074
# 90            90         0.269411
# 172          172         0.266451
# 231          231         0.258278
# 283          283         0.251765
# 88            88         0.250956
# 71            71         0.238814

# %%
import matplotlib.pyplot as plt

top_k = 10
top_mi = feat_mi_global_df.head(top_k)

plt.figure(figsize=(10, 5))
plt.barh(
    [f"F{int(i)}" for i in top_mi["feature_idx"]][::-1],
    top_mi["mi_global_score"][::-1],
    color="darkorange"
)
plt.xlabel("Mutual Information Score")
plt.title(f"Top {top_k} Features by Global Mutual Information (mutual_info_classif)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 基于Mutual Information 的 pairwise 分析

# %% [markdown]
# 对每个类别对 (i,j) 做子集的 MI，哪些特征在局部类别对中区分强

# %%
from sklearn.feature_selection import mutual_info_classif
from itertools import combinations

class_pairs = list(combinations(np.unique(y), 2))
pairwise_topk_mi = {}

for cls0, cls1 in class_pairs:
    idx = (y == cls0) | (y == cls1)
    X_sub = X[idx]
    y_sub = y[idx]
    
    mi_scores = mutual_info_classif(X_sub, y_sub, discrete_features=False, random_state=42)
    topk_idx = np.argsort(mi_scores)[::-1][:k]

    feature_info = []
    for rank, feat_idx in enumerate(topk_idx):
        feature_info.append({
            "feature_idx": int(feat_idx),
            "mi_score": float(mi_scores[feat_idx]),
            "rank": rank + 1
        })

    pairwise_topk_mi[(int(cls0), int(cls1))] = feature_info

# %%
from collections import Counter
import matplotlib.pyplot as plt

# 统计所有出现过的特征频次
all_topk_feats_mi = []
for pair in pairwise_topk_mi.values():
    all_topk_feats_mi.extend([f['feature_idx'] for f in pair])

feat_counter_mi = Counter(all_topk_feats_mi)
feat_mi_pairwise_df = pd.DataFrame(feat_counter_mi.items(), columns=["feature_idx", "count"])
feat_mi_pairwise_df.sort_values(by="count", ascending=False, inplace=True)

# 前10个最常出现的特征
print("\nTop 10 most frequently selected features across class pairs (by mutual information):")
print(feat_mi_pairwise_df.head(10))

# 可视化
top_n = 10
plt.figure(figsize=(10, 5))
plt.barh(
    [f"F{int(i)}" for i in feat_mi_pairwise_df["feature_idx"].head(top_n)][::-1],
    feat_mi_pairwise_df["count"].head(top_n)[::-1],
    color="green"
)
plt.xlabel("Frequency across class pairs")
plt.title(f"Top {top_n} Features by Mutual Information (Pairwise)")
plt.tight_layout()
plt.show()
# Out:
# Top 10 most frequently selected features across class pairs (by mutual information):
#      feature_idx  count
# 14           270     88
# 46            17     83
# 40            90     71
# 34           218     65
# 107          279     64
# 53            79     55
# 37           265     51
# 10            55     51
# 90           268     51
# 39            87     48

# %% [markdown]
# ### 特征融合

# %%
# 标准化列名 重命名所有列，保持统一
feat_freq_df = feat_freq_df.rename(columns={"count": "freq_mean"})
feat_freq_df_pval = feat_freq_df_pval.rename(columns={"count": "freq_pval"})
feat_mi_pairwise_df = feat_mi_pairwise_df.rename(columns={"count": "freq_mi_pairwise"})
feat_mi_global_df = feat_mi_global_df.rename(columns={"mi_global_score": "freq_mi_global"})

# %%
# 合并所有特征选择结果
from functools import reduce

# 用 feature_idx 作为主键进行 outer 合并
dfs = [feat_freq_df, feat_freq_df_pval, feat_mi_pairwise_df, feat_mi_global_df]
feat_merged = reduce(lambda left, right: pd.merge(left, right, on="feature_idx", how="outer"), dfs)

# 空值填 0（即某方法未选中）
feat_merged.fillna(0, inplace=True)

# %%
# 合并所有特征选择结果
from functools import reduce

# 用 feature_idx 作为主键进行 outer 合并
dfs = [feat_freq_df, feat_freq_df_pval, feat_mi_pairwise_df, feat_mi_global_df]
feat_merged = reduce(lambda left, right: pd.merge(left, right, on="feature_idx", how="outer"), dfs)

# 空值填 0（即某方法未选中）
feat_merged.fillna(0, inplace=True)

# %%
## 方法一：Rank 平均融合
# 对每一列进行排名（值越大排名越靠前）
feat_merged["rank_mean"] = feat_merged["freq_mean"].rank(ascending=False)
feat_merged["rank_pval"] = feat_merged["freq_pval"].rank(ascending=False)
feat_merged["rank_mi_pairwise"] = feat_merged["freq_mi_pairwise"].rank(ascending=False)
feat_merged["rank_mi_global"] = feat_merged["freq_mi_global"].rank(ascending=False)

# 综合评分（可调权重）
feat_merged["rank_avg"] = (
    feat_merged["rank_mean"] +
    feat_merged["rank_pval"] +
    feat_merged["rank_mi_pairwise"] +
    feat_merged["rank_mi_global"]
) / 4

# 排序输出
feat_merged.sort_values(by="rank_avg", inplace=True)

# %%
## 方法二：投票机制（至少出现在多少种方法中）
feat_merged["vote_count"] = (
    (feat_merged["freq_mean"] > 0).astype(int) +
    (feat_merged["freq_pval"] > 0).astype(int) +
    (feat_merged["freq_mi_pairwise"] > 0).astype(int) +
    (feat_merged["freq_mi_global"] > 0).astype(int)
)

# %%
# 最终选出 Top-K 特征
top_k = 100
final_features = feat_merged["feature_idx"].head(top_k).astype(int).tolist()

# 可视输出
print(f"\nFinal Selected Top-{top_k} Features (Fused)")
print(feat_merged[["feature_idx", "rank_avg", "vote_count"]].head(top_k))
# Out:
# Final Selected Top-100 Features (Fused)
#      feature_idx  rank_avg  vote_count
# 17            17     2.750           4
# 270          270     3.000           4
# 218          218    10.250           4
# 90            90    11.750           4
# 265          265    15.500           4
# ..           ...       ...         ...
# 287          287   110.250           4
# 21            21   112.375           4
# 116          116   112.750           4
# 261          261   113.750           4
# 159          159   113.750           4
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 评估特征

# %%
## 互信息解释比 累计
import numpy as np

def plot_cumulative_information(feat_merged, mi_scores, top_k=100):
    """
    画出融合特征排序下前 N 个特征的累计互信息解释比。
    """
    # 1. 取前 top_k 的特征索引（已排序）
    feat_merged_sorted = feat_merged.sort_values(by="rank_avg")
    selected_indices = feat_merged_sorted["feature_idx"].tolist()[:top_k]

    # 2. 计算累计互信息
    cumulative_info = np.cumsum([mi_scores[i] for i in selected_indices])
    total_info = np.sum(mi_scores)
    explained_ratio = cumulative_info / total_info

    # 3. 打印一些 Top-N 的解释率
    print("\nCumulative Mutual Information Explained:")
    for n in [10, 20, 30, 50, 100, 150, 200, 250]:
        if n <= len(explained_ratio):
            print(f"  Top-{n:>3}: {explained_ratio[n-1]:.2%} of total MI")

    # 4. 可视化
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, top_k + 1), explained_ratio, marker='o', color='steelblue')
    plt.xlabel("Top-N Features (by fused rank)")
    plt.ylabel("Cumulative Mutual Information Ratio")
    plt.title("Cumulative Information Explained by Top-N Features")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return None

# %%
# 计算全局 MI 分数
from sklearn.feature_selection import mutual_info_classif
mi_scores = mutual_info_classif(X, y, discrete_features=False, random_state=42)

# 默认 Top 100
plot_cumulative_information(feat_merged, mi_scores, top_k=250)
# Out:
# Cumulative Mutual Information Explained:
#   Top- 10: 8.01% of total MI
#   Top- 20: 15.29% of total MI
#   Top- 30: 21.92% of total MI
#   Top- 50: 31.85% of total MI
#   Top-100: 52.00% of total MI
#   Top-150: 68.32% of total MI
#   Top-200: 82.55% of total MI
#   Top-250: 93.16% of total MI

# %%
## Weighted F1-score

from xgboost import XGBClassifier
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# 准备数据
X_train = pd.read_csv("../data/X_train.csv", skiprows=1, header=None).values
y_train = pd.read_csv("../data/y_train.csv", skiprows=1, header=None).values.ravel()
X_test_2 = pd.read_csv("../data/X_test_2.csv", skiprows=1, header=None).values
y_test_2 = pd.read_csv("../data/y_test_2_reduced.csv", skiprows=1, header=None).values.ravel()
X_test_eval = X_test_2[:202]

# 标准化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test_eval)

# 获取融合排序后的特征列表（最多前300个）
max_k = 300
sorted_features = feat_merged.sort_values(by="rank_avg")["feature_idx"].astype(int).tolist()[:max_k]

# 逐步评估不同 top-K 的性能
k_list = list(range(10, max_k + 1, 10))  # 从10开始每10步，避免0或过密
f1_scores = []

for k in k_list:
    selected_feats = sorted_features[:k]
    X_train_k = X_train_scaled[:, selected_feats]
    X_test_k = X_test_scaled[:, selected_feats]

    model = XGBClassifier(
        objective="multi:softprob",
        num_class=28,
        eval_metric="mlogloss",
        use_label_encoder=False,
        n_estimators=100,
        random_state=42
    )
    model.fit(X_train_k, y_train)
    y_pred = model.predict(X_test_k)

    f1 = f1_score(y_test_2, y_pred, average="weighted")
    f1_scores.append(f1)

plt.figure(figsize=(10, 5))
plt.plot(k_list, f1_scores, marker="o", color="royalblue")
plt.xlabel("Top-K Features (by fused rank)")
plt.ylabel("Weighted F1 Score")
plt.title("Feature Selection Performance vs Top-K")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:54:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:54:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:55:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:56:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:56:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:56:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:56:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:56:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:57:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:57:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:57:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:57:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:58:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:58:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:58:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:59:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:59:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [01:59:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:00:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:00:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:01:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:01:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:02:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [02:02:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ## 类别不均衡所带来的影响 和 缓解措施

# %%
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import f1_score, classification_report, recall_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

X_train_all = pd.read_csv("../data/X_train.csv", skiprows=1, header=None).values
y_train_raw = pd.read_csv("../data/y_train.csv", skiprows=1, header=None).values.ravel()

le = LabelEncoder()
y_all = le.fit_transform(y_train_raw)

X_subtrain_all, X_val_all, y_subtrain, y_val = train_test_split(
    X_train_all, y_all, test_size=0.2, stratify=y_all, random_state=42
)

# 使用前 100 个特征
final_features = feat_merged.sort_values(by="rank_avg")["feature_idx"].head(100).astype(int).tolist()
X_subtrain = X_subtrain_all[:, final_features]
X_val = X_val_all[:, final_features]

scaler = StandardScaler()
X_subtrain_std = scaler.fit_transform(X_subtrain)
X_val_std = scaler.transform(X_val)

# SMOTE 配置
min_samples = min(Counter(y_subtrain).values())
k = max(1, min(min_samples - 1, 5))
X_smote, y_smote = SMOTE(random_state=42, k_neighbors=k).fit_resample(X_subtrain_std, y_subtrain)

# 类权重计算
weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_subtrain), y=y_subtrain)
class_weights = dict(zip(np.unique(y_subtrain), weights))
sample_weights = np.array([class_weights[label] for label in y_subtrain])

# A. 原始训练
model_a = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_a.fit(X_subtrain_std, y_subtrain)
y_pred_a = model_a.predict(X_val_std)

# B. SMOTE
model_b = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_b.fit(X_smote, y_smote)
y_pred_b = model_b.predict(X_val_std)

# C. 类权重训练
model_c = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_c.fit(X_subtrain_std, y_subtrain, sample_weight=sample_weights)
y_pred_c = model_c.predict(X_val_std)

# 指标计算
results_xgb = {
    "A.Original": f1_score(y_val, y_pred_a, average="weighted"),
    "B.SMOTE": f1_score(y_val, y_pred_b, average="weighted"),
    "C.Weighted": f1_score(y_val, y_pred_c, average="weighted"),
}

# 每类 recall 比较
recall_df = pd.DataFrame({
    "Class": np.arange(28),
    "Original": recall_score(y_val, y_pred_a, average=None, zero_division=0),
    "SMOTE": recall_score(y_val, y_pred_b, average=None, zero_division=0),
    "Weighted": recall_score(y_val, y_pred_c, average=None, zero_division=0),
})

# 混淆矩阵函数
def plot_conf_matrix(title, y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, normalize=None, labels=np.arange(28))
    plt.figure(figsize=(14, 12))  
    sns.heatmap(cm, 
                annot=True, 
                fmt=".0f",         # 显示整数
                cmap="viridis", 
                annot_kws={"size": 6}, 
                xticklabels=np.arange(28), 
                yticklabels=np.arange(28))
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(title)
    plt.tight_layout()
    plt.show()


# 柱状图比较 Recall
plt.figure(figsize=(14, 6))
x = np.arange(len(recall_df))
width = 0.25
plt.bar(x - width, recall_df["Original"], width=width, label="Original")
plt.bar(x, recall_df["SMOTE"], width=width, label="SMOTE")
plt.bar(x + width, recall_df["Weighted"], width=width, label="Weighted")
plt.xticks(ticks=x, labels=recall_df["Class"])
plt.xlabel("Class")
plt.ylabel("Recall")
plt.title("Per-class Recall Comparison (XGBoost)")
plt.legend()
plt.tight_layout()
plt.show()

# 混淆矩阵
plot_conf_matrix("Confusion Matrix - Original", y_val, y_pred_a)
plot_conf_matrix("Confusion Matrix - SMOTE", y_val, y_pred_b)
plot_conf_matrix("Confusion Matrix - Weighted", y_val, y_pred_c)

report_original = pd.DataFrame(classification_report(y_val, y_pred_a, output_dict=True, zero_division=0)).T
report_smote = pd.DataFrame(classification_report(y_val, y_pred_b, output_dict=True, zero_division=0)).T
report_weighted = pd.DataFrame(classification_report(y_val, y_pred_c, output_dict=True, zero_division=0)).T

print(recall_df)
print(results_xgb)
# Out:
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:11:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:11:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:11:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#     Class  Original     SMOTE  Weighted
# 0       0  0.000000  0.000000  0.000000
# 1       1  0.000000  0.000000  0.000000
# 2       2  0.000000  0.000000  0.000000
# 3       3  0.076923  0.384615  0.153846
# 4       4  0.458333  0.541667  0.458333
# 5       5  0.978795  0.927455  0.944196
# 6       6  0.882883  0.882883  0.927928
# 7       7  0.333333  0.571429  0.380952
# 8       8  0.689320  0.689320  0.669903
# 9       9  0.000000  0.000000  0.000000
# 10     10  0.888889  0.810185  0.805556
# 11     11  0.375000  0.437500  0.625000
# 12     12  0.516484  0.472527  0.494505
# 13     13  0.083333  0.166667  0.083333
# 14     14  0.018868  0.037736  0.018868
# 15     15  0.800000  0.800000  0.400000
# 16     16  0.000000  1.000000  0.000000
# 17     17  0.492958  0.676056  0.661972
# 18     18  0.166667  0.166667  0.250000
# 19     19  0.257143  0.314286  0.371429
# 20     20  0.193548  0.193548  0.193548
# 21     21  0.555556  0.537037  0.555556
# 22     22  0.000000  0.000000  0.000000
# 23     23  0.375000  0.500000  0.375000
# 24     24  0.337662  0.415584  0.376623
# 25     25  0.189189  0.270270  0.324324
# 26     26  0.535714  0.517857  0.517857
# 27     27  0.714286  0.809524  0.857143
# {'A.Original': 0.7178871288468922, 'B.SMOTE': 0.7257952944659758, 'C.Weighted': 0.7209702951157121}

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import f1_score, recall_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

X_train_all = pd.read_csv("../data/X_train.csv", skiprows=1, header=None).values
y_train_raw = pd.read_csv("../data/y_train.csv", skiprows=1, header=None).values.ravel()
X_test_all = pd.read_csv("../data/X_test_2.csv", skiprows=1, header=None).values[:202]
y_test_raw = pd.read_csv("../data/y_test_2_reduced.csv", skiprows=1, header=None).values.ravel()

# 标签编码
le = LabelEncoder()
y_train = le.fit_transform(y_train_raw)
y_test = le.transform(y_test_raw)

# 使用 Top 100 特征
final_features = feat_merged.sort_values(by="rank_avg")["feature_idx"].head(100).astype(int).tolist()
X_train = X_train_all[:, final_features]
X_test = X_test_all[:, final_features]

# 标准化
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# 模型训练与预测
results = {}

# A. 原始数据训练
model_a = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_a.fit(X_train_std, y_train)
y_pred_a = model_a.predict(X_test_std)
results["A.Original"] = f1_score(y_test, y_pred_a, average="weighted")

# B. SMOTE
min_samples = np.min(np.bincount(y_train))
k = max(1, min(min_samples - 1, 5))
X_smote, y_smote = SMOTE(random_state=42, k_neighbors=k).fit_resample(X_train_std, y_train)
model_b = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_b.fit(X_smote, y_smote)
y_pred_b = model_b.predict(X_test_std)
results["B.SMOTE"] = f1_score(y_test, y_pred_b, average="weighted")

# C. 类权重
weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(zip(np.unique(y_train), weights))
sample_weights = np.array([class_weights[label] for label in y_train])
model_c = XGBClassifier(objective="multi:softprob", num_class=28,
                        eval_metric="mlogloss", use_label_encoder=False, random_state=42)
model_c.fit(X_train_std, y_train, sample_weight=sample_weights)
y_pred_c = model_c.predict(X_test_std)
results["C.Weighted"] = f1_score(y_test, y_pred_c, average="weighted")

# Per-class Recall
recall_df_test = pd.DataFrame({
    "Class": np.arange(28),
    "Original": recall_score(y_test, y_pred_a, average=None, labels=np.arange(28), zero_division=0),
    "SMOTE": recall_score(y_test, y_pred_b, average=None, labels=np.arange(28), zero_division=0),
    "Weighted": recall_score(y_test, y_pred_c, average=None, labels=np.arange(28), zero_division=0),
})

plt.figure(figsize=(14, 6))
x = np.arange(len(recall_df_test))
width = 0.25
plt.bar(x - width, recall_df_test["Original"], width=width, label="Original")
plt.bar(x, recall_df_test["SMOTE"], width=width, label="SMOTE")
plt.bar(x + width, recall_df_test["Weighted"], width=width, label="Weighted")
plt.xticks(ticks=x, labels=recall_df_test["Class"])
plt.xlabel("Class")
plt.ylabel("Recall")
plt.title("Per-class Recall Comparison on Test Set (XGBoost)")
plt.legend()
plt.tight_layout()
plt.show()

plot_conf_matrix("Confusion Matrix - Original (Test Set)", y_test, y_pred_a)
plot_conf_matrix("Confusion Matrix - SMOTE (Test Set)", y_test, y_pred_b)
plot_conf_matrix("Confusion Matrix - Weighted (Test Set)", y_test, y_pred_c)

report_original = classification_report(y_test, y_pred_a, output_dict=True, zero_division=0)
report_smote = classification_report(y_test, y_pred_b, output_dict=True, zero_division=0)
report_weighted = classification_report(y_test, y_pred_c, output_dict=True, zero_division=0)

df_report_original = pd.DataFrame(report_original).transpose()
df_report_smote = pd.DataFrame(report_smote).transpose()
df_report_weighted = pd.DataFrame(report_weighted).transpose()

print(recall_df_test)
print(results)
# Out:
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:13:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# E:\Languages\Anaconda3\envs\py310\lib\site-packages\xgboost\core.py:158: UserWarning: [14:14:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#     Class  Original     SMOTE  Weighted
# 0       0  0.000000  0.000000  0.000000
# 1       1  0.000000  0.000000  0.000000
# 2       2  0.000000  0.000000  0.000000
# 3       3  0.000000  0.000000  0.000000
# 4       4  0.750000  0.500000  0.750000
# 5       5  1.000000  0.777778  1.000000
# 6       6  1.000000  1.000000  1.000000
# 7       7  0.214286  0.428571  0.357143
# 8       8  0.689655  0.793103  0.793103
# 9       9  0.000000  0.000000  0.000000
# 10     10  1.000000  1.000000  1.000000
# 11     11  0.666667  0.888889  0.888889
# 12     12  0.604651  0.604651  0.581395
# 13     13  1.000000  1.000000  1.000000
# 14     14  0.000000  0.166667  0.000000
# 15     15  0.000000  0.000000  0.000000
# 16     16  0.000000  0.000000  0.000000
# 17     17  0.500000  0.700000  0.600000
# 18     18  0.000000  0.000000  0.000000
# 19     19  0.500000  0.250000  0.250000
# 20     20  0.333333  0.666667  0.000000
# 21     21  0.714286  0.571429  0.571429
# 22     22  0.000000  0.000000  0.000000
# 23     23  0.000000  0.000000  0.000000
# 24     24  0.400000  0.533333  0.333333
# 25     25  0.384615  0.461538  0.461538
# 26     26  1.000000  1.000000  1.000000
# 27     27  0.625000  0.750000  0.500000
# {'A.Original': 0.5491248082019291, 'B.SMOTE': 0.6163808216982826, 'C.Weighted': 0.5717742659734806}

# %% [markdown]
# ## 为什么accuracy指标 不适合 用于类别不均衡场景问题 有什么更合适的评价指标

# %% [markdown]
#  类别分布严重不平衡的多分类问题中，传统的准确率（Accuracy）指标往往无法真实反映模型性能。例如，当训练数据中某一主类占比达到 95% 时，模型即便始终预测为该主类，也可轻松获得 95% 的准确率。然而，此时模型对其他 27 个类别完全没有学习能力。因此，仅使用准确率作为评估标准，会对模型在少数类上的表现产生误导性判断。
#
# 为更全面地评估模型性能，尤其是其对少数类的识别能力，我们将采用以下更优的评价指标：
#
# - **Precision（精确率）**：用于衡量模型在预测为某类时的正确率。它反映了误报（False Positives）情况，特别适合对错误预测代价较高的场景。
#
# - **Recall（召回率）**：衡量模型在实际属于某类的样本中被成功识别出来的比例，强调覆盖性。对于少数类识别能力的评估尤为关键。
#
# - **F1-score**：精确率与召回率的调和平均值，兼顾“预测准确性”与“检测全面性”，在精确率和召回率存在权衡时能提供更稳定的评价。
#
# - **AUC-ROC / AUC-PR 曲线面积**：从概率输出角度评价模型的排序能力。特别是 AUC-PR，在正负样本比例极度失衡时更为敏感，是对少数类预测质量的补充评估手段。
#
# - **Confusion Matrix（混淆矩阵）**：直观展示模型在各类别上的预测正确率与混淆情况，有助于发现模型在哪些具体类别上存在识别偏差。
#
# 此外，我们将会使用不同的聚合方式：
# - `macro` 平均对每个类别赋予相同权重，反映模型在所有类别上的“公平性”；
# - `weighted` 平均根据类别样本数加权，更能代表模型整体预测性能。
